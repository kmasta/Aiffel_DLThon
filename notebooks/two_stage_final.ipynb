# %%
# !git clone https://github.com/kmasta/Aiffel_DLThon.git
# Out:
# Cloning into 'Aiffel_DLThon'...
# remote: Enumerating objects: 509, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 509 (delta 43), reused 42 (delta 26), pack-reused 420 (from 1)
# Receiving objects: 100% (509/509), 80.87 MiB | 16.94 MiB/s, done.
# Resolving deltas: 100% (241/241), done.
# Updating files: 100% (196/196), done.

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.51.3

# %% [markdown]
# # Baseline Code

# %% [markdown]
# ## 필요한 라이브러리 임포트

# %%
import yaml
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments, EarlyStoppingCallback, ElectraForSequenceClassification
from sklearn.metrics import f1_score, accuracy_score
from torch.utils.data import Dataset
import torch
import os

from Aiffel_DLThon.pytorch_code.callback.logger import log_message, log_target_distribution, LoggingCallback
from Aiffel_DLThon.pytorch_code.callback.early_stopping import EarlyStopping
from Aiffel_DLThon.pytorch_code.callback.checkpoint import save_model
from Aiffel_DLThon.pytorch_code.callback.save_results import save_submission

# %% [markdown]
# ## 모델 정보 불러오기

# %%
# Load model name
with open("./Aiffel_DLThon/pytorch_code/config/model_name.yaml", "r") as f:
    model_name_config = yaml.safe_load(f)
model_key = model_name_config["model_name"]

# Load full config for that model
with open(f"./Aiffel_DLThon/pytorch_code/config/{model_key}.yaml", "r") as f:
    config = yaml.safe_load(f)

log_message(f"Running experiment: {config['experiment_name']}", config["log_dir"])
# Out:
# [2025-05-06 19:45:17] Running experiment: klue_roberta_exp3

# %% [markdown]
# ## 토크나이저, 모델 구현

# %%
from transformers import ElectraPreTrainedModel, ElectraModel
from transformers.modeling_outputs import SequenceClassifierOutput
import torch.nn.functional as F
import torch.nn as nn

class ElectraTwoStageModel(ElectraPreTrainedModel):
    def __init__(self, config):
        super().__init__(config)
        self.electra = ElectraModel(config)
        self.dropout = nn.Dropout(config.hidden_dropout_prob)
        self.stage1_classifier = nn.Linear(config.hidden_size, 2)  # Binary
        self.stage2_classifier = nn.Linear(config.hidden_size, 4)  # Multiclass

        self.init_weights()

    def forward(self, input_ids, attention_mask=None, token_type_ids=None,
            binary_labels=None, multiclass_labels=None):
        outputs = self.electra(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids
        )
        cls_output = self.dropout(outputs.last_hidden_state[:, 0, :])

        # Stage 1: 일반 vs 특수
        stage1_logits = self.stage1_classifier(cls_output)

        # Stage 2: 일반 중 세부 분류
        stage2_logits = self.stage2_classifier(cls_output)

        loss = None
        if binary_labels is not None and multiclass_labels is not None:
            loss_fct = nn.CrossEntropyLoss()
            loss1 = loss_fct(stage1_logits, binary_labels)

            mask = (binary_labels == 0)
            if mask.sum() > 0:
                loss2 = loss_fct(stage2_logits[mask], multiclass_labels[mask])
                loss = loss1 + loss2
            else:
                loss = loss1

        return SequenceClassifierOutput(
            loss=loss,
            logits=stage1_logits
        )

# %%
from transformers import RobertaModel, RobertaPreTrainedModel

class RobertaTwoStageModel(RobertaPreTrainedModel):
    def __init__(self, config):
        super().__init__(config)
        self.roberta           = RobertaModel(config)
        self.dropout           = nn.Dropout(config.hidden_dropout_prob)
        self.stage1_classifier = nn.Linear(config.hidden_size, 2)
        # Temperature Scaling 파라미터 (초기값 1.0)
        self.temperature = nn.Parameter(torch.ones(1))
        self.init_weights()

    def forward(self,
                input_ids,
                attention_mask=None,
                token_type_ids=None,
                labels=None,
                calibrate: bool = False):
        # 1) RoBERTa 통과
        outputs = self.roberta(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids
        )

        # 2) [CLS] 토큰 임베딩
        cls_output = outputs.last_hidden_state[:, 0, :]
        cls_output = self.dropout(cls_output)

        # 3) Stage1 로짓
        logits = self.stage1_classifier(cls_output)  # (batch, 2)

        # 4) Temperature Scaling 적용
        #    - training 중에는 원본 logits 그대로
        #    - inference 또는 calibrate=True 경우 temperature로 나눔
        if not self.training or calibrate:
            # clamp로 0 방지
            T = self.temperature.clamp(min=1e-6)
            logits = logits / T

        # 5) Loss 계산 (label_smoothing=0.2)
        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss(label_smoothing=0.2)
            loss = loss_fn(logits, labels)

        return SequenceClassifierOutput(
            loss=loss,
            logits=logits
        )

    @torch.no_grad()
    def calibrate_temperature(self, valid_loader, device, lr: float = 0.01, max_iter: int = 50):
        """
        검증셋(valid_loader)에 대해 temperature(T)만 최적화합니다.
        """
        self.to(device)
        self.eval()
        logits_list, labels_list = [], []
        for batch in valid_loader:
            batch = {k: v.to(device) for k, v in batch.items()}
            out = self.forward(**batch, calibrate=False)
            logits_list.append(out.logits)
            labels_list.append(batch['labels'])
        logits = torch.cat(logits_list, dim=0)
        labels = torch.cat(labels_list, dim=0)

        # T만 최적화
        optimizer = torch.optim.LBFGS([self.temperature], lr=lr, max_iter=max_iter)

        def _eval():
            optimizer.zero_grad()
            loss = F.cross_entropy(logits / self.temperature.clamp(min=1e-6), labels)
            loss.backward()
            return loss

# %%
tokenizer = AutoTokenizer.from_pretrained('klue/roberta-base')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/752k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/173 [00:00<?, ?B/s]

# %% [markdown]
# ## 커스텀 데이터셋 클래스(토크나이징)

# %%
class TwoStageDataset(Dataset):
    def __init__(self, encodings, binary_labels, multiclass_labels):
        self.encodings = encodings
        self.binary_labels = binary_labels
        self.multiclass_labels = multiclass_labels

    def __len__(self):
        return len(self.binary_labels)

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item["labels"] = torch.tensor(self.binary_labels[idx])  # ✅ 반드시 Trainer용 key
        item["binary_labels"] = torch.tensor(self.binary_labels[idx])
        item["multiclass_labels"] = torch.tensor(self.multiclass_labels[idx])
        return item

# %%
class BinaryDataset(Dataset):
    def __init__(self, encodings, binary_labels):
        num = len(next(iter(encodings.values())))
        assert num == len(binary_labels), "encodings와 라벨 길이가 달라요"
        self.encodings     = encodings
        self.binary_labels = binary_labels

    def __len__(self):
        return len(self.binary_labels)

    def __getitem__(self, idx):
        item = {}
        for k, v in self.encodings.items():
            # 이미 Tensor이면 바로 슬라이스
            item[k] = v[idx] if isinstance(v, torch.Tensor) else torch.tensor(v[idx])
        item["labels"] = torch.tensor(self.binary_labels[idx])
        return item

class MultiDataset(Dataset):
    def __init__(self, encodings, multiclass_labels):
        num = len(next(iter(encodings.values())))
        assert num == len(multiclass_labels), "encodings와 라벨 길이가 달라요"
        self.encodings         = encodings
        self.multiclass_labels = multiclass_labels

    def __len__(self):
        return len(self.multiclass_labels)

    def __getitem__(self, idx):
        item = {}
        for k, v in self.encodings.items():
            item[k] = v[idx] if isinstance(v, torch.Tensor) else torch.tensor(v[idx])
        item["labels"] = torch.tensor(self.multiclass_labels[idx])
        return item

# %% [markdown]
# ## 데이터 불러오기

# %%
from sklearn.model_selection import train_test_split

def prepare_two_stage_dataset(texts, labels, tokenizer, max_length=400, test_size=0.2):
    # 1) Stage1 이진 레이블, Stage2 다중 레이블(-1은 일반 대화)
    binary_labels    = [0 if l in [0,1,2,3] else 1 for l in labels]
    multiclass_labels= [l if l in [0,1,2,3] else -1 for l in labels]

    # 2) Train/Val 분리 (stratify는 원래 multiclass_labels가 아니라 binary_labels 로 하는 게 안전합니다)
    train_texts, val_texts, \
    train_binary, val_binary, \
    train_multi,  val_multi = train_test_split(
        texts, binary_labels, multiclass_labels,
        test_size=test_size,
        stratify=binary_labels,  # 일반/협박 비율 유지
        random_state=42
    )

    # 3) 토크나이즈
    train_enc = tokenizer(train_texts, truncation=True, padding=True,
                           max_length=max_length, return_tensors="pt")
    val_enc   = tokenizer(val_texts,   truncation=True, padding=True,
                           max_length=max_length, return_tensors="pt")

    # 4) Stage1 Dataset
    binary_train_dataset = BinaryDataset(train_enc, train_binary)
    binary_val_dataset   = BinaryDataset(val_enc,   val_binary)

    # 5) Stage2: multiclass_labels == -1 인 인덱스 제거
    train_idx_keep = [i for i, l in enumerate(train_multi) if l != -1]
    val_idx_keep   = [i for i, l in enumerate(val_multi)   if l != -1]

    # 텐서 슬라이싱: 각 key에 대해 first-dim 인덱싱
    def slice_enc(encodings, idxs):
        return {k: v[idxs] for k, v in encodings.items()}

    train_enc_filt = slice_enc(train_enc, train_idx_keep)
    val_enc_filt   = slice_enc(val_enc,   val_idx_keep)

    train_multi_filt = [train_multi[i] for i in train_idx_keep]
    val_multi_filt   = [val_multi[i]   for i in val_idx_keep]

    multi_train_dataset = MultiDataset(train_enc_filt, train_multi_filt)
    multi_val_dataset   = MultiDataset(val_enc_filt,   val_multi_filt)

    return binary_train_dataset, multi_train_dataset, binary_val_dataset, multi_val_dataset

# %%
train_df = pd.read_csv("./Aiffel_DLThon/data/processed/stopwords/original/st_train.csv")
texts = train_df["clean_text"].tolist()
labels = train_df["label"].tolist()

gen1_df = pd.read_csv("./Aiffel_DLThon/data/processed/stopwords/generated/st_general.csv")
texts.extend(gen1_df["clean_text"].tolist())
labels.extend(gen1_df["label"].tolist())

gen_bad_df1 = pd.read_csv( "./Aiffel_DLThon/data/processed/stopwords/generated/st_bad.csv")
texts.extend(gen_bad_df1["clean_text"].tolist())
labels.extend(gen_bad_df1["label"].tolist())

gen_bad_df2 = pd.read_csv( "./Aiffel_DLThon/data/processed/stopwords/generated/st_bad2.csv")
texts.extend(gen_bad_df2["clean_text"].tolist())
labels.extend(gen_bad_df2["label"].tolist())

back_trans_df = pd.read_csv("./Aiffel_DLThon/data/processed/stopwords/augmented/st_backT.csv")
texts.extend(back_trans_df["clean_text"].tolist())
labels.extend(back_trans_df["label"].tolist())

ri_df = pd.read_csv("./Aiffel_DLThon/data/processed/stopwords/augmented/st_ri.csv")
texts.extend(ri_df["clean_text"].tolist())
labels.extend(ri_df["label"].tolist())

#eda_df = pd.read_csv("./Aiffel_DLThon/data/processed/stopwords/augmented/st_eda.csv")
#texts.extend(eda_df["clean_text"].tolist())
#labels.extend(eda_df["label"].tolist())
#gen2_df = pd.read_csv("./Aiffel_DLThon/data/processed/stopwords/generated/st_general2.csv")
#texts.extend(gen2_df["clean_text"].tolist())
#labels.extend(gen2_df["label"].tolist())
#rd_df = pd.read_csv("./Aiffel_DLThon/data/processed/stopwords/augmented/st_rd.csv")
#texts.extend(rd_df["clean_text"].tolist())
#labels.extend(rd_df["label"].tolist())
#mlm_df = pd.read_csv('./Aiffel_DLThon/data/processed/augmented/clean_mlm.csv')
#texts.extend(mlm_df["clean_text"].tolist())
#labels.extend(mlm_df["label"].tolist())

# %%
data_df = pd.concat([train_df, gen1_df, gen_bad_df1, gen_bad_df2, back_trans_df, ri_df], ignore_index=True)

# %%
binary_train_dataset, multi_train_dataset, binary_val_dataset, multi_val_dataset = prepare_two_stage_dataset(texts, labels, tokenizer)

# %%
sample = binary_val_dataset[0]
print("🔍 sample['labels']:", sample['labels'])
print("🔍 type:", type(sample['labels']))
# Out:
# 🔍 sample['labels']: tensor(0)
# 🔍 type: <class 'torch.Tensor'>

# %%
label_counts = pd.Series(labels).value_counts().sort_index()

print("📊 train label 클래스 분포:")
print(label_counts)
# Out:
# 📊 train label 클래스 분포:
# 0    2688
# 1    2943
# 2    2937
# 3    3282
# 4    3036
# Name: count, dtype: int64

# %% [markdown]
# ## 매트릭 함수

# %%
from sklearn.metrics import f1_score, accuracy_score
import numpy as np
from collections import Counter

def evaluate_stage1(trainer, val_dataset):
    pred_output = trainer.predict(val_dataset)
    y_true = pred_output.label_ids
    y_pred = np.argmax(pred_output.predictions, axis=1)

    # 메트릭 계산
    f1 = f1_score(y_true, y_pred, average="macro")
    acc = accuracy_score(y_true, y_pred)

    # 분포 확인
    print("📊 Stage 1 정답 분포:", Counter(y_true))
    print("📊 Stage 1 예측 분포:", Counter(y_pred))
    print("✅ Stage 1 Accuracy:", acc)
    print("✅ Stage 1 F1 (macro):", f1)

    return {
        "f1_macro": f1,
        "accuracy": acc
    }

# %%
from sklearn.metrics import f1_score, accuracy_score
import numpy as np
from collections import Counter

def evaluate_stage2(trainer, val_dataset):
    # 예측
    pred_output = trainer.predict(val_dataset)
    y_true = pred_output.label_ids
    y_pred = np.argmax(pred_output.predictions, axis=1)

    # 메트릭 계산
    f1 = f1_score(y_true, y_pred, average="macro")
    acc = accuracy_score(y_true, y_pred)

    # 분포 확인
    print("📊 정답 분포:", Counter(y_true))
    print("📊 예측 분포:", Counter(y_pred))
    print("✅ Stage 2 Accuracy:", acc)
    print("✅ Stage 2 F1 (macro):", f1)

    return {
        "f1_macro": f1,
        "accuracy": acc
    }

# %%
"""def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    return {
        "accuracy": accuracy_score(labels, preds),
        "f1_macro": f1_score(labels, preds, average="macro")
    }"""
# Out:
# 'def compute_metrics(pred):\n    labels = pred.label_ids\n    preds = pred.predictions.argmax(-1)\n    return {\n        "accuracy": accuracy_score(labels, preds),\n        "f1_macro": f1_score(labels, preds, average="macro")\n    }'

# %%
def compute_metrics(pred):
    print("✅ compute_metrics called")
    print("🔍 type(pred.label_ids):", type(pred.label_ids))

    # 예외 처리: label_ids가 tuple이면 첫 번째 요소만 사용 (binary classification용)
    label_ids = pred.label_ids[0] if isinstance(pred.label_ids, tuple) else pred.label_ids

    print("🔍 label_ids shape:", getattr(label_ids, "shape", "❌ No shape"))
    print("🔍 predictions shape:", pred.predictions.shape)

    preds = np.argmax(pred.predictions, axis=1)

    return {
        "accuracy": accuracy_score(label_ids, preds),
        "f1_macro": f1_score(label_ids, preds, average="macro")
    }

# %% [markdown]
# ## 모델 준비

# %%
print(TrainingArguments.__module__)
# Out:
# transformers.training_args

# %%
training_args = TrainingArguments(
    output_dir='./Aiffel_DLThon/ckpoints/roberta',
    num_train_epochs=8,
    per_device_train_batch_size=16,
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=float(1e-6),
    weight_decay=0.1,
    warmup_ratio=0.2,
    logging_dir='./Aiffel_DLThon/logs/klue_roberta',
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="f1_macro",
    logging_strategy="steps",
    logging_steps=50,
    report_to="tensorboard",
)

from transformers import AutoConfig

config = AutoConfig.from_pretrained("klue/roberta-base", num_labels=2)
config.hidden_dropout_prob = 0.3
two_stage_model = RobertaTwoStageModel(config)

trainer = Trainer(
    model=two_stage_model,
    args=training_args,
    train_dataset=binary_train_dataset,
    eval_dataset=binary_val_dataset,
    compute_metrics=compute_metrics,
    callbacks=[
        EarlyStoppingCallback(early_stopping_patience=2),
        LoggingCallback(),
    ]
)
# Out:
# config.json:   0%|          | 0.00/546 [00:00<?, ?B/s]

# %% [markdown]
# ## 모델 학습

# %%
print(trainer.compute_metrics)
# Out:
# <function compute_metrics at 0x7857949ca0c0>

# %%
trainer.train()
save_model(two_stage_model, './save_model', epoch=8)
# Out:
#     <div>
#
#       <progress value='5960' max='5960' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5960/5960 26:18, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.595400</td>
#       <td>0.672619</td>
#       <td>0.796172</td>
#       <td>0.443260</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.473700</td>
#       <td>0.476698</td>
#       <td>0.912021</td>
#       <td>0.843317</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.416900</td>
#       <td>0.416877</td>
#       <td>0.969107</td>
#       <td>0.952811</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.397700</td>
#       <td>0.448437</td>
#       <td>0.969107</td>
#       <td>0.949692</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.390700</td>
#       <td>0.395812</td>
#       <td>0.981867</td>
#       <td>0.971207</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.378300</td>
#       <td>0.387552</td>
#       <td>0.983882</td>
#       <td>0.974505</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.369900</td>
#       <td>0.386381</td>
#       <td>0.983210</td>
#       <td>0.973375</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.375700</td>
#       <td>0.385322</td>
#       <td>0.983546</td>
#       <td>0.973924</td>
#     </tr>
#   </tbody>
# </table><p>
# ✅ compute_metrics called
# 🔍 type(pred.label_ids): <class 'numpy.ndarray'>
# 🔍 label_ids shape: (2978,)
# 🔍 predictions shape: (2978, 2)
# [2025-05-06 19:48:46] Epoch 01 | Train Loss: 0.0000 | Val Loss: 0.6726 | Val Acc: 0.7962 | Val F1(Macro): 0.4433
# ✅ compute_metrics called
# 🔍 type(pred.label_ids): <class 'numpy.ndarray'>
# 🔍 label_ids shape: (2978,)
# 🔍 predictions shape: (2978, 2)
# [2025-05-06 19:52:03] Epoch 02 | Train Loss: 0.0000 | Val Loss: 0.4767 | Val Acc: 0.9120 | Val F1(Macro): 0.8433
# ✅ compute_metrics called
# 🔍 type(pred.label_ids): <class 'numpy.ndarray'>
# 🔍 label_ids shape: (2978,)
# 🔍 predictions shape: (2978, 2)
# [2025-05-06 19:55:20] Epoch 03 | Train Loss: 0.0000 | Val Loss: 0.4169 | Val Acc: 0.9691 | Val F1(Macro): 0.9528
# ✅ compute_metrics called
# 🔍 type(pred.label_ids): <class 'numpy.ndarray'>
# 🔍 label_ids shape: (2978,)
# 🔍 predictions shape: (2978, 2)
# [2025-05-06 19:58:37] Epoch 04 | Train Loss: 0.0000 | Val Loss: 0.4484 | Val Acc: 0.9691 | Val F1(Macro): 0.9497
# ✅ compute_metrics called
# 🔍 type(pred.label_ids): <class 'numpy.ndarray'>
# 🔍 label_ids shape: (2978,)
# 🔍 predictions shape: (2978, 2)
# [2025-05-06 20:01:55] Epoch 05 | Train Loss: 0.0000 | Val Loss: 0.3958 | Val Acc: 0.9819 | Val F1(Macro): 0.9712
# ✅ compute_metrics called
# 🔍 type(pred.label_ids): <class 'numpy.ndarray'>
# 🔍 label_ids shape: (2978,)
# 🔍 predictions shape: (2978, 2)
# [2025-05-06 20:05:12] Epoch 06 | Train Loss: 0.0000 | Val Loss: 0.3876 | Val Acc: 0.9839 | Val F1(Macro): 0.9745
# ✅ compute_metrics called
# 🔍 type(pred.label_ids): <class 'numpy.ndarray'>
# 🔍 label_ids shape: (2978,)
# 🔍 predictions shape: (2978, 2)
# [2025-05-06 20:08:29] Epoch 07 | Train Loss: 0.0000 | Val Loss: 0.3864 | Val Acc: 0.9832 | Val F1(Macro): 0.9734
# ✅ compute_metrics called
# 🔍 type(pred.label_ids): <class 'numpy.ndarray'>
# 🔍 label_ids shape: (2978,)
# 🔍 predictions shape: (2978, 2)
# [2025-05-06 20:11:47] Epoch 08 | Train Loss: 0.0000 | Val Loss: 0.3853 | Val Acc: 0.9835 | Val F1(Macro): 0.9739

# %%
from torch.utils.data import Dataset, DataLoader

model = two_stage_model
class PlainTextDataset(Dataset):
    def __init__(self, texts, tokenizer, max_length):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=max_length)

    def __len__(self):
        return len(self.encodings["input_ids"])

    def __getitem__(self, idx):
        return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}


test_df = pd.read_csv("./Aiffel_DLThon/data/original_data/test.csv")
test_texts = test_df["text"].tolist()

# Dataset & Dataloader
test_dataset = PlainTextDataset(test_texts, tokenizer, 200)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

import torch
from torch.nn.functional import softmax

model.eval()
label4_probs = []

with torch.no_grad():
    for batch in test_loader:
        batch = {k: v.to(model.device) for k, v in batch.items()}
        outputs = model(**batch)
        probs = softmax(outputs.logits, dim=-1)
        label4_batch_probs = probs[:, 1].cpu().numpy()
        label4_probs.extend(label4_batch_probs)

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 4))
sns.histplot(label4_probs, bins=30, kde=True)
plt.title("Distribution of Label 4 Probabilities on Test Set")
plt.xlabel("Predicted Probability of Label 4")
plt.ylabel("Number of Samples")
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report
from torch.utils.data import DataLoader
from tqdm import tqdm
import torch

def evaluate_stage1(model, dataset, batch_size=32):
    model.eval()
    dataloader = DataLoader(dataset, batch_size=batch_size)
    preds = []
    labels = []

    for batch in tqdm(dataloader, desc="Stage 1 Evaluation"):
        input_ids = batch["input_ids"].to(model.device)
        attention_mask = batch["attention_mask"].to(model.device)
        token_type_ids = batch["token_type_ids"].to(model.device)
        binary_labels = batch["labels"].to(model.device)

        with torch.no_grad():
            logits = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                token_type_ids=token_type_ids
            ).logits  # ✅ Stage 1 logits only

        pred = torch.argmax(logits, dim=1)
        preds.extend(pred.cpu().tolist())
        labels.extend(binary_labels.cpu().tolist())

    acc = accuracy_score(labels, preds)
    f1 = f1_score(labels, preds, average='macro')

    print("📊 Stage 1 Evaluation Results")
    print(f"✅ Accuracy: {acc:.4f}")
    print(f"✅ F1 Score (macro): {f1:.4f}")
    print("📋 Classification Report:\n", classification_report(labels, preds, digits=4))
    return {"accuracy": acc, "f1_macro": f1}
stage1_metrics = evaluate_stage1(two_stage_model, binary_val_dataset)
# Out:
# Stage 1 Evaluation: 100%|██████████| 94/94 [00:13<00:00,  6.98it/s]
# 📊 Stage 1 Evaluation Results
# ✅ Accuracy: 0.9839
# ✅ F1 Score (macro): 0.9745
# 📋 Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9814    0.9987    0.9900      2371
#            1     0.9947    0.9259    0.9590       607
#
#     accuracy                         0.9839      2978
#    macro avg     0.9880    0.9623    0.9745      2978
# weighted avg     0.9841    0.9839    0.9837      2978

# %%
from collections import Counter

binary_preds = np.argmax(trainer.predict(binary_val_dataset).predictions, axis=1)
counter = Counter(binary_preds)
print("✅ Stage 1 예측 분포:", counter)
# Out:
# ✅ compute_metrics called
# 🔍 type(pred.label_ids): <class 'numpy.ndarray'>
# 🔍 label_ids shape: (2978,)
# 🔍 predictions shape: (2978, 2)
# ✅ Stage 1 예측 분포: Counter({np.int64(0): 2413, np.int64(1): 565})

# %%
from torch.utils.data import DataLoader
dl = DataLoader(multi_train_dataset, batch_size=128)
all_labels = []
for batch in dl:
    lbls = batch["labels"]  # or batch[2] depending on __getitem__
    all_labels.append(lbls)
all = torch.cat(all_labels)
print("min:", all.min().item(), "max:", all.max().item())
# ==> 둘 다 0~3 사이여야 합니다.
# Out:
# min: 0 max: 3

# %%
from transformers import ElectraModel, ElectraPreTrainedModel
import torch.nn as nn

class ElectraStage2Classifier(ElectraPreTrainedModel):
    def __init__(self, config):
        super().__init__(config)
        self.electra = ElectraModel(config)
        self.dropout = nn.Dropout(config.hidden_dropout_prob)
        self.classifier = nn.Linear(config.hidden_size, 4)  # 4-class

        self.init_weights()

    def forward(self, input_ids, attention_mask=None, token_type_ids=None, labels=None):
        outputs = self.electra(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids
        )
        cls_output = self.dropout(outputs.last_hidden_state[:, 0, :])
        logits = self.classifier(cls_output)

        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)

        return SequenceClassifierOutput(
            loss=loss,
            logits=logits
        )

class RobertaStage2Classifier(RobertaPreTrainedModel):
    def __init__(self, config):
        super().__init__(config)
        self.roberta    = RobertaModel(config)
        self.dropout    = nn.Dropout(config.hidden_dropout_prob)
        self.classifier = nn.Linear(config.hidden_size, config.num_labels)
        self.init_weights()

    def forward(
        self,
        input_ids,
        attention_mask=None,
        token_type_ids=None,
        labels=None
    ):
        outputs = self.roberta(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids
        )
        cls_output = self.dropout(outputs.last_hidden_state[:, 0, :])
        logits     = self.classifier(cls_output)

        loss = None
        if labels is not None:
            loss = nn.CrossEntropyLoss(label_smoothing=0.2)(logits, labels)

        # dict 대신 ModelOutput 반환
        return SequenceClassifierOutput(
            loss=loss,
            logits=logits,
            hidden_states=outputs.hidden_states,
            attentions=outputs.attentions
        )


from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(
    output_dir="./stage2_model",
    eval_strategy="epoch",
    save_strategy="epoch",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=5,
    logging_dir="./logs",
    logging_steps=50,
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="f1_macro",
    report_to="tensorboard",
)

"""training_args = TrainingArguments(
    output_dir='./stage2_model',
    num_train_epochs=8,
    per_device_train_batch_size=16,
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=float(1e-6),
    weight_decay=0.1,
    warmup_ratio=0.2,
    logging_dir='./Aiffel_DLThon/logs/klue_roberta',
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="f1_macro",
    logging_strategy="steps",
    logging_steps=50,
    report_to="tensorboard",
)"""
from sklearn.metrics import accuracy_score, f1_score

def compute_metrics_stage2(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    return {
        "accuracy": accuracy_score(labels, preds),
        "f1_macro": f1_score(labels, preds, average="macro")
    }
from transformers import AutoConfig

config = AutoConfig.from_pretrained("klue/roberta-base", num_labels=4)
model = RobertaStage2Classifier.from_pretrained("klue/roberta-base", config=config)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=multi_train_dataset,
    eval_dataset=multi_val_dataset,
    compute_metrics=compute_metrics_stage2
)

trainer.train()
# Out:
# Some weights of RobertaStage2Classifier were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='2965' max='2965' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2965/2965 13:00, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.798000</td>
#       <td>0.743740</td>
#       <td>0.899199</td>
#       <td>0.898923</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.694000</td>
#       <td>0.714037</td>
#       <td>0.935049</td>
#       <td>0.934818</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.629800</td>
#       <td>0.681119</td>
#       <td>0.954871</td>
#       <td>0.954993</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.608500</td>
#       <td>0.662317</td>
#       <td>0.964150</td>
#       <td>0.964128</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.597800</td>
#       <td>0.664632</td>
#       <td>0.961620</td>
#       <td>0.961394</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2965, training_loss=0.6842122468739296, metrics={'train_runtime': 781.1745, 'train_samples_per_second': 60.671, 'train_steps_per_second': 3.796, 'total_flos': 9742478435664000.0, 'train_loss': 0.6842122468739296, 'epoch': 5.0})

# %%
save_model(model, './save_model2', epoch=5)

# %%
from collections import Counter
import matplotlib.pyplot as plt

stage2_labels = labels

# 분포 확인
label_counts = Counter(stage2_labels)

print("📊 Stage 2 학습용 라벨 분포:")
for label, count in sorted(label_counts.items()):
    print(f"Label {label}: {count}")

# 시각화
plt.bar(label_counts.keys(), label_counts.values())
plt.title("Stage 2 Class Distribution")
plt.xlabel("Label")
plt.ylabel("Count")
plt.xticks([0, 1, 2, 3, 4])
plt.show()
# Out:
# 📊 Stage 2 학습용 라벨 분포:
# Label 0: 2688
# Label 1: 2943
# Label 2: 2937
# Label 3: 3282
# Label 4: 3036

# %%
output_dir = "./roberta_two_stage_model2"

# 디렉토리 생성 (필요시)
import os
os.makedirs(output_dir, exist_ok=True)

# 모델 저장
two_stage_model.save_pretrained(output_dir)

# config도 함께 저장
two_stage_model.config.save_pretrained(output_dir)

output_dir = "./roberta_two_stage_model1"

# 디렉토리 생성 (필요시)
import os
os.makedirs(output_dir, exist_ok=True)

# 모델 저장
model.save_pretrained(output_dir)

# config도 함께 저장
model.config.save_pretrained(output_dir)

# %%
def eval_stage1(model, dataloader, device):
    model.eval()
    all_preds, all_probs = [], []
    with torch.no_grad():
        for batch in dataloader:
            # batch가 dict인지 tuple/list인지 분기
            if isinstance(batch, dict):
                input_ids      = batch["input_ids"].to(device)
                attention_mask = batch["attention_mask"].to(device)
            else:
                # tuple/list인 경우, 첫 번째와 두 번째 요소를 사용
                input_ids      = batch[0].to(device)
                attention_mask = batch[1].to(device)

            logits = model(input_ids=input_ids,
                           attention_mask=attention_mask).logits
            probs = torch.softmax(logits, dim=-1)[:, 1]    # 협박(1) 확률
            preds = (probs >= 0.5).long()

            all_probs.extend(probs.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

    return np.array(all_preds), np.array(all_probs)


def eval_stage2(model, dataloader, device):
    model.eval()
    all_preds, all_probs = [], []
    with torch.no_grad():
        for batch in dataloader:
            if isinstance(batch, dict):
                input_ids      = batch["input_ids"].to(device)
                attention_mask = batch["attention_mask"].to(device)
            else:
                input_ids      = batch[0].to(device)
                attention_mask = batch[1].to(device)

            logits = model(input_ids=input_ids,
                           attention_mask=attention_mask).logits
            probs = torch.softmax(logits, dim=-1)
            preds = torch.argmax(probs, dim=-1)

            all_probs.extend(probs.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

    return np.array(all_preds), np.array(all_probs)

# %%
from torch.utils.data import DataLoader
from sklearn.metrics import classification_report
import torch
from tqdm import tqdm

bin_loader = DataLoader(binary_val_dataset, batch_size=32, shuffle=False)
multi_loader = DataLoader(multi_val_dataset, batch_size=32, shuffle=False)

two_stage_model.eval()
model.eval()

y_true, y_pred = [], []

with torch.no_grad():
    for b_batch, m_batch in tqdm(zip(bin_loader, multi_loader),
                                 total=len(bin_loader),
                                 desc="Val Two-Stage"):
        # Binary input & prediction
        b_input = {k: v.to(two_stage_model.device)
                   for k, v in b_batch.items()
                   if k.startswith("input_ids") or k=="attention_mask"}
        b_logits = two_stage_model(**b_input).logits
        b_preds  = torch.argmax(b_logits, dim=1)  # 0=일반, 1=위협
        b_true   = b_batch["labels"]              # 0=일반, 1=위협

        # Multi input & prediction
        m_input = {k: v.to(model.device)
                   for k, v in m_batch.items()
                   if k.startswith("input_ids") or k=="attention_mask"}
        m_logits = model(**m_input).logits         # shape (B,4)
        m_preds  = torch.argmax(m_logits, dim=1)   # 0~3
        m_true   = m_batch["labels"]               # 0~3

        # Final true & pred
        for bp, mp, bt, mt in zip(b_preds, m_preds, b_true, m_true):
            # 실제 레이블
            if bt.item() == 1:
                y_true.append(4)   # 실제 일반 → class 4
            else:
                y_true.append(mt.item())  # 실제 위협 → multiclass 0~3

            # 예측 레이블
            if bp.item() == 1:
                y_pred.append(4)   # 예측이 일반(1) → class 4
            else:
                y_pred.append(mp.item())  # 예측이 위협(0) → 0~3

# 6) classification_report 출력
#    클래스 이름은 실제 레이블 맵핑에 맞게 수정하세요.
class_names = [
    "협박 대화",
    "갈취 대화",
    "직장 내 괴롭힘 대화",
    "기타 괴롭힘 대화",
    "일반 대화"
]
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Val Two-Stage:  80%|███████▉  | 75/94 [00:21<00:05,  3.48it/s]
#               precision    recall  f1-score   support
#
#        협박 대화       0.95      0.95      0.95       442
#        갈취 대화       0.93      0.96      0.94       480
#  직장 내 괴롭힘 대화       0.97      0.98      0.97       474
#    기타 괴롭힘 대화       0.94      0.96      0.95       510
#        일반 대화       0.99      0.93      0.96       465
#
#     accuracy                           0.95      2371
#    macro avg       0.96      0.95      0.95      2371
# weighted avg       0.96      0.95      0.95      2371

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# [[418  12   3   7   2]
#  [  9 461   3   7   0]
#  [  0   3 463   8   0]
#  [  4  14   1 490   1]
#  [  8   6   8  12 431]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_predictions(y_true, y_pred, cmap="Blues")

# %%
import numpy as np
from sklearn.metrics import f1_score, precision_score, recall_score

# Stage-1 검증 예측 확률과 실제 라벨
#  y_true : (N,) – 0(비협박) / 1(협박)
#  y_prob : (N,) – ‘협박(1)’ 클래스의 softmax 확률
def sweep_threshold(y_true, y_prob, metric="f1", step=0.02):
    best_thr, best_score = 0.5, -1
    metric_fn = {
        "f1":        f1_score,
        "precision": precision_score,
        "recall":    recall_score
    }[metric]

    for thr in np.arange(0.0, 1.0 + step, step):
        y_pred = (y_prob >= thr).astype(int)
        score  = metric_fn(y_true, y_pred)
        if score > best_score:
            best_thr, best_score = thr, score
    return best_thr, best_score

val_probs, val_labels = [], []
two_stage_model.eval()
bin_loader   = DataLoader(binary_val_dataset,
                          batch_size=32,
                          shuffle=False,)
device = next(two_stage_model.parameters()).device
for batch in bin_loader:
    enc = {k: v.to(device) for k, v in batch.items() if k != "labels"}
    with torch.no_grad():
        logits = two_stage_model(**enc).logits        # (batch, 2)
    prob_threat = torch.softmax(logits, dim=1)[:, 1]  # (batch,)
    val_probs.append(prob_threat.cpu().numpy())
    val_labels.append(batch["labels"].cpu().numpy())

val_probs   = np.concatenate(val_probs)
val_labels  = np.concatenate(val_labels)

best_thr, best_f1 = sweep_threshold(val_labels, val_probs, metric="f1")
print(f"✅ Stage-1 best F1={best_f1:.4f} @ threshold={best_thr:.3f}")
# Out:
# ✅ Stage-1 best F1=0.9657 @ threshold=0.400

# %%
multi_loader = DataLoader(multi_val_dataset,
                          batch_size=32,
                          shuffle=False,)


def sweep_stage2_threshold(y_true, y_probs, reject_label=4, step=0.01):
    best_thr, best_macro_f1 = 0.0, -1
    for thr in np.arange(0.0, 1.0+step, step):
        preds = []
        for p in y_probs:
            if p.max() < thr:
                preds.append(reject_label)  # 불확실 → 특별 레이블
            else:
                preds.append(np.argmax(p))
        score = f1_score(y_true, preds, average="macro")
        if score > best_macro_f1:
            best_thr = thr
            best_macro_f1 = score
    return best_thr, best_macro_f1


s2_probs, s2_labels = [], []
model.eval()

for batch in multi_loader:
    enc = {k: v.to(model.device) for k, v in batch.items() if k != "labels"}
    with torch.no_grad():
        logits = model(**enc).logits
    probs = torch.softmax(logits, dim=1).cpu().numpy()
    s2_probs.append(probs)
    s2_labels.append(batch["labels"].cpu().numpy())

s2_probs  = np.concatenate(s2_probs, axis=0)   # (N, 4)
s2_labels = np.concatenate(s2_labels, axis=0)  # (N,)


best_thr2, best_f1_2 = sweep_stage2_threshold(s2_labels, s2_probs)
print(f"✅ Stage 2 best macro-F1 = {best_f1_2:.4f} @ threshold = {best_thr2:.3f}")
# Out:
# ✅ Stage 2 best macro-F1 = 0.9641 @ threshold = 0.000

# %%
print("y_true 분포:", Counter(y_true))
print("y_pred 분포:", Counter(y_pred))
# Out:
# y_true 분포: Counter({3: 510, 1: 480, 2: 474, 4: 465, 0: 442})
# y_pred 분포: Counter({3: 524, 1: 496, 2: 478, 0: 439, 4: 434})

# %%
import collections
from collections import Counter

# 1) 멀티클래스 검증 데이터셋에서 실제 labels 꺼내기
val_labels_list = [item["labels"].item() for item in multi_val_dataset]

# 2) 분포 출력
print(Counter(val_labels_list))
# 2) multi_val_dataset 의 길이 및 클래스 분포
for item in multi_val_dataset:
    print(item["labels"].item(), end=" ")
# Out:
# Counter({3: 643, 2: 600, 1: 585, 0: 543})
# 2 1 3 3 1 3 3 1 1 2 3 3 2 0 3 0 1 1 2 2 0 1 2 1 3 0 3 0 3 1 3 0 2 1 3 3 1 0 2 3 1 0 1 0 3 0 1 0 2 2 1 0 2 2 3 3 3 3 0 2 3 2 2 3 2 0 1 3 1 3 0 3 1 3 1 2 1 0 0 1 0 2 2 1 1 2 2 2 1 2 3 2 1 1 0 2 3 2 3 3 3 0 2 1 2 2 3 3 3 0 2 3 0 1 0 3 0 1 2 2 1 3 3 0 3 2 1 3 2 3 1 2 2 2 1 2 2 3 3 2 1 0 3 1 0 0 2 0 2 1 2 3 0 1 0 3 2 0 3 3 2 0 3 2 3 3 1 3 0 2 0 2 3 2 1 3 2 3 1 1 1 1 3 3 1 2 3 0 3 0 2 1 2 1 3 3 1 3 2 3 1 2 1 3 1 1 1 3 0 1 2 1 3 3 3 3 3 3 2 1 2 1 0 2 3 2 1 3 0 0 0 3 2 2 2 0 1 1 3 2 2 2 0 2 2 1 1 3 2 1 3 3 3 0 0 3 2 2 1 0 1 3 3 3 1 3 1 2 2 3 2 0 3 0 0 2 0 2 1 0 1 1 1 1 3 2 0 0 3 1 0 3 1 0 3 1 1 3 0 1 3 1 3 1 1 0 3 3 3 3 2 1 2 2 3 0 1 0 0 1 0 3 3 2 1 2 1 3 1 3 1 1 3 1 2 3 0 0 0 2 0 1 1 3 1 3 2 1 2 1 2 2 3 1 1 0 2 0 3 2 0 2 3 1 0 1 3 1 0 0 1 2 1 2 3 1 3 3 2 3 1 2 3 3 0 3 0 1 3 2 1 1 3 1 0 2 3 1 3 0 2 1 2 1 1 3 3 0 1 2 3 1 3 1 1 2 3 3 2 3 0 1 1 2 1 1 2 2 3 2 3 2 1 1 1 2 2 3 0 2 3 2 2 3 1 3 2 0 2 0 0 3 2 3 2 3 2 1 1 2 1 0 2 2 3 3 3 2 0 3 3 0 1 1 2 2 2 2 1 3 0 3 3 2 2 3 3 3 2 2 1 3 2 3 1 1 1 3 1 3 0 3 1 0 1 3 2 3 2 3 3 3 1 0 2 3 1 2 3 1 2 1 3 1 1 2 1 2 0 3 2 0 3 0 0 2 3 1 3 1 0 2 3 0 2 1 2 3 1 2 1 2 0 1 1 1 3 1 2 2 2 1 2 2 0 1 1 0 1 0 2 0 3 0 2 0 2 3 3 3 2 3 2 1 1 3 2 0 0 0 2 2 2 0 3 0 3 1 0 0 0 0 0 0 0 1 3 1 3 2 0 1 3 0 3 2 2 1 1 1 3 1 0 3 0 3 1 3 3 0 2 2 2 2 2 1 1 3 0 2 0 2 1 2 2 2 0 3 2 0 2 1 3 1 3 2 0 2 1 1 3 3 0 2 2 3 1 3 0 2 0 3 2 0 0 0 2 2 3 0 2 1 3 1 1 1 0 3 0 0 3 1 2 3 1 0 0 3 3 3 3 0 1 2 3 2 3 3 0 1 0 1 0 1 1 3 3 0 1 3 2 2 1 0 0 2 2 3 1 3 0 0 3 0 3 0 0 1 2 2 0 0 2 1 0 1 3 1 0 2 2 2 0 2 2 1 0 0 2 2 1 1 3 2 3 2 0 3 2 1 0 3 1 2 3 1 0 0 1 1 1 2 3 0 3 2 0 1 3 1 3 3 0 3 1 2 3 3 3 3 2 2 3 2 3 3 0 1 3 3 0 3 2 2 1 1 0 3 3 2 3 0 3 2 2 2 3 1 0 1 1 3 1 0 2 3 2 3 0 2 0 2 3 0 1 1 0 2 3 0 1 3 0 3 1 2 3 3 2 0 3 0 2 1 0 1 1 3 3 3 3 0 0 2 2 3 1 1 0 1 1 0 2 2 3 3 3 2 2 1 3 3 0 2 0 2 0 3 3 1 1 1 2 0 0 0 2 3 2 3 0 3 0 3 3 0 0 2 1 2 0 2 1 3 3 3 0 0 3 1 2 0 1 0 3 0 2 3 3 1 0 3 1 3 2 0 2 3 0 2 3 3 1 3 1 3 2 1 0 1 0 0 2 3 2 1 1 1 2 1 1 0 3 1 3 0 3 1 2 2 3 2 2 1 0 2 0 1 3 1 3 0 3 0 3 3 3 1 1 0 0 1 3 1 0 2 1 1 1 2 0 2 0 0 3 3 0 1 0 3 1 1 3 3 1 0 2 1 0 1 0 1 1 2 3 2 3 3 1 3 1 0 3 1 0 2 3 1 2 2 0 3 3 1 1 1 2 1 2 1 2 0 3 0 0 3 1 0 1 1 3 2 2 2 3 2 1 2 0 0 2 1 1 2 2 0 3 3 2 2 2 3 0 0 3 1 2 3 2 0 0 1 0 3 0 2 0 2 1 3 3 1 2 1 3 1 3 0 0 1 3 0 1 2 1 1 0 2 3 0 2 0 2 3 3 0 0 2 3 1 2 1 3 1 3 2 3 3 2 2 1 1 3 3 2 1 0 1 1 3 2 3 1 2 1 1 3 0 1 1 1 1 0 2 2 1 3 3 3 3 1 1 2 2 2 2 2 3 2 1 3 1 0 2 3 3 2 1 3 0 0 1 0 3 3 2 2 1 2 3 3 0 3 2 3 1 1 1 2 2 3 2 1 3 1 1 0 1 3 3 2 2 0 2 2 2 2 3 2 0 2 0 3 3 2 3 2 3 0 2 0 1 0 2 3 0 1 0 3 0 1 0 1 3 3 3 3 1 2 3 1 3 0 0 0 2 1 2 0 2 0 2 2 2 0 1 3 1 2 2 1 1 0 1 1 2 3 2 2 1 1 0 0 3 3 1 0 3 3 2 1 2 2 0 0 0 1 2 3 2 0 1 1 0 1 1 3 3 1 3 3 1 3 0 2 3 0 2 0 0 2 0 1 1 2 3 1 0 0 2 0 2 1 2 3 0 2 2 2 3 1 1 1 3 3 0 3 2 1 2 0 0 1 0 3 3 2 1 1 3 3 1 0 1 0 2 3 2 2 1 0 3 3 3 3 1 3 0 3 3 0 2 3 1 2 1 1 2 2 3 2 1 0 0 0 0 2 0 2 2 3 0 0 0 1 1 2 3 3 3 2 2 0 1 0 3 3 0 3 3 2 0 1 2 2 2 0 3 2 3 2 0 0 2 2 0 0 2 1 2 2 3 1 3 1 2 2 1 1 2 2 3 2 3 0 2 2 0 2 0 2 0 3 2 1 3 2 3 2 2 3 2 2 3 3 3 0 2 3 2 1 0 0 2 2 1 0 1 2 3 3 0 2 0 1 2 1 2 2 0 3 2 0 3 0 2 2 3 3 2 2 3 3 0 3 0 1 3 3 2 0 2 3 2 3 1 1 0 2 0 2 1 2 1 0 3 0 2 3 0 1 0 1 0 0 3 3 2 2 0 0 3 0 2 0 0 1 0 0 0 0 2 3 1 1 0 0 1 2 3 1 1 2 3 3 3 0 3 0 3 3 1 3 3 0 3 0 1 1 2 2 1 2 2 2 2 0 2 1 3 1 0 2 1 2 0 0 3 0 0 2 1 2 3 1 2 0 2 1 3 0 1 2 0 0 3 1 3 3 1 0 1 1 1 3 1 3 2 2 0 1 0 2 2 2 3 0 1 2 0 3 0 2 0 0 3 2 1 3 2 1 3 1 1 1 2 2 3 2 0 3 1 1 2 1 3 0 3 3 2 2 1 3 3 1 0 3 1 1 2 0 0 0 3 0 3 0 2 1 0 3 3 2 3 3 1 0 2 1 3 3 2 1 3 3 1 1 3 2 3 0 2 2 3 2 2 3 0 1 3 1 0 0 2 1 2 0 3 1 0 3 0 0 0 2 1 2 0 2 0 1 1 1 0 3 1 2 0 2 3 0 1 3 3 2 1 0 1 2 3 1 3 1 0 0 1 1 0 1 0 3 2 1 2 1 0 1 0 3 3 3 1 1 0 3 0 0 2 3 2 1 0 3 2 2 0 0 1 0 1 2 3 1 3 2 1 0 2 3 0 3 0 2 1 2 0 1 1 1 1 3 2 2 2 2 3 1 2 1 0 0 1 2 2 0 3 2 0 0 0 2 2 3 3 1 0 2 3 1 0 2 1 3 2 1 3 3 2 1 1 3 2 1 2 3 3 0 1 2 1 2 3 1 0 2 2 3 1 1 2 0 1 1 1 2 2 1 0 2 1 1 1 2 3 1 2 2 0 0 3 2 2 0 3 3 2 0 3 3 3 1 1 1 3 3 1 2 0 3 1 2 2 0 2 1 1 0 0 0 2 0 0 3 0 1 2 3 3 1 3 1 0 2 0 2 0 3 3 1 1 3 1 3 1 2 3 2 1 1 0 2 2 2 0 0 0 2 1 3 1  ...

# %% [markdown]
# ## 테스트

# %%
from tqdm import tqdm

batch_size = 32  # 또는 16으로 줄일 수 있음
two_stage_model.eval()
model.eval()
final_preds = []
test_df = pd.read_csv("./Aiffel_DLThon/data/original_data/test.csv")
test_texts = test_df["text"].tolist()

for i in tqdm(range(0, len(test_texts), batch_size), desc="Stage 1 + Stage 2 추론"):
    batch_texts = test_texts[i:i + batch_size]

    # 인코딩 + device 이동
    batch_encodings = tokenizer(
        batch_texts,
        truncation=True,
        padding=True,
        max_length=400,
        return_tensors="pt"
    )
    batch_encodings = {k: v.to(two_stage_model.device) for k, v in batch_encodings.items()}

    with torch.no_grad():
        # Stage 1 예측
        s1_logits = two_stage_model(**batch_encodings).logits
        s1_preds = torch.argmax(s1_logits, dim=1)

        for j, s1 in enumerate(s1_preds):
            if s1 == 1:
                final_preds.append(4)
            else:
                # Stage 2 예측
                single_input = {
                    key: val[j].unsqueeze(0).to(model.device)
                    for key, val in batch_encodings.items()
                }
                with torch.no_grad():
                    s2_logits = model(**single_input).logits
                    s2_pred = torch.argmax(s2_logits, dim=1).item()
                    final_preds.append(s2_pred)
# Out:
# Stage 1 + Stage 2 추론: 100%|██████████| 16/16 [00:05<00:00,  3.18it/s]

# %%
from collections import Counter

print("📊 예측 결과 분포:")
print(Counter(final_preds))
# Out:
# 📊 예측 결과 분포:
# Counter({4: 126, 1: 104, 3: 101, 2: 95, 0: 74})

# %%
import torch
import torch.nn.functional as F
import pandas as pd
from tqdm import tqdm

# ─── 하이퍼파라미터 ──────────────────────────────────────────────────────────────
BATCH_SIZE          = 32
STAGE1_THRESHOLD    = 0.40        # τ = 0.400 (best F1 0.9657)

# ─── 모델 평가 모드 ─────────────────────────────────────────────────────────────
two_stage_model.eval()
model.eval()

final_preds = []
test_df     = pd.read_csv("./Aiffel_DLThon/data/original_data/test.csv")
test_texts  = test_df["text"].tolist()

for i in tqdm(range(0, len(test_texts), BATCH_SIZE), desc="Stage-1 + Stage-2 추론"):
    batch_texts = test_texts[i : i + BATCH_SIZE]

    # ── 토큰화 & 디바이스 이동 ────────────────────────────────────────────────
    batch_enc = tokenizer(
        batch_texts,
        truncation=True,
        padding=True,
        max_length=400,
        return_tensors="pt"
    )
    batch_enc = {k: v.to(two_stage_model.device) for k, v in batch_enc.items()}

    with torch.no_grad():
        # ── Stage-1: 유해 확률 계산 ───────────────────────────────────────────
        s1_logits       = two_stage_model(**batch_enc).logits          # (B,2)
        probs_harmful   = F.softmax(s1_logits, dim=1)[:, 0]            # 클래스 0 = 유해
        harm_mask       = probs_harmful >= STAGE1_THRESHOLD            # True → Stage-2 대상

        # ── 기본 예측 = 전부 일반(4)로 초기화 ────────────────────────────────
        batch_preds = torch.full_like(probs_harmful, fill_value=4, dtype=torch.long)

        if harm_mask.any():
            # ── Stage-2: 멀티클래스(0~3) 추론 ──────────────────────────────
            harm_inputs = {k: v[harm_mask] for k, v in batch_enc.items()}
            s2_logits   = model(**harm_inputs).logits                   # (H,4)
            s2_preds    = torch.argmax(s2_logits, dim=1)                # 0~3

            # ── 유해 위치에 Stage-2 결과 삽입 ───────────────────────────────
            batch_preds[harm_mask] = s2_preds

    final_preds.extend(batch_preds.tolist())

# final_preds 에 최종 0~4 라벨 완성
# Out:
# Stage-1 + Stage-2 추론: 100%|██████████| 16/16 [00:02<00:00,  5.37it/s]

# %%
from collections import Counter

print("📊 예측 결과 분포:")
print(Counter(final_preds))
# Out:
# 📊 예측 결과 분포:
# Counter({3: 115, 1: 109, 2: 105, 4: 92, 0: 79})

# %%
id_to_label = {
    0: "협박 대화",
    1: "갈취 대화",
    2: "직장 내 괴롭힘 대화",
    3: "기타 괴롭힘 대화",
    4: "일반 대화"
}
for i in range(500):
    print(f"문장: {test_texts[i]}")
    print(f"예측 라벨: {id_to_label[final_preds[i]]}")
    print("-" * 30)
# Out:
# 문장: 아가씨 담배한갑주소 네 4500원입니다 어 네 지갑어디갔지 에이 버스에서 잃어버렸나보네 그럼 취소할까요 아가씨 내 여기단골이니 담에 갖다줄께 저도 알바생이라 외상안됩니다 아따 누가 떼먹는다고 그러나 갖다준다고 안됩니다 자꾸이럼 경찰불러요 아가씨 담배피는교 그건 왜 물으세요 그람 아가씨 담배 한대만 빌립시다 내 지금 지갑도 잃어버리고 기분이 그래서 그러니 여기요  아따 주는김에 한개더 주면 되겠네
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 우리팀에서 다른팀으로 갈 사람 없나? 그럼 영지씨가 가는건 어때?  네? 제가요? 그렇지? 2달만 파견 잘 갔다오면 승진이야. 네? 저는 별로 가고 싶지 않습니다. 여기 있는 모든사람도 가기 싫어해. 그러니까 막내인 영지씨가 가는게 맞지 정말 죄송합니다. 저는 못갑니다. 장난해? 모두를 위해 영지씨가 희생하는게 싫어? 네. 부당한 방법으로 가는 것 같습니다. 영지씨 안가면 회사생활 오래 못할 것 같은데 그래도 안갈거야? 안가면 지옥일텐데. 그래도 이 방법은 아닌 것 같습니다. 죄송합니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 너 오늘 그게 뭐야 네 제가 뭘 잘못했나요.? 제대로 좀 하지 네 똑바로 좀 하지 행실이 맘에 안들어 네 실천할께요 옆에 동기들 좀 본받으란 말야 어? 네 알겠습니다 그래 똑바로해 노럭할께요
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 이거 들어바 와 이 노래 진짜 좋다 그치 요즘 이 것만 들어 진짜 너무 좋다 내가 요즘 듣는 것도 들어봐 음 난 좀 별론데 좋을 줄 알았는데 아쉽네 내 취향은 아닌 듯 배고프다 밥이나 먹으러 가자 그래
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 아무튼 앞으로 니가 내 와이파이야. .응 와이파이 온. 켰어. 반말? 주인님이라고도 말해야지? .켰습니다. 주인님. 오냐. 앞으로도 잘부탁한다 와이파이. 넵. 이렇게만 해? 알겠지? 응.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 그러니까 빨리 말해. 선생님 제발 살려주십시오.  비밀번호 틀릴 때마다 손톱 하나씩 뺀찌로 뽑는다.  선생님 저도 정말 모릅니다.  하나 엄지 손톱 뽑는다.  으악! 잘못했습니다. 그런데 진짜 모릅니다.  둘 이번에는 두 번째 손톱 뽑는다.  으악! 진짜 저는 모릅니다.  셋 중지를 아주 분질러 줄까?  으아아 살려주십시오.  아니다 아주 손가락을 다 잘라놔야겠다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 그 사람 누구냐?  누구말하는거야?  다 알면서 모른척 하지마. 둘다 쏴버리기 전에.  아니 정말 왜이래? 누굴말하는거냐고.  어제 밤에 전화온 그새끼 말이야. 번호 알아놨으니까 죽이기 전에 다 불어라.  아! 김대리? 그냥 회사사람이야. 오해하지마  회사사람이란 인간이 그 오밤중에 사랑한다고 보고싶다고 하냐? 진짜 다 죽여버리기 전에 솔직히 말해라.  정말 아니야. 왜 이래? 오해라니까.  안되겠다. 그럼 지난주 점심시간에 모텔은 왜갔냐?  어??? 그냥 피곤해서 쉬러간거야. 오해야.  안되겠다. 그냥 불지르고 다 끝내자.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 야 저기야 닭꼬치 트럭왔다 응 그러네 그치? 너도 먹고 싶지? 어?나도? 그래 너 세상에 닭꼬치 싫어하는 사람이 어딨어 그렇긴한데 배부른데 그래? 그럼 나만 먹고 올게 응. 뭐해?? 뭘? 돈줘야 먹고오지 내가 돈이 어딨냐 할머니랑 둘이 사는데? 응.?? 어 알겠어 얼른줘 미적거리지말고
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 안경 안쓰고 키작고통통해보이는 분이었는데 다안경안씀  쌍꺼풀없었던것같고 아 단발인가 키작은사람들은 검정색 머리인데 없어가지고 단발인가 단발은 아니었던것같은데 막 나같은 장발도아님 모르겟다 중단발  영업직분중 하나인가 그럴수도
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야 너 2학년 김민석 맞지? 네 맞는데요. 혹시 누구신가요? 내가 누군지 궁금하면 학교 뒤쪽으로 내려와. 2분 준다. 네 지금 내려가겠습니다. 야 니가 김민석이냐? 돈 있어? 돈 없는데요. 야 쟤 몸뒤져. 너 천 원 나올 때마다 얼차려 10분이다. 야 여기 얘 지갑 있는데? 오 지갑만 봐도 돈 많게 생겼네. 열어봐봐 오 12만원 있네? 얼차려가 몇 분이야? 야 이 돈 주면 얼차려 없애줄게. 그거 오늘 저 문제집 사려고 가져온 돈이라. 혹시 내일 드리면 안될까요? 야 니 얼차려 받고 싶냐? 그렇게 내일 주고 싶으면 오늘 이 돈도 우리 주고 내일도 돈 가져다 주면 돼. 뭐가 어려워. 네 알겠습니다. 그 12만원 가져게세요. 말 잘 듣네. 아주 예뻐 내일도 돈 가져와라. 안 그러면 알지? 내일도 같은 시간에 여기로 와.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 예전에 네가 나한테 했던 일 기억하지? 너도 당해봐 예전 일이라면 내가 사과할게. 제발 살려줘. 과만 하면 다야? 그 때 네가 칼로 내 얼굴에 흉터낸 거 아직도 남아있어 그 때는 어렸을 때야. 이제는 나도 변했다고! 이렇게 용서를 빌게 아니. 그런 깨달음은 그 때 했었어야지. 빈다고 변하는 건 없어 제발 이러지마. 나에겐 먹여 살려야 할 가족도 있어. 이제와서 이렇게 빌어봤자 그 때의 내 상처는 사라지지 않아. 네가 잘못한 것들도. 원하는 게 뭐야? 날 죽이는 거 말고 원하는 건 뭐든지 할게. 내가 원하는 건 네가 나와 같은 상처를 입고 죽는 것 뿐이야 그거 말고 다른 건 뭐든지 할게. 제발 살려줘. 그래? 그렇다면 네 아들의 목숨을 내놔. 그럼 넌 살려주지. 네가 사람이야? 어떻게 그럴 수 있어? 너는 그 때 사람이었니?  난 그 때 아직 어렸어. 내가 너무 철이 없었어.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 아 취업하고 싶은데 누가 나 좀 안 데려가냐 아 그니까 나도 취업하고싶다 코로나때문에 미친거같아 진짜 너무 안 뽑아 그니까 동기들중에 취업한애들 아는애들 있어 뭐 지한이 삼성갔다그러고 그 여자애 이름 기억 안나는데 카카오 들어갔다던데 와 씨발 다들 잘갔네 부럽다 그니까 그냥 그럭저럭 학교생활 했는데 쫌 더 열씸히 할껄 아 난 나름 열심히해서 학점도 좋고한데 왜 안되냐 맨날 면접가서 떨어지니까 더 힘드네 너는 면접연습만 하면 될거같은데 나는 서류에서 광탈이야 아 그러게 면접연습 해야되는데 타고난게 말을 잘 못하는데 어쩌라는거야 그니까 공부도 잘해야되고 말도잘해야 취업되는 더러운세상 에휴 부모님한테도 죄송하고 얼른 취업해야되는데
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 김비서 지금 우리애 학교가서 집에다가 좀 데려다 주세요 사장님 그런 개인적인 일은 제가 도와드릴수 없습니다 머라고? 자네는 비서아닌가? 내 개인적인 일이 바로 회사의 공적인일이야 죄송합니다. 아무리 그래도 그건 아닌거 같습니다 김비서 지금 상사의 지시에 항명하는건가 죄송합니다. 부당한 지시에는 따를 수 없습니다 김비서 월급주는사람이 바로 나야. 월급받기 싫은가? 죄송합니다. 개인적인 용무를 지시하는것은 아닌것 같습니다 머라고?!! 꼴도 보기싫으니깐 당장나가 죄송합니다. 나가보겠습니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 과장님 오늘 부장님 기분이 안 좋으신것 같네요 오늘 프레젠테이션 있었는데 사장님한테 엄청 까였나봐 아 그래요 오늘 조심해야겠네요 엉 알아서들 조심해 완전 저기압인거 같아 네 근데 오늘 저희 주간 회의 있어서 어차피 부딪힐거 같은데 그때까지 부장님 기분이 풀리길 바래야지 뭐 아 오늘 잘못하면 엄청 혼날꺼 같은데 그니까 준비 잘해 네 알겠습니다
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야 김대리 니 주말에 뭐했냐? 아 그냥 쉬었습니다. 아 그냥 쉬어? 말 좀 짧다이 어. 집에서 그냥 친구랑 배달 시켜먹고 쉬어서 그랬습니다 왜그러세요 과장님 그냥 쉬었다는데 아니 내가 물어보지도 못해? 뭐 내가 여친이랑 있었는지 물어본것도 아니고 안그래 김대리? 여친이랑 있었어? 아. 아뇨 그냥 친구입니다. 어 반응 뭐야 여친이랑 있었나본데 아닙니다 그냥 대학 동기였습니다. 그게 아닌 것 같은데 이새끼 뭐했냐 여친이랑?
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 후기 내리세요. 안그러면 고소합니다.  지금 협박하시는 건가요?  협박 아니고 알려주는 겁니다. 당장 내리세요.  제 후기는 사실만을 적었고 잘못된 부분이 없는데요?  사실적시 명예훼손 모르세요? 그리고 업무방해도 포함입니다.  공익목적으로 적은 후기는 무죄인걸로 알고 있는데요  마음대로 생각하세요 무죄가 나오든 어쨌든 고소할거니까요  제 후기의 어떤점이 잘못됐다는거죠?  그냥 돈받고 합의하시라고요 왜 굳이 인터넷에 올리고 그러세요  음식에서 쥐가 나왔는데 그걸 다른 사람들이 알게 한게 잘못인가요?  네 잘못 맞아요 손님때문에 매출 떨어지면 어쩔거냐고요.  애초에 저는 사실을 고발했을뿐 진작 대처를 잘하셨으면 됐잖아요.  아 죄송하다고요 빨리 내리라고요!! 가게 망하게 생겼는데 이거 잘못되면 직접 찾아갑니다. 주소 저한테 있고요 저 무서운거 없어요. 님 죽일수도 있으니까 그만하세요.  진짜 적반하장도 유분수네. 프로그램에 제보하겠습니다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 응응 점점 깊이 깊이 이야기가 들어갈수록 응응 맞아 마음이 좀 그럴수 잇을것같은데 그리고 감사한일 많이 주셨으니깐 전혀 안그러고 좋아지고 잇다는게 너무 신기하네 하나님한테 더 잘해야지 네 마음이 그래지는게 뭐야 무슨 뜻이지 나 아직 바본가 음뭔가 새로운 음 오늘 같이 조금 부끄러운 모습들이나 말하기 힘든 이야기들을 응응 털어놓았는데도 상대방 마음이 실망감이나 충격 이런 느낌이 아니라 아아아 더더 좋아진다는것이 대충 무슨 느낌인지 알겠다
#
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 박보영 오늘 학원 갔다왔어 아니 오늘 못갔어 왜 아니 친구랑 놀다가 시간을 못봤어 자랑이냐 깜빡했어 저녁은 뭐야 너는 저녁 없어 학원 다녀왔어야지 엄마 미안해 나 배고파 다음부터 꼭 가 알았어 나 손 씻고올게 깨끗하게 씻고와
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 좋은말 할때 내돈갚아. 내가 왜 그래야 하지? 너가 여기 재개발 된다며. 너믿고 내 전재산을 투자했다고 꼼꼼히 확인안한 너 잘못이지 나도 그땐 맹지인지 몰랐다고 웃기지마! 너랑 공인중개사랑 짜고 나 속인거 모를줄 알아? 증거있으면 대보라고 내가 너 칼로 죽이고 교도소가고말거야 어이구 무서워라 너뿐아니라 너 가족까지 다 죽여버릴거야 어디 한번 해보시지.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 저기요. 혹시 번호 좀 알려주실 수 있나요? 네? 아 죄송해요. 저 남자친구 있어서요 . 그게 뭐가 중요한데요? 네? 그게 뭐가 중요하냐뇨. 아니 남자 꼬실라고 그렇게 입고 나오신 거 아는데 그만 튕기시고 그냥 좀 알려주세요. 참. 어이가 없네요. 제가 남자를 꼬시려고 입고 나왔다뇨. 무례하시네요. 어이가 없는 건 그 쪽아니에요? 딱 봐도 남자하나 잡고 놀고 싶어서 안달난 싸구려같은 여자 옷 입고와놓고  저기요. 그 쪽같은 싸구려 남자랑 저도 더 이상 대화하고 싶지가 않은데요. 그만 가주시죠. 겁나게 비싸게 구네. 하루 놀고 버림 당하게 생긴 년이 뭘 믿고 저러나. 야 너같은 애들은 딱 한 번만 놀고 버리기 좋은 타입이야 알아? 자꾸 그러시면 성희롱으로 신고 할거니까 그렇게 아세요. 사실을 말해도 신고를 당하나? 웃기는 년이네. 저거
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 너 내가 돈 갚으라고 했지!!!!! 안갚으면 죽여버릴거야 어떻게 죽일건데 내가 칼로 너를 찔러 죽여버릴거야 언재까지 갚으면 되는데? 내일 까지 당장 갚아 내일까지는 못 갚아 그럼 너 칼로 찍어 죽일게 안돼 죽이지마 그럼 너 딸을 죽일게
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 야 얘는 왤케 돼지냐? 그만 좀 먹어라 놀리지마 너 라면 한번에 5개 끓어먹지? 아니야 그런 말 하지마 아니긴 뭐가 아니야 너 먹방 해봐라 조회수 잘 나올거 같네 하지말라고 와 내가 너였으면 자살했다 그만둬 제발 어휴 그래도 살겠다고 쳐먹는거 봐라 그만하라고
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 너 왜 그렇게 생겼어?  내가 뭘  너 정말 토나오게 생겼어 알아?  너도 잘생긴 거 아니거든?  너보단 백배 낫지 너처럼 생기면 어떤 기분이냐? 이 세상 살아갈 수는 있는거냐?  그만해  뭘 그만해 현실을 자각시켜야 너가 성형을 하든 뭘 하든 할 거아냐  내 얼굴이고 내가 알아서 할 거야  너 얼굴을 계속 대면해야하는 내가 괴로워서 그래  그만하라고!  얼굴도 못생긴데 성질도 드럽네
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 너 이리로 와서 돈 좀 내놔라 아니 당신 미쳤나요? 나 참 너야 말로 목숨이 여러 개인줄 아는 미친놈이세요? 날 어떻게 할거죠? 이 아줌마 눈치가 지지리도 없으시네 돈 안주면 큰일날거야. 자 여기요 얼시구 돈을 일부만 주셨네 장난치나 그럼 얼마나 줘야 하는데 다 줘야지 어딜 장난치고 있어
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 나. 이번에도 돈이 좀 필요한데. 우리사이에 차용증이나 돈 갚겠다는 각서는 필요없지? 자기야. 저번에도 돈 필요하다면서 5백만원 가져갔잖아 나 빨리 백수탈출 해야지. 원래 강남 학원이 비싸. 그래도.무슨 학원비가 5백만원이나. 이번엔 또 뭔데? 집이랑 학원이랑 너무 멀어서 근처 오피스텔이나 원룸 좀 알아보려고. 뭐어!? 그건 몇백이 아니라 몇천만원이 필요한거 아니야?  자기야!! 나 사랑한다면서 그것도 못해줘? 그래도 이건 너무하잖아. 백수가 돈이 어딨어? 오빠 저번에 상여금 많이 받았잖아. 그거 좀 줘. 저번에 말한 그친구 사정이 안좋아서 걔한테 좀 빌려주기로 했어 .무튼 이번달엔 지출할곳이 좀 많아. 내가 오빠 반찬도 갖다주고 함께 한 시간이 얼마인데. 나야 아니면 그 친구야?
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 김인턴 지금 회의 들어가야 되니까 빨리 이거 좀 해와. 아 저 지금 퇴근하려고 했는데요 야 김인턴. 너 정규직 되기 싫어? 아뇨 되고 싶습니다 근데 행동거지가 그따구야? 죄송합니다 너 전환되는거 내 입김 쎈거 몰라서 지금 말대꾸야? 빨리 해와 알았어? 알겠습니다 너 한 번만 더 그래봐 진짜. 죄송합니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 저기요 돈을 빌리셨음 갚으셔야죠 뭐래 상황극 좀 그만해 재미없었어 엉 재미없어 센치한놈 하여튼 상황극 할거면 재밌게나 하던가 연기도 더럽게 못해요 디스 장난아니네 내가 배우냐 연기 잘하게 그니까 쫌 하지를 말아라 알았어 알았어
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 와 강아지 너무 이쁘다 감사합니다 몇 살이에요 올해로 네 살이에요 와 애기네요 애기 포메인가여 네 맞아요 잘 아시네요 그럼요 저희 집도 개 키우거든요 오오 대박 강아지 키우는 사람들은 모두 강아지를 좋아하죠 맞아여 정말 그런 것 같아요
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 김대리 이따구로 할꺼야?  네?  글씨가 왜 이모양이야?  죄송합니다  김대리 학교 안나왔어?   죄송합니다 똑바로 쓰겠습니다  그럼 이건 똑바로 안쓴거야? 정신 안차려?  정신차리겠습니다 집안사정이랑 일이랑 별개야 이따구로 일하꺼여? 네 죄송합니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 선생님도 환자타는 징크스 있겠네요 난 그런거 없어 특이하네요 다들 하나씩 있으시던데 굳이 있다면 족보에도 나와있는 전통적인 징크스 그정도 그게 뭔데요 후배가 산 과자나 음식을 하나라도 먹는다면 어떻게 되는데요 하늘에서 환자가 우수수수수 내려 아 큰일났다 왜왜 내가 지금 먹는 아이스크림 누가 산거야 제 제가 빨리 계좌번호 불러 빨리 돈 보내줄게
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 너 이 영상 유포되면 어떻게 될거 같아? 미안. 지워줘. 그건 안 되지. 내가 뭐든 할게. 그래? 그러면 합의금으로 1억만 줘. 뭐? 나한테 그런 큰 돈이 어디있어? 그럼 인터넷에 올리지 뭐. 아니야. 내가 마련해 볼게. 시간를 조금 줘. 그래 1달이야. 1달 안에 1억 입금해. 응.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 서울 전체를 10분 뒤에 폭파하겠다. 너 대체 원하는게 뭐야? 왜 이런짓을 하는거냐고 돈 300억과 내가 안전하게 탈출할 수 있는 제트보트를 10분내로 준비해라 조금이라도 늦으면 시민들의 안전은 보장 못한다. 알았어 일단 진정해 다 준비해준다고 근데 10분은 너무 촉박하잖아 그래? 이러면 가능하려나? 아니 왜 갑자기 반포대교를 박살내는거야!!! 제발 알겠어 금방 준비할게 조금만 기다려 딱 10분이야 그 이상은 없어 잘 생각해 지금부터 딱 10분내로 준비해줄게 제발 서울만은 안돼!!! 참고로 서울이 끝이라고 생각하지마 대한민국 전체가 될 수도 있으니까 제발. 제발 그만해 이러다 다죽어
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 오늘 너 미팅아니야 맞아 망했어 오늘 왜 뭐가 문제야 나 살이 너무 많이 쪘나봐 옷이 다 이상해 괜찮은데 뭐가 그래 어디서 만나냐 오늘 강남역에서 보기로했어 누구랑 그 너 친구 민영이랑 이대이야 맞아 나 괜찮지 이옷 응 이쁘네 재밌게 놀다와라 알았어 나 오늘 늦을수도 있다 먼저 자
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 저 며칠전에 대리 운전 했던 길동 기사입니다. 아 네네 무슨 일로 전화하셨죠? 제가 돈을 모자르게 드렸나요? 아니 그게 아니고. 손님 내려드리고 내여보라고 저장되어 있는 분께 전화 걸었더니 와이프라 저장 되어 있는 사람한테 전화를 걸라고 하더군요 네. 근데요? 뭐가 문제인가요? 에이 같은 선수끼리 왜 그러실까? 둘이 다른 사람 이잖아요 제가 증거 다 확보 했어요 어쩌피 번호도 모르면서 어떻게 알려주게요 그냥 끊으세요 01012345678 이거 지금 부인분 번호 맞죠? 여기로 증거 보내도 되는거죠? 상관없어 하시는거 같은데. 아. 아니 뭐 어떻게 하면 되는데요. 아내한테 말하면 안돼요. 저 이제 곧 결혼 할 사람이란 말이에요. 그럼 내 계좌로 120만원만 보내 그럼 못 봤던 일로 해줄테니까 120이요.??? 당장 120만원을 어디서 구해요. 저 결혼식에 돈 다들었단 말이에요. 그럼 포기하던가 뭐 재산은 아내가 다 가져가겠네. 결혼도 안 하고 헤어진 사이인가? 아내 될 사람이 불쌍하다. 그 날만 엄청 기다렸을텐데 아. 지금 보내드릴게요. 그대신 꼭 지워주셔야 합니다. 이건 저희둘의 약속입니다 꼭 지우세요.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 그만 건드리세요 뭐? 반복하시잖아요 뭐를 진짜 모르세요? 몰라 불쾌하네요 이 새끼좀봐라 그만요 제발 넌 좀 쳐 맞자 제발요
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 어이 코털 왜 왜? 아놔됐고 너 매점가서 곰보빵 두개에 콜라하나 사와라 나 돈없어 돈없어? 그럼 내가 돈줄께 어 여기 1000원 줄테니까 빵두개 콜라하나 사고 거스름돈 거슬러와라 야 택도없어 야 뒤질래? 쌔벼서라도 갖고와 색키야 야
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 저기요 번호 주세요 네? 죄송합니다. 머라고요? 내가 누군줄 알아요? 아. 네 당연히 알죠 근데 왜 번호 안줘요? 아니요. 저는 남자친구있어요 남자친구 있는거랑 번호주는거랑 무슨 상관인데 빨리 번호 찍어봐요 죄송합니다. 개인정보잖아요. 그래도 빨리 줘봐 튕기지말고 여기 계속 번호달라 그래요 살려주세요.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 다 손들어! 지금부터 손을 내리면 이 직원은 죽는거야 저한테 왜 그러세요 빨리 돈다발 이 가방에 담아. 빨리! 담지 않으면 넌 총에 맞는거야 저 비밀번호 몰라요! 5초 준다 5 4 3 2 1 정말 모른다니깐요. 너가 돈을 담는게 빠를까? 얘가 죽는게 빠를까? 죄송합니다. 얼른 열게요. 진작에 그럴 것이지. 더 빠르게 더 빠르게! 네 제발 쏘지마세요.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 다시 못걸어다니게 만들어줄까? 어? 이러지마세요. 난 분명히 시간을 줬다. 제가 할 수 없는 일이에요. 그래? 그러면 어쩔 수 없네. 이제 못걷는거지 뭐. 왜이러세요. 빨리빨리 시키는 대로 했어야지.  어떻게 시간을 좀 더 주세요. 다음번에도 안되어 있으면 못걷는거에서 안끝날 줄 알아. 알겠어? .네 어떻게든 해보겠습니다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 핸드폰 빌려 주실 수 있어요?  네? 급하시면 1통화 하세요  감사합니다  어?  제가 깨트린거 아니에요  니가 빌려달라고 하고 니가 깨트렸잖아  아니라구요 님이 깨트렸잖아요  이거 완전 사기꾼이네. 당장 액정 값 내놔  사기꾼은 당신이지. 한두번 해본 솜씨가 아니구만  이 새끼야 니 핸드폰이라도 가져간다.  뭐하는거야? 당신! 돌려줘  꺼져 이제부터 이거 내 꺼야.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 이 영감탱이 자네가 우리 할망구랑 바람났지? 노망났나 이게 무슨소리야 왜 젊었을때 서로 첫사랑이라 아직도 못잊었나? 무슨 말도 안되는 소리야 옛날일이네 다 내가 암만 생각해도 이 시골 촌구석으로 이사온 자네의 저의가 심히 궁금하네 그건 고향이라 돌아온거네 고향에 옛사랑까지 있어 돌아온거 아닌가? 내가 자네랑 우리 망구 똑똑히 지켜보고 있네 혹시라도 헛짓거리 하다 걸리면 다 죽는거여 자네도 죽고 나도 죽고 우리 망구도 죽고 이 마을도 다 불태워서 다 죽여버릴거여 그런거 아니니 제발 진정하게 뒤가 구린새끼가 아주그냥 입만 열면 거짓부렁이네 그런거 아니네 제발
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 야 거기 이 골목 지나려면 통행비 5만원이다. 그딴게 어딨어요? 오늘부터다 시발롬아. 저 돈 없어요. 돈 뒤져서 나오면 10원당 한대다 오케이? 아 시발 통행비가 고속도로도 아니고 왜 있어요 미친놈아. 뒤질래 어디서 욕이야. 그럼 본인 지나가주는 대가로 헌금 5만원 걷어간다 십새야 미친놈이네 너도다 시발
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 수진씨 목마른데 1층 커피숍에서 나 커피 한 잔 사다 줄 수 있어? 돈은 내가 줄게. 이따 줄테니까 일단 다녀와.  네 알겠습니다.  아 잘 사왔네 고마워. 내일도 나 커피 한 잔 사다 줄 수 있어? 돈은 한 번에 줄게.  네? 내일 주신다고요? 네. 알겠습니다. 수진씨 나 오늘 커피 부탁해.  부장님 벌써 한 달째인데 돈은 언제 주시나요?  아 벌써 그렇게 되었나? 다음달에 줄게.  .  수진씨 왜그래. 내가 안준다는 것도 아니고. 잘하다가 왜그래. 이래서 젊은 것들은 안된다니까  아닙니다. 죄송합니다.  그래 정신 똑바로 챙겨야지? 그래야 일도 잘하지.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 저희 이 집에서 나가게 하려면 위로금이라도 주시고 나가게 하세요. 저번에 원래 집 값이랑 조금의 보상금 까지 드리기로 계약하셨잖아요. 근데 며칠사이에 집 값이 더 올랐어. 집 값 달라고 안 할테니가 위로금이라도 달라니까? 계약서에 명시 되어 있고 마음대로 바꾸실 수 없어요. 빨리 나가세요. 절대 안 나갈거야 돈 주기 전까지. 마음대로 내쫓으면 폭력으로 신고할거야. 그럼 도대체 얼마만큼에 돈을 더 드려야 하는건가요? 집 값오른거에 5분의 1인 100만원만 더 얹어줘. 100만원 더 받고 나가는거 이 집밖에 없어요. 원래 의무적으로 비워줘야 하시는거예요 알아요? 그래서 뭐 어떡하라고 줄거야 안 줄거야 빨리 결정해 시간 없으니까 내일 안으로 돈 드릴테니 꼭 퇴거 하십시오.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 와 너 요즘 태양의 후예 보냐 아 당연하지 요즘 누가 안보냐 송준기 존잘 송혜교 존예 진짜 그니까 군복 너무 멋있더라 진짜로 저런 군인들 있나 있으면 소개좀 미쳤냐 내가 만나지 와 주위에 전역하는 애들한테 연락해봐야겠따 군인 너무 멋있다 아 그니까 관심도 없었는데 저거 보니까 관심생기더라 미쳤나봐 진짜 나 입대할까도 고민했잖아 미쳤나봐 진짜 개웃기네
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 홍시씨 오늘 데이트 하나 봐? 엄청 힘줬네? 네? 아니 저 평상시랑 똑같은데. 그렇게 외모신경 쓰는 거 반만이라도 일에 신경 좀 써 회사 놀러왔어? 죄송합니다 열심히 하겠습니다 열심히? 열심 필요없어 잘 해야지 홍시씨 머리가 좀 안 좋나? 네? 무슨 말씀이신지 그 왜 있잖아 머리가 안 좋으면 몸이 고생한다고 홍시씨 보면 딱 그 말이 생각나서 내 마음이 아파 잘하겠습니다 홍시씨 지금 나랑 말장난 해? 면접은 어떻게 붙은 거야 빽이라도 있는거야 뭐야 팀장님 말이 너무 심하세요
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 차에서 당장 내려 내가 왜 내려? 당신이 뭔데 이래라 저래라야? 그럼 왜 계속 내 차 뒤에서 빵빵거렸는데? 당신이 답답하게 운전하니까 그랬지 노란불에 멈추는 게 당연한 거 아니야? 바빠죽겠는데 에휴 이 사람아 당신만 바빠? 나도 바빠 그럼 갈 길 그냥 가시라고요 됐고 당장 내려서 사과해 아님 너 오늘 집에 못 가 당장 차 안 빼? 확 박아버릴라
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 너 때문에 내 인생이 망했어! 아빠 왜 이러세요. 너도 내가 알콜 중독자라고 생각하냐? 왜.왜 그래요. 또 술 드신 거예요? 네 애미를 닮아 쨍알쨍알 시끄럽네! 아빠! 술 그만 드시기로 했잖아요. 닥쳐! 내가 술을 마시든 약을 하든 내 알바야! 아빠.전 아빠 딸이잖아요. 그러니까 넌 내 소유잖아! 따지지 말고 술이나 더 사와! 흑흑
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 나 호랑이 보러 가고 싶어 갑자기 호랑이 좋아했나 원래 내가 원래 동물을 좋아하잖아 에버랜드 가고싶다 에버랜드 여기서 가깝잖아 내일 갈까 오 진짜 같이 가줄거야 응 가서 놀이기구도 타자 나 놀이기구는 잘 못타는데 안 무서운건만 가능 아 뭐야 그럼 동물만 볼거야 응 호랑이도 보고 사자도 보고 펭귄도 보고 뭐그래 나도 오랜만에 동물보면 재밌을거 같네
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 니 죽고싶냐?  아니요.  왜 사람 말귀 한번에 못알아처먹고 자꾸 두 번 세 번 말하게 하냐?  죄송합니다.  니 딸래미 거기에서 알바하는거 알고 있다. 니 아들래미 주몽학교 다니는것도 다 알아  제 아이들은 건들지마세요 왜 그러세요.  너는 내 말 안들으면 니가 사랑하는 사람 포함해서 니 주변 가까운 사람 하나씩 다 너 보는 앞에서 쥐도 새도 모르게 액체로 만들어버릴 수도 있어  그런 무서운 말씀 하지마세요 제발.  니가 애초에 제대로 했으면 내가 이러냐 나 착한놈 나쁜놈 만드는거 니가 하는거에 달렸어  죄송합니다 제가 다 잘못했습니다.  오늘은 이정도지만 다음번엔 치아 보험 제대로 들어와야 될거다. 강냉이를 다 털어버릴거니까. 이제 니 그 죄송하단 말도 지겹고 죄송하단 말도 못하게 만들어줄게 그냥
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 이 자식 아이패드 새로 샀네?  좋아보인다 나도 요즘 아이패드 사고 싶었는데 잘 됐네.  우리 좀 써 봐도 되지?  안돼. 엄마가 사주신 거란 말야.  친구끼리 왜 이래 한 번만 써본다니까.  안된다니까.  야 맞고 싶냐? 내놓으라면 그냥 내놔.  한 대 맞고 내놓을래 그냥 내놓을래?  진짜 안 되는데. 여기.  아싸 아이패드 득템
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 야 고구마?  내가 왜 고구마야? 고구마니까 고구마지.  그만해. 내 이름은 고군만이야.  너 불붙이면 아주 맛있겠다.  가 비켜.  아주 빨갛게 익으니까 군고구마네.  비키라고.  야 군고?  제발 좀 그만해. 나 정말 힘들어.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 100원만 빌려주라 구라치네 내일 200원로 갚을게 밀린 돈이 니가 천원이 넘어 아니 우리 친구잖아 친구긴 하냐? 아 백원만 이번만이다 진짜 고마워 안 갚으면 죽인다
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 민선씨 이번주 주말까지 제출인데 이것 좀 도와줘요.  각자 개인 업무 입니다. 저도 아직 제출 전이라 바빠요.  상사 부탁인데 이정도도 못 해주나요 ?  그래도 대신 업무를 봐주는 건 아닌 것 같습니다.  하기 싫으면 회사를 관둬요.  너무 심하십니다.  지옥 같은 회사 생활을 경험하게 해줄게요  그래도 업무 대신 처리는 부당합니다.  잘 생각하고 대답해요. 회사에서 고통을 맛 보게 해줄테니까  죄송합니다. 안될 것 같습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 김대리 네 과장님 무슨일이세요? 김대리 옷이 오늘 왜그래? 제 옷에 무슨문제가 있나요?  김대리 일을 못하면 옷이라도 단정하게라도 입고 출근하던가.  제 나름 신경 쓰고 입고 나온건데 죄송합니다.  과장님 요즘 김대리 남편이랑 사이가 안좋아서 옷에 신경 쓸수 없다고 하네요. 남편과 사이도 안좋은데 회사일은 제대로 하겠냐? 회사일에는 지장없게 하겠습니다.  아침부터 김대리 옷 꼬라지 보니깐 기분이 팍 상하네.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 아 내가 아이스 시켰지? 네 근데 지금 너무추운것같아서 나 뜨거운 걸로 마시려구 아네 손님 그럼 다시 계산해드릴까요? 무슨소리야? 바꿔주라고 하지만 아이스 반쯤 드신것같은데. 아이거 흘려서 그런거지 입 안댔어 그러니까 새거지 바꿔줄수 있지? 네? 원래 교환 환불은 7일까지된까 얼른 해줘 그건 이상황이랑 안맞는거 같은데요. 뭐가 달라? 소비자 보호법도 모르니?
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 어이 오랜만이다 너 나 피해 다니냐? 그건 아니야 근데 왜 난 그렇게 느껴지지? 지난번 맞은곳 아파서 잘 못 나갔어 그래? 어디더라 그건 왜 거기 빼고 맞자 제발 이러지마 싫은데? 난 재밌는데?
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장:  아니 진짜 걍 지구 망할 거 같아 위쪽은 비 난리고 밑에는 비는 안 와도 공기 난리고 이제 또 비오는 너무 많이와 진짜 망할려고이러나  그러게 말이여 진짜 몇년 전부터 미세먼지도 난리고 원래는 봄에만 황사처럼 공기 안 좋았잖아 근데 요즘엔 걍 사계절 내내 안 좋으니까 약간 더 무서운 건 또 거기에 다 적응한 거임  일단 나부터 적응 다함 공기 안 좋은 거 그러려니해 아 개인정  어쩌다 이렇게 됐는지 진짜 예전이 그립다 초딩 때라던가 그냥 벌받는거 같기두 하구 마잡 그래서 나 늦은 감 있지만  이제라도 일회용 줄이려고 뭔가 이젠 다들 좀 경각심 느껴야 할 거 같음
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 너네 엄마 다리가 하나 없더라? 응 사고 당하셔서 그래 으 다리 하나 없는 장애인이네 그래도 생활하시는데 문제 없으셔 문제가 없긴 뭐가 없어. 걸을 때 뒤뚱뒤뚱 이상하더만 말을 왜 그렇게 하니? 뭐가 맞는 말한건데 이상하잖아 계속 뭐가 이상하다는거야 뛰지도 못하고 걷는것도 이상하다는거지 뭐야 너 진짜 나쁘다 너가 불쌍해서 그러지
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 애 시어머니가 우습니? 아니요.그건아닌데 그게 아니면 미역국에 소고기 건더기가 없네? 아니. 요새 건강생각하셔서 채식하신다하셔서요 그래도 그렇지 미역국에 고기가 없음 그게 미역국이니? 죄.죄송합니다 내가 말을 말지 이렇게 답답해서야 다시 끓일까요? 그럼 이거 먹으라고? 죄송합니다.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 너 이번에 알바비 들어왔다며? 어 . 근데 왜? 내가 급해서 그러는데 10만원만 줘봐 왜 . 저번에도 안갚았잖아. 아니 한번에 돌려준다니깐 줘봐 언제까지 갚을껀데 . 아 시끄럽고 맞기 싫으면 빨리 보내 나도 써야하는데 . 안보내면 진짜 뒤진다 빨리 보내 아 제발.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 선생님 지금 저희애가 잘못했다는거에요? 아니요 어머니 그게 아니라요 그게 아니면 뭔데요? 시작은 민혁이가 먼저 했기때문에 사과를 하고 좋게 넘어가는게 아니 우리 민혁이가 그럴애가 아닌데 상대 아이가 잘못했겠죠 어머니 제가 상황을 파악해봤는데 민혁이가 먼저 시작한게 맞대요 아니 선생님이 너무 편파적이고 편협하고 일방적이시네요? 어머니. 일이 더 커져요. 제발요 진정하세요 아니 나는 진정못해요 우리 민혁이 얼마나 애지중지 키웠는데 게다가 민혁이가 틀린말한것도 아니잖아요? 그애가 한부모 가정인게 우리 민혁이 잘못도 아니고 어머니 제발요.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 자네 이번에 취직을 했다지? 예. 어렵사리 구한 자리입니다 그래. 잃기에는 너무 아쉬운 자리겠군 예? 그게 무슨 소리십니까 그날 자네가 본 것들. 네?! 못 본거로 해줬으면 좋겠구먼 무. 무슨 참. 어린나이에 가족들을 부양하는건 쉽지 않은 일이지. 아니면 부양할 가족들을 없애버리는게 나으려나. 제발 아무에게도 말하지 않을테니 제발. 내 항상 자네를 걱정하고 있다는걸 알아주게. 그럼 일 열심히 하게.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 이쪽에 주차 하시면 됩니다. 너가 대주세요 고객님 저의 역할은 안내요원 입니다. 내가 바쁘니까 빨리 가야된다고 죄송합니다 아 여기 사장 누구야 죄송합니다 저의 역할은. 아니 너 가만히 있고 사장 나오라고 해 죄송해요 이러지 말아주세요 너 자르는 건 일도 아니야
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 오늘 저녁 회식합시다  네 갑자기요? 왜요? 하은씨안돼요? 애가 아파서 빨리 가봐야할것같은데요  애는 하은씨만 키웁니까?  죄송합니다. 신랑이 오늘 출장이라  죄송할 것 없고 오늘 회식은 무조건 참석이니까그리 아세요 .아. 안되는 사람은 다음 인사고가때 봅시다 . 죄송합니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 야 새끼야 내 사랑스러운 여동생을 욕하면 어떡하냐 진짜 땅에 매장 될 준비나 해 죄송합니다. 한번만 봐주세요 하이고 싫은데 너 내가 깡패를 고용해서 널 보복할줄 몰랐지? 죄송합니다. 여동생분 한테 함부로 까불지 않겠습니다. 살려주세요 야 깡패야 이 새끼 봐줘야 하냐? 너가 판단해봐 아뇨 저런 새끼는 남자도 아니에요 그냥 형님이 원하는대로 진행 하겠습니다. 들었지 새끼야 너 임마 건들면 안되는 사람을 건든거야 우리 형님 무서우신 분이다.  넌 이 세상에서 아예 삭제 시켜줄게
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 201호에 좀 이상한 사람이 이사왔다면서요?  무슨 조현병인가 뭔가?  그거 완전 정신병이잖아요  맞아 요즘 그런것들이 잠재적 범죄자잖아  아휴 무서워  집값떨어지겠어요  그러니까요 장애인들은 집에만 조용히 있었음좋겠어요  그러게요 괜히 애들 교육에도 좋지않겠어요  무슨말씀이세요? 감기처럼 치료가능한 질병이에요.  아니 우리가 못할말했어? 맞잖아 정신병자 아휴 옮을까 두렵네 왠만하면 보지맙시다?
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 아니 커피를 이따구로 만들어서 돈받고 팔아도 되는거야? 손님 어떤일로 그러시죠?  아니 커피가 쓰다고!!!!!!!평소에 먹던 커피처럼 달지거 않고 쓰다고!!!  손님 평소에는 마끼야또 드시다가 아메리카노 드셔서 쓰게 느껴지실 수있습니다  아니 이렇게 쓰면 어떻게 먹냐고  손님 그러면 따뜻한 물을 섞어서 좀 도 연하게 희석해서 드리겠습니다  아니 나 안먹어 환불해주고 내 시간도 보상해 당장  손님 이미 커피는 주문해주신 것이어서 환불은 어렵습니다  아니 내 입을 버려서 기분이 나쁘다고!!!!!!!!사장어딨어 사장 나오라고해  손님 죄송합니다 환불해드리겠습니다
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 옥상에서 사람이 떨어졌어요. 사람이 떨어졌다고요? 위치가 어디세요? 경기도 광주시 오포읍 문형리 행복 아파트인데요, 사람이 떨어졌어요. 몇층에서 떨어졌는지는 보셨나요? 아니요 어디서 떨어졌는지는 못봤어요. 알겠습니다. 잠시만 기다려 주세요.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 사장님 제 돈 돌려주세요 시끄러 너가 줬잖아 갚아주신다면서요 됐고 너가 준 이상 지금 내 돈이야 와 이런 도둑놈을 봤나 새끼야 인생은 먹고 먹히는 세상이야 사장님 진짜 천벌받아요 이러다가 음 호랑이가 사슴을 잡아먹는다고 천벌받냐? 네? 에휴 그러게 자신을 믿었어야지 남을 믿으면 어쩌냐 경찰에 신고 합니다. 진짜 신고 해봐 넌 일자리 없어 질줄 알아 새끼가 더 큰 돈을 받을수있는데
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 말편하게해도될까요 도 아니고 갑자기 다짜고짜 놓고 응응 마저 이러는데 나 첨에 잘못 들은줄 맞긴 뭐가 맞아 첨엔  있어 했는데 그때 딱 알았어 아 말 놓으려고 드릉드릉 하는구나
#
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 쓰레기통 비우고 왔으면 당연히 닦아야죠. 그거 다 막내 일인데. 안했네?  네 선배님 죄송합니다. 제가 바빠서 깜빡했습니다  회사 소문 안 궁금해요? 돌아가는 꼴 한번 재미있네.  네? 소문이요?  막내가 막내 일 제대로 못한다는 소문이 있던데 완전 사실이잖아. 대체 하는 게 뭐에요?  예? 그 저기. 시키시는 일 위주로.  저기요 눈치가 없어요? 네? 아 그. 죄송합니다. 그치만 사실 제 주요 업무를 위주로 하다보니.  주 업무? 지금 그쪽한테 그런 업무가 있긴 해요? 내가 그런 거 까지 알거 없고 똑바로해요. 장난치나 지금. 짤리고싶어요? 눈치껏 하라고. 재바르게.  네 죄송합니다.  대답 한마디 듣기가 어쩜 저렇게 힘드냐. 진짜 누가 뽑았는지. 인사팀 보는 눈 다 죽었지 쯧쯧
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 야 돼지 . 돼지 너 부르잖아 왜 너가 돼지야? 왜 대답해 하아 그러니까 살을 빼 돼지새끼야 하지마 뭘 하지마 너나 뚱뚱하지마 왜 그래 보기 역겨워서 그런다 왜
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 수민 씨 아침에 일찍 좀 오세요  저 지각 안했습니다  아니 신입이면 1시간 일찍 와야지  네?  요즘 애들은 기본이 없어 일찍 와서 커피도 타고 정리도 해놓고 그래야지  그건 부당하다고 생각합니다  이것 봐 바로 말대꾸야  말대꾸라뇨?  역시 싸가지가 없어 수민 씨는 회사 짧게 다니고 싶은가 보네  지금 무슨 말씀을 하시는지 모르겠네요
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 넌 뭔데 시비야?  그쪽이 먼저 시비걸지 않았나? 그 여자 놔줘. 형씨 정의의 사도라도 납셨나? 그냥 가던 길 가 못가겠다면? 그럼 너도 같이 맞던가. 평생 절름발이로 살게해줄까? 여자부터 놔줘. 여자는 아무 잘못 없어.  와 이거 어이없네. 순순히 놔줄거라 생각한게 웃기다야 남자답게 덤벼. 여자는 건드리지마. 난 내가 안 때려. 우리 애들이 대신 때리지. 가지마.! 그 여자만 으윽 놔주고 가
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 나 오늘 회사 지각한거 있지 헐 몇분이나 삼십분 하 미쳤다 어캐 됨 부장님한테 한시간동안 깨지고 왔다 개같은거 그래서 저기압이었구나 왜 늦었는데 아니 어제 깜빡하고 알람을 안 맞추고 잔거야 알람 안맞췄는데 삼십분밖에 안늦은거면 대단한건데 그치 그니까 부장님이 그걸 알아줘야되는데 그래도 앞으로 조심해야겠다
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 서류 오늘까지야 자리에 안계셔서 책상위에 올려 놓았습니다 그래?언제? 오전에요 그럼 내가 왔을때 다시 왔어야지.가정 교육을 못 받았나. 무슨 말씀이세요? 가정교육을 못받아서 일을 그리 하는거 아냐 저희 부모님께 막말 하시는 거에요? 막말은 무슨. 히스테리 대단하네. 남자친구랑 문제 있어? 뭐라구요?
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 안녕 얘들아 이번 반장은 내가 맡게 되었어. 모두들 잘 부탁해. 우와 축하해! 우리반을 위해 열심히 일을 해줘! 아 그런데 이번에 반장되고 반장으로서 너희들에게 할 말이 있어. 우리에게 할 말이 있다고? 뭔데? 벌써부터 일 하려는거야? 무리하지 마 이제 앞으로 아침마다 등교시간은 8시며 지각할 때마다 벌금을 오천원 씩 걷어 들이려고 해. 뭔소리야 우리 학교 원래 지정된 등교시간은 9시잖아. 아무리 반장이어도 교칙을 바꿔서는 안 돼. 더욱이 벌금같은 돈이 오가서는 안되고. 내가 반장이잖아. 너가 반장이야? 그럼 뭐 반장은 아무 재정도 없이 일을 해야해? 지각을 안하면 되는거잖아. 애초에 돈을 걷을 생각이면 그 돈을 어디에다 어떻게 쓸건지 말해줘야 하는게 먼저 아닐까? 일단 지각비로 걷은 오천원 중 삼천원은 반의 발전을 위해 쓸거고 이천원은 그래도 내가 반을 위해 일 하는데 수고금 같은건 가져가야지. 야 무슨 학교에서 반장 하나 하는데 돈이 필요해. 너 도둑놈심보다. 그럼 너가 반장하던지 그럴 용기도 없으면서 말이 많네? 어쨌든 내일부터 지각하면 오천원이야. 지각할 마음 있으면 오천원씩 들고와.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 신입 치마가 진짜 잘 어울린다. 아 감사해요. 앞으로 매일 치마 입고 안 돼? 얼마나 좋아? 네? 무슨 말씀이세요? 아니 신입이 치마 입고 사무실 걸어다니니까 얼마나 좋아. 무슨 말씀이신지 잘 모르겠어요. 사무실 분위기가 산다구. 예쁜 다리로 걸어다니니까 아 네. 기분이 조금 나쁘네요. 아이 참 뭘 그래. 조심해주세요.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 하지만 내려서 최대한 아무렇지 않은척 빨리 이곳을 벗어나자 이런일 익숙하다는 듯 사람이 그럴 수 있지 와 마자 태연한척 합리화하며 소심쟁이들끼리만의 공감대구나 이거시 와 그니깐 너무공감되고귀까지빨개지는 그런 썰이야
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 아 이자식 이십분이나 늦어 죽을래 미안 버스를 반대 방향으로 탔지 뭐야 지랄하네 그 핑계 이제 지겨워 임마 아 진짜야 됐고 니 한번만 더 늦으면 쌩깐다 알겠어 대신 내가 오늘 밥 사줄게 나 졸라 비싼거 먹는다 아이 그건 아니지 적당히 골라 너 용돈 받아서 돈 많잖아 한 턱 크게 쏴라 아 알겠어 골라
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 총 내려놔 너 이래 봤자 이미 경찰 불렀고 나는 그 사람 어디 갔는 지 몰라 경찰 오기 전에 튀면 그만이야 너 걔 어디 갔는 지 안불면 니 이마에 총알 박히는 거야 어디서 부터 잘못 한 건지 모르지만 나는 그 사람이랑 전혀 관련 없어. 그냥 나는 시키는 대로 할 뿐이었다고 웃기시네 너 잔챙이인 척 할려나 본데 다 알고 왔어 꿈틀 거리지 말고 제대로 손 들어 나는 정말 아랫것일 뿐이라니까 내 말좀 들어줘 너 3일 전에도 그 사람이랑 통화한 내역 나한테 있어 그거는 내가 약속했던 물건 준다고 만난 거고 역 앞에서 잠깐 만난 거야 그 사람 어디로 갔는 지 나는 몰라 조금이라도 알고 있는 거라도 빨리 불어 배를 타고 갔는 지 비행기를 탄 건지 아마 배를 탔을 거야 그게 밀수하기가 쉬우니까 나도 정말 모른다고 그 뒤에도 통화 내역이 있은 걸 내가 알게 되면 너 손가락 부터 잘라버릴 거야
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 천안 두정동 제이빌라 인데요, 지금 화재가 발생했어요. 빌라 어디에 불이 났나요? 1층 주차장에서 불이 나고 있어요. 그러면 지금 다친 사람도 있나요? 아직까지는 없는거 같아요. 알겠습니다. 지금 119 소방대를 보내도록 하겠습니다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 당신 블랙박스 삭제하세요! 당장!  내가왜요? 이게 당신에게 불리하게 작용하나요?  삭제하라면 할 것이지 말이 많아?  명령조로 제가 왜 말을 들어야하죠??목소리크면 다에요?  뭐?? 목소리크며 다냐고??  손찌검하시려거든 동영상녹화 하겠습니다  녹화한다는게 더 협박아닌가??  당신도 찍으시던지요.  무고한 상대로 고소를 하는게 말이 되나?  차량 훼손혐의 증거입니다.  그건 법정가서 얘기하면 되고 그게 나인지 확실한가??  변호사랑 얘기하시죠  내가 순순히넘어갈거같나? 밤길조심하라고  경찰에신고하겠습니다  신고? 뭘했다고신고?  협박이잖습니까?  증거있어? 사전동의없는 녹취는 증거도 안돼  .당신이 이러고도 사람이야??  뒤통수조심하라고  .절대 고소취하안할겁니다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 너 살 빼야겠다 살 빼야 겠지 나는 먹어도 잘 살도 안 찌는데 그래 좋겠다 너는 먹으면 살 찌는 편이니 뭐 그런 편이야 너는 공부 잘하니 아니 너 나한테 고마워 해야겠다 뚱뚱하고 공부도 못 하는데 친구 해 주잖아 그래 고맙다
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 신대리 오늘 내 아내가 계단에서 넘어져서 무릎 수술을 했다고 하더라고 이를 어쩌나. 어머 어떡해요. 많이 다치시는 않으셨나요? 한창 조심하셔야 할 나이인데. 그래서 말인데. 오늘 내 아내 간병 좀 부탁 드려도 될까? 내가 오늘 저녁에 술 약속이 있어서. 사모님께서 아프신데 병원에 직접 가셔야죠. 수술도 하셨다면서요. 친구들이랑 술 약속이야 거의 두달만에 가는건데 빠질 순 없잖아. 한 번만 부탁할게. 저도 오늘 친구들이랑 저녁 약속 있어서 안 돼요. 다음 달 결혼하는 친구 만나서 노는거라 빠지기가 좀 그렇네요. 내가 이렇게 부탁하는데도 거절하는거야? 내가 썩어빠진 물에서 건져 올려서 취직 시켜줬으면 이런 일 하나라도 해야지. 정말 실망이네. 제가 약속이 있어서 그래요. 정말 죄송합니다. 죄송하면 다 될거라 생각하는가? 이런 사소한 부탁도 못 들어주는데 나중에 회사에 중요 한 일 있을 때 내가 자네를 어떻게 믿나? 사소한것도 거절하니까 기분이 썩 좋지가 않네. 하.이번 부서이동 할 때 불이익 줄거니까 그렇게 알고 있어. 그럼. 사모님 간병 몇시까지 해드려야 하는건데요. 오늘 저녁 6시부터 모레 아침까지만 해주면 돼. 내가 지방으로 술마시러 가서 좀 오래걸려. 그건 안돼요. 저도 회사 쉬는 날 해야 할 일이 산더미입니다. 그럼 왜 물어봤나? 나 가지고 노는건가 자네? 그니까 자네가 일 할 곳도 없는거야. 얼굴부터 딱 보이거든 놀고 마실거 같은게.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 이 자료를 공개 시 당신의 명예를 실추시킬 수 있습니다  새꺄 해봐  네 해당 자료는 당신의 범죄이력을 적은 문서입니다. 괜찮습니까  어떻게 얻은거야  공개 시 아무런 무리가 없으신지 다시한번 여쭙습니다  살려주세요. 그거 있음 나 죽어요  좋습니다. 대신 제가 요구한 금액에 맞춰주시죠.  오 부디. 부탁드립니다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야 창모 신곡 나온거 들었어 아 당연하지 한시간 내내 들었잖아 개좋아 이번꺼 진짜 그니까 아니 근데 댓글 보니까 실망했다는 사람들도 있더라고 헐 그래 솔직히 실망할 정도는 아닌데 나도 놀랐어 뭐 모든 사람이 좋아하는건 불가능하긴하지 그렇긴해 아이유 싫어하는 사람도 있잖아 맞아 근데 내 주변에선 못보긴함 나도 아이유 싫어한다하면 좀 이상해보일듯 그니까 인정
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야 꼬맹아 일로와  아저씨 누군데요  아씨 오라면 와 임마  싫어요 도망갈래요.  가봐야 꼬맹이지 야 돈있냐  없어요 저 갈래요  아니 있으면 어쩔건데 맞고 싶냐  죄송해요.  아무거나 돈 되는거나 줘  네 여기요
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 아니. 마케팅 팀은 이번 행사 때 김민주사원인가 ? 그 사원 참 예쁘던데. 죄송해요. 제가 이번 행사에 더 열심히 했어야했는데. 뭐 박사원이 잘못을 한 건 아니지. 그렇게 생긴게 죄는 아니잖아 그렇게 생긴거라뇨.? 그렇잖아 그 때 반응도 그렇고 박사원나올 때랑 김민주사원 나올 때 반응부터가 너무 다르던데 뭐. 외모를 보고 뽑는 이벤트가 아니지 않았나요.? 요즘은 말야 외모도 능력이라고 기본으로 가지고 가야하는거야. 전 그렇게 생각하지 않습니다. 일 백날 열심히 해봐 나중에 누가 먼저 대리달고 승진하겠어. 참 아직 세상물정 모르는구나. 그래 가서 일이나 열심히 해. 그래야 조금이라도 따라가지. 제가 그렇게 많이 부족한가요.?  부족한 수준이면 말을 안하지. 괜찮아. 누구 탓을 해. 그렇지? 어디 샵이라도 다녀와봐 요즘 메이크업도 영 안어울린다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 좋은 아침 좋지 않아 왜 그래 무슨 일 있어 또 산더미처럼 들어가서 잠을 못 잤지 헐 설마 김 차장님 또 누구 겠니 나 정말 일 폭탄으로 누구 죽일 있어 그러게나 말이다 그런 좀 도와주겠니 친구야이 몸도 달리 할 일이 생긴 듯하다 힘내라 새끼
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 김대리 여기서 뭐해? 탕비실에 뭐 꿀 발라 놨니? 아닙니다. 바로 들어가겠습니다. 아니 내가 계속 보니까 김대리는 화장실에도 꿀 발라 놓고 탕비실에도 꿀 발라 놓았나? 아닙니다. 우린 이렇게 열심히 일하는데 김대리는 내가 볼 때마다 사라져있네? 회사가 편하나? 아닙니다. 열심히 하겠습니다. 아니. 내가 기합하는 것도 아니고 그럴 필요는 없는데. 옆 부서도 옆옆 부서도 대리들이 다 일 잘해서 좋다네? 그에 비해 우리 김대리는? 죄송합니다. 그렇게 사과만 하고 행동이 안 바뀌니 김대리가 아직도 대리인거지. 아무튼 내가 앞으로 김대리 지켜볼거야. 열심히 하겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 닌 진짜 다시 생각해 봤는데 그냥 살려주면 안될 것 같다. 그래 새끼야 한번 죽여봐라 이거 진짜 돌았노 그래 내가 못 찌를 줄 알았냐 왓다 마 진짜로 찌를 생각이네 알겠다 미안하다. 내가 잘못했다 아이가 도와주세요 여기 사람이 죽을것 같아요 뭔 상관이야 너도 죽여줄까? 아니요 죄송합니다. 그냥 조용히 지나가겠습니다. 그냥 보내줄 순 없지 너도 내 얼굴을 봤잖아 너도 이리로 와!
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 야 오늘 쟤로 우리 내기할까? 오 뭔데 뭔게 쟤가 빵을 몇 분안에 사오는지! 오우 쉣 콜 콜 만원빵이다? 오케이 야 길동아 지금부터 최대한 빵 빨리 사와라 어? 어어 알겠어! 키키 쟤 뛰는거봐라 내가 이기겠는데? 3분안에 무조건 온다 쟤 어리버리하느라 무조건 5분 이상이야 봐라 한 번 그러면 쟨 나한테 뒤지지 여 여기!! 야 7분이나 걸렸잖아 니 뒤질래?
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 아우 가만히 좀 있어 정신없어 죽겠네 저 새끼 저 고등학교부터 유명해  왜 고등학교때 어땠길래 그래 아주 다 말 걸고 다녀 정신없어 죽겠어 이리 갔다 저리 갔다 그런 걸 요즘 말로 인싸라고하지 인싸 얘는 아싸 나 지금 음악감상 중이거든 매앤날 가만히 누워만 있어 아주 난 이게 좋아 이 인싸새끼야
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 김대리 연차는 또 왜내? 아 예 부장님 막내가 많이 아파서 그렇습니다. 이래서 암탉이 울면 집안이 망한다니까? 아.죄송합니다 결혼하고 애 낳은 것들은 뽑지를 말아야해 죄송합니다. 시정하겠습니다. 뭘 시정해? 그냥 가서 설거지나 하고 살아 연차 제가 생각이 짧았습니다. 쯧 계집애들은 꼭 좋게 말하면 못 알아들어 .나가보겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 일날 도착했단 우편물이 보이지 않아요  뭐지 에 왜죠 모르겠어요 새 주소로 했는데 경비실이 있나요 아니면 편의점이 근처에 있나 아니 으아닠 자연스럽게 부동산에 맡기고갔나봐요 못살아 아씨 그 택배가 내것이었어  내것이었어
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 민성이 이번주 뭐하니? 네 대구에서 부모님 오시기러 했습니다 아그래?? 네 교수님 무슨일있으세요? 아니 우리 딸이 이번주에 귀국인데 내가 그날 약속이 있네 . 아네. 부모님몇시에 오시나? 오전에 오십니다 아 그럼 잘됏네 내 딸은 새벽 비행기로 오니까 자네가 다녀왔다가 바로 버스터미널로 부모님 모시러 가면 되겠구만 네. 좀 피곤하겠지만 다 젊을때 고생은 사서도 한다고하지 않나? 네
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 지금 당장 돈 꺼내라고 제가 지금 가진 돈이 없어요 그게 말이 돼 당장 내놔 진짜로 돈이 없어요 저도 월급을 못 받았어요 내가 그말을 믿을 거 같아? 그러면 너 진짜 죽는거야 잘못했어요 제가 다음달엔 꼭 드릴게요 내가 이 칼로 진짜 못 찌를 것 같지? 잘못했어요 죄송해요 내가 너네 집 가서도 깽판치고 다 부숴버릴 수 있어 안돼요 죄송해요 한번만 봐주세요
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 김기자 내일 그 기사 낼생각인가? 제상각은 변함 없습니다 그래 우리 김기자 뚝심있어 그래서 내가 좋아해 죄송합니다. 이렇게 나랑 척 지어도 괜찮겠어? 죄송합니다. 음 뭐 마음이 확고한건 알았어 근데 김기자 딸 이쁘더라? 네?? 우리 딸이랑 같은 나이던데 딸 못보면 상심이 크겠어? 무슨 소리를 하시는 겁니까 아니 잘 생각하라고 대의를 선택할지 딸을 고를지
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 그리거 니보증금 아빠가 내준대 사장한테 빌리지마래 아 왜 자는데 놀래라 을  왜 엄마한테 돈달라고안했냐고 빌려준다고 왜 남한테달라하냐고 말도안했냐면서
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야 나 오늘 차비가 없는데 만원만 빌려주라 안돼 나 돈 없어 뒤져서 나오면 뒤진다 너 저번에 빌려간 돈도 안갚았잖아 그것까지 한번에 갚을께 안돼 그것부터 내놔 벌써 10만원이야 미친 어서 돈 빌려주라고 갚겠다고 못믿어 못비렬줘 찌질하게 왜그러냐 사람 화나게 하지말아라 너는 뭐가 그렇게 떳떳하냐 마지막으로 말한다 어서 내놔
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 울고잇는데 옆에서 웃으면 나도 웃음나는거잇자나 그런거지 웃음벨같은거지 마저 인강다봣당 오이 완존슈퍼공부러셧 히히헤헤 근데 짧은거엿어 옹개꿀띠 지금 크루롤한다고 같이하제 옧글쿤 밥부터머거야지 그래용 캐춰 그래용 그래용 저녁은 뭐드세용 스퓀이랑 배부르게머것당 에벌써드심 그뤄치 와근데개졸령 지금 주무심 안되여 졸려죽겠는데 오늘방송없다하고 그냥지금부터잘까 띠로리 그정도야 잠깐 앉아서 자는건 어떠심 잠이미친듯이옴
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 씨파. 이것들이 지금 .내가 우스워? 아닙니다.형님 .죄송합니다  피맛을 니들이 아직 못봤지? 잘못했습니다. 살려주십시요. 흑흑흑 야. 눈알 하나씩 뽑자. 눈 하나없어도 다 보이제? 형님.살려만 주십시요. 시키는건 다하겠습니다  내손에 피 묻히기전에 해라 응
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 너 꿈이 뭐라고? 교수?  넵  네 머리로 무슨 교수는 교수야.  제 목표입니다.  현실성 없는 목표는 그냥 없는 것보다 못해. 포기해.  저는 제 꿈을 계속 실현해 나갈 것입니다.  그래 응원은 못해주겠다.  열심히 하겠습니다.  백날 해봐라 교수의 교 자도 못 따라갈거다.  그냥 저를 좀 응원해주셨으면 좋겠네요.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 승현씨 오늘 저녁에 약속있어요? 아니요. 없습니다. 잘됐네. 오늘 남아서 내 내 야근 좀 해줘요 네? 그거 대리님 야근이요? 네. 조금만 부탁해요. 나 우리애 학예회 가야 해서 아무래도 이건 아닌 것 같아요 대리님. 머가 아니라는 거야? 엄마로써 학예회는 가야지. 그래도 대리님 일이잖아요. 그래서 대타 뛰어달라는데 말이 많어. 그렇게 회사 다녀도 돼? 그래도 이건 아닌 것 같아요. 대리님.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 너 어제 영수씨랑 잤다며? 책임님. 누가 그런 소리를 해요.? 누구긴 여기 사람들 다 아는데? 정말 다들 왜그러시는 거에요. 저는 그런적 없어요. 흑흑 너가 영수씨 맨날 꼬리치고 다니잖아. 그러면 뻔하지 뭐. 제가 언제 꼬리치고 다녔다는 거에요? 어제는 술마시고 취한 척 영수씨 차에타고. 쯧쯧 저도 영수씨 때문에 많이 힘들어요. 회사생활 잘하고 싶으면 앞으로 조심해라 예.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 으악. 이게 뭐야! 어머 지혜야 너 안에 있었구나 너.너 정말. 아니 우리는 아까 걸레빨고 남은 물을 버려야 하는데 화장실이 다 닫혀있길래 아무대나 버린다는게 진짜 너무하는거 아니야!? 교복이고 다 젖었잖아! 어차피 너도 드러운데 씻었다 생각해  저 더러운 물로 씻었다니? 저 물이 아무리 더러워도 너만큼 더럽겠니?  진짜 돌았어 너? 아니? 그러니까 조심히 다녀 언제 또 이런 일 생길지 장담못하니까.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 너 살 좀 빠졌냐 아니 그대론데 아 그래 좀 빠진 것 같네 요즘 운동하기는 하는데 잘 안빠져 일주일에 몇번 가 나 두번정도 별로 안가네 더 많이 가야지 그런가 겨울이면 원래 더 안빠지는거 아냐 에이 그런가 모르겠네 더 열심히 해봐 알았어 고맙다
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 이 가방에 있는 돈 다 쓸어담아. 그러지 않으면 쏴 죽인다. 예. 알겠습니다. 제발 살려만 주십쇼. 움직이지 않고 뭐해! 당장 시작해! 알겠습니다. 거짓말하면 들통나는거 알지? 네 절대 거짓말 안 합니다. 경찰한테 신고하면 너 뿐만 아니라 너 주변에 있는 가족들 다 죽여버릴 줄 알아. 저는 괜찮지만 제 가족들은 죽이지 마세요.! 부탁입니다! 제대로 해. 일단 다리부터 쏠까? 죄송합니다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 내려놓고있기뭐해서 올린거야 응 어머니 캐리어 필요하시다며 문앞에둘테니까 가져가 배낭메고갈거래 짐다쌌어 알겠어 엄마 금토일 가는거였어 너일에 오전에가 새벽에가 그래 롤안해 응안해 아까 내 어떤 말에 기분이 나빴던거야  그거 모르는것도 기분이나빠 말해주면되잖아 내가 하는말 다 기분나빠겠지 아까말했어 근데 너가 그런식으로나온거지 진짜오늘일은 무조건 너잘못이야 나도 내가 일부러 안받는게아닌데 계속 그걸로 우리가 안좋게 이야기가 나오니까 기분이 안 좋아졌어 물론내가 너한테 말 안하고 빌려준게 잘못인건 알아 그래도 계속 그 얘기가 나오는게 싫어 너가 말안해도 생각나면 짜증나는데
#
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 너 나 좋아하냐?  어 좋아하지 죽을만큼 좋아? 응 당연하지 그럼 죽어봐 죽는시늉이라도 해봐 무슨말이야장난이지 사람 가지고 장난하니? 못죽겠으면 죽여줄께 내가 왜그래 진짜 너야말로 왜그래 나 좋아한다며 내가 죽어라면 죽을수도 있는거 아냐? 무슨말을 그렇게 해 지금 나 너무 무섭다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 내가 이번달까지라고 하지 않았나? 아. 월급이 밀리는 바람에 죄송합니다. 조금만 더 기회를 주십쇼. 됐고 오늘 이 각서 사인받으려고 온거야. 네? 다음달까지 못갚으면 여기 신장하나랑 여기 안구하나 대신 가져간다 오케이? 두 달만 더 주시면 안될까요? 장난해? 다음주까지로 해버리기 전에 알겠다고해. 예. 당장 각서에 사인해. 네 알겠습니다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 요새 살좀 빠졌네 민주씨? 아 네 신랑이 잘안해줘? 네?? 저 살빠지는거랑 신랑이랑 무슨 상관이. 신랑이 속썩이는거 아닌가 해서 글지 괜찮습니다. 이런 대화 불편해요 민주씨 상사가 걱정해서 하는 말에 왜이렇게 정색이야? 하지만. 하지만은 무슨 하지만이야 그렇게 딱딱하게 해서 사회생활 어찌고 하려고 그래? 죄송합니다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 언니 이거하나사줘 아 이쁘네요 얼마에요? 30000원이야 네? 그냥 리본 삔인거 같은데 삼만원이요? 응 삼만원 아 다음에 살게요 언니 지금 장난해? 나 데리고 장난쳐? 그게 아니라 터무니없이 비싼것같아서 지금 나 길바닥에서 이런거 판다고 무시하냐고 그런거 아니에요. 그럼 얼른 사가라고 짜증나게 하지말고
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 여기 있던 돈 어디다 뒀어?  무슨 소리야? 돈이 어디있다고 그래?  얼른 내놔! 여기 있는거 마지막으로 확인했어!  또 도박하려고 하지? 미친 인간아!  이번엔 느낌이 아주 좋다고! 내가 톡톡히 쳐서 되돌려줄게!  지금 공과금 낼 돈도 없는데. 무슨 소리야?!  세간 살림 다 부셔놔야 정신 차리겠어?! 내놔!  그 돈이 어떤 돈인데.! 현아 등록금이야.  내가 그냥 달래? 돌려준다고!  아이고. 내 팔자야. 이 돈 쳐먹고 다시는 돌아오지마.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 예쁜이메리크리스마쑤 아직인뎅 원래 이브에하는거거든 카드써조 카드 어제 써서보냈는데 어디 카톡선물하면서 써서 보냈어 안봤나보네 그거카드아닌데
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 자 다들 일 멈추고 점심식사 하러갑시다  네 알겠습니다  자네도 갈거야? 일 더 안하고?  네. 저도 점심 식사 해야합니다  근데 우리는 선약이 있어서 안될 것 같은데  같이 먹으면 안될까요?  동료들이 불편해할 것 같은데 말이지  동료들이 저를 싫어하나요?  어쨌든 알아서 식사하라구  알겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 한수씨 네? 이번주말에 어디 나들이 안갈래요?  저요? 아 나 옆 팀 미영씨랑 사귀는거 알지? 아네. 아니 텐트치고 놀다올건데 내가 텐트 잘 못치잖아 아. 저번에 보니까 캠핑이 취미라든데 같이 가자구 아.안가면 안될까요 아니 같이 가서 고기도 구워먹고 좀 친해지자는건데 사람 왜이렇게 딱딱해 암튼 짐도 많고 머리가니까 토요일 8시까지 우리집앞으로와
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 사진 보셨죠? 이야.아내분이 있는데 이렇게 당당하게 바람을 피시다니. 뭐야.당신 어떻게 이걸. 에이 중요한겅 제가 이걸 어떻게 알았냐가 아니라 그쪽이 바람을 폈다는 사실이죠. 이걸 당신 부인이랑 가족들이 알게되면. 바라는게 뭐야 도데체. 뭐 다른건 없고 돈 한 3억 정도? 말도안되는. 갑자기 그런 큰돈이 어디서 구해진다고 내놓으란거야 뭐 어떻게 구하실진 저는 잘 모르겠고 못구하시면 부인분이랑 가족들이 크게 실망하실겁니다. 너.두고보자. 그럼 일주일내로 돈가지고 다시 봅시다. 일주일은 너무 짧아.한달만 시간을 줘.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 대성씨 네? 이번주말에 뭐해? 애들이랑 놀이동산 가기러 했습니다 아그래? 우리 아버지 과수원에 사과를 좀 따야하는데 네?? 아이고 대성씨 그렇게 귀가 어두워서 사회생할 어떻게하나? 무슨말씀이신지 애들이 데리고 와서 여기가 놀이동산이라 생각하고 풀어두고 자네는 사과좀 따지 그래 제가요??? 그럼 여기 누가있나? 주말에 보세 주소는 문자로 보낼테니
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 저.저기요 네? 아까부터 지켜봤는데 너무 예쁘시네요 네? 아 예. 감사합니다 저기 남자친구 있으세요? 그건 왜요? 없으면 만난것도 인연이니 차 한잔 하실 수 있나해서요 죄송해요. 시간이 없네요. 에이 그러지 말고 차 한잔만 합시다. 제가 보기에는 바빠보이지도 않는데 뭐하시는거예요? 이 손 치워요!
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 야 기타연주를 그것 밖에 못치냐? 죄송합니다. 그러면서 길거리 연주로 돈을 받으려고 해? 니가 받은 돈 내가 가져간다. 아니 주세요 뭐하세요 지금 야 빨리 도망가 넌 가만히 있어  아니 이거 범죄에요 신고 할거에요 신고해 봐라 어처피 우린 지문 등록도 안되어있는 노숙자라서 소용없어 도망치면 끝이야 도대체 왜 그러세요 넌 우리 구역에서 영업을 했어  뭐라고요 우리 구역에서 돈을 벌면 너 돈이 아니지
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 친구야 돈좀 빌려주라.  돈.? 왜 빌리려고? 왜긴 왜야. 매점가려 그러지  지난번에 빌려간 것도 안갚았잖아.  아 그거 얼마나 한다고! 나중에 한꺼번에 갚는다니까.  오늘은 돈 없어.  아니 그럼 아까 쉬는시간에 너 매점 다녀온건 뭐냐?  그때 남은돈 다 쓴거야.  그럼 너네 어머니께 지난번에 있었던일 전화로 말한다?  아. 알겠어. 여기 돈 줄게.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 내일까지 입금하세요  도저히 내일까지는 돈 마련 못할 것 같아요  그럼 저도 가만히 있지 않겠습니다  500만 원이라는 큰 돈을 어떻게 하루만에 마련하나요  그럼 인터넷에 유출해도 되나요?  그것만은. 안돼요 시간을 좀 더 주세요 부탁이예요  그럼 이번주 안까지는 돈 마련할 수 있나요?  이번주요? 하. 최대한 노력할게요  노력말고 확실히 입금하시길 바랍니다. 더이상 봐드리지 않고 사이트에 공개하겠습니다  알겠습니다.  시간 더 드렸으니 입금하시고 연락주세요. 이번이 마지막 기회 드리는겁니다  알겠습니다.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 이거 한정판 굿즈 아니야? 대박 영롱하다. 그지 우리 오빠들 너무 멋져. 오 고생한 보람 좀 있다. 그런 의미로 나 이것 좀 빌려주라 어? 안돼. 이거 나도 구하기 힘들었어. 하나라도 없어지면 난리나. 안 잃어버리고 잘 돌려줄게 그럼 되는거지 그래도. 이거 조금이라도 너 힘들게 얻은거야. 나도 자랑이란걸 좀 해보자 자랑만 하고 다시 돌려줄게 된거지 그럼?? 그래도 안돼. 야 다시 돌려준다고 돌려줘도 난리야. 좋은말로 할 때 줘라. 알았어. 빨리 돌려줘.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 새론씨 오늘 저녁에 약속있어요?  아니요. 없습니다. 잘됐다. 그럼 보고서 작성을 좀 부탁해도 될까요.? 내가 급하게 일이 생겨서 가야할 것 같은데. 네? 그거 주임님 일 아니에요? 그래도 내가 오늘 급한 일이 있어서 어려울 것 같네. 남아서 좀 부탁해요. 아무래도 이러한 방법은 좀 아닌 것 같아요 주임님. 머가 아니야? 내가 공손하게 부탁한다고 머 먹고 싶은거나 갖고 싶은거 있어? 그거 사주면 되는거지 아니에요. 대가를 바라는게 아니라 원래 주임님 일이잖아요. 그래서 뭐 좀 도와달라는데 말이 많니. 그렇게 회사 다녀도 돼? 그래도 이건 아닌 것 같아요. 주임님.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 친구가 나를 이용해 보장항목이 별로 없는 암보험 상품을 계약하게 했어 네? 친구가 그런 행동을 했다구요? 응 자기 실적을 올리려고 그런 행동을 했어. 믿었던 친구였는데 기분이 너무 나빠. 지금 이 상황을 바꾸기 위해 할 수 있는게 없을까요? 친구 회사에 연락을 해 볼까 해. 잘못 계약 했다고 당신이 원하는대로 일이 풀렸으면 좋겠어요
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 어 아가씨 잠깐 스돕스톱 누구세요? 아가씨 내가 요즘 좀 힘들어서 그런데 불우이웃 돕는다 생각하고 만원짜리 몇장만 좀 꺼내줘봐 왜 이러세요 왜 이러긴 아가씨는 도덕심이라곤 없어? 네 이웃을 사랑하라 몰라? 지금 부도덕 저지르고 있는게 누군데요. 이게 진짜 맞고 줄래 그냥 줄래 때리기 전에 좋은 말로 할래 달라니까 이 돈 진짜 저한테 소중한 돈이에요 이러지 마세요 잔말 말고 빨리 내놔 드릴테니 저 좀 보내주세요
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 야 내꺼 겁나 맛없어 내거도 그래 여기 개별로다 그니까 여기 리뷰 안좋은 이유가 있었네 내가 별로일 것 같다 그랬지 다신 오지 말자 그래 내가 어리석었네 그냥 저기나 갈걸 진짜 왜 이렇게 덮밥 잘하는데가 없지 이 주변엔 그니까 내가 집에서 만든거보다 맛이 없는게 말이 되냐고 우리가 가게 하나 차리자 콜 우리가 원탑 먹을듯 인정
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 내 이름 불러봐. 기. 기. 기.기철.아 내 이름이 기기기기철이냐? 제대로 불러! 기. 기. 야! 말더듬이! 똑바로 말 못해? 미. 미.안 야! 장애인! 너 말 한 번 더듬을 때마다 한 대씩이다? 왜.? 왜긴 네 목소리만 들어도 열불 터지니까 그렇지. 미. 미. 안
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 입어보시니 어떠세요 손님? 다 별로네 여기 옷이 다 왜이래? 그럼 어떤 옷을 원하시나요? 아니 그걸 아직도 파악 못했어? 옷가게 직원이 뭔 일을 이딴식으로 해! 죄송합니다 손님 근데 원하는걸 말해주서야 야 너 뭔데 눈을 똑바로 뜨고 나한테 이래라 저래라야? 아니 저 손님 지금 10벌 넘게 입어보셨는데 야 너 몇 살이야? 어디서 알바 주제에! 너 내가 누군지 알아? 죄송합니다 진정하세요 손님 매니저 불러와 너 가고 매니저 불러!
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 최대리 옷 샀어? 네!  또 똑같은 거므스레한 옷이네.  하하.이런 게 좋네요. 좀 화사하게 입어보지 그래 그래도 나름 깔끔한 옷으로 샀는데. 깔끔이 문제가 아니라 보는 재미도 있게 어우 강부장. 요즘 젊은 사람들 그런 말 하면 싫어해 하 그치? 내가 실수를 했네 원 아닙니다.하하 무슨 말도 못하는 세상에서 입을 나불댔구만. 하하
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 야 이리와봐 왜.왜불러. 너는 친구가 부르는데 가봐야지 왜 부르냐고 물어보면 어떻게 해 미.미안.왔어. 애들아 성적표 나왔잖아. 얘 성적 궁금하지 않아? 그러지 마.내 성적.공개하지 마. 공걔하지마아 크크크크 말투 진짜 웃겨. 왜 성적 안좋아? 그.그게. 말 못하는거보면 성적 더 떨어졌나보네? 이렇게 나오니까 더 궁금하다 하지마.진짜로. 햬지마 얘 진짜 웃겨 성적표 어딨냐?
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 나 사고쳤어. 갑자기 무슨소리야 아 몰라. 걍 돈 좀 줘봐. 입막아야 하니까. 아니 갑자기 그게 무슨 소리야! 아!! 그냥 사고 쳤으니까 돈 달라고!!!!! 내용이 뭐가 중요해 내가 돈이 필요하다고!!! 무슨 사고를 친건지 알아야 돈을 주든 말든하지!! 무슨짓을 한거야!!! 몰카찍다 걸렸다!!! 재수가 없을라니까 그년이 합의 안해주면 빨간줄 걸린다고!! 합의하게 돈달라고! 너 진짜 미쳤어?!?! 씨발 내가 몰카 좀 찍었을 수도 있지 돈 줄거야 말거야!!! 몰카라니 너 똑바로 이야기해 니가 찍은거 맞아? 안걸렸으면 이러고 있겠냐고!! 아 어쩔거야 나 빨간줄 그이게 걍 냅둬?! 어? 합의포기하고 이대로 빨간 줄 끄일까?! 돈 줄거야 말거야!!!!!
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 내가 너한테 얼마나 잘했는데. 술만 마시면 욕하고 때리고. 내가 취해서 그랬어.  그게 니 본성이야. 말 다 했어? 어. 헤어져. 안 돼. 너 없으면 나 못 살아. 나 죽는 꼴 보고 싶어? 죽으려면 몰래 죽어. 광고하지 말고. 너 진짜 사람 미치게 한다. 한번 더 헤어지자는 말 하면 쥐도 새도 모르게 죽여버릴줄 알아. 이거 놔!
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 마스크써주세요 공공장소입니다 니가뭔데 쓰라마라야 코로나로 예민한때에 우리모두 조심해야 합니다 백신맞아서 안써도돼 돌파감염도 있으니 주의해주세요 야 참견하지마 여기 제가하나드릴게요 나사실 코로나 환자인데 너같은것들 코로나걸리라고 안쓰는건데 옮아라 너는 코로나걸려 죽을꺼야 보건당국에 신고할게요
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 저 그만좀 하시면 안될까요 야 니가 만져도 된다고 거의 이미 합의가 된상태야 만약 경찰한테 신고 하면 그날 니 맞아 죽는줄알아라 네 알겠습니다. 야 안되겠어 그냥 살려두면 신고할게 뻔해 그래 안되겠다  살려주세요. 진짜 다시 경고 한다. 신고 하면 죽는다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 거지 왔네 나 거지 아니야 맞잖아 너네 아빠 어제 노가다 하는거 봤어 헐 진짜? 니가뭔데! 아니 난그냥 본걸 말하는거야 그거 하루종일 일하면 얼마 받어? 하루 한 끼는 먹고 살 수 있어? 야야 얘 운다! 찐따새끼
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 지금 사장딸 없어서 에어팟끼고 동영상 보고 있어 사장 심부름 간다고 갔는데 아직도  걔 땡땡이치네  바로 집갔을수도 있고  하 상상하니까  열받네 아냐 오늘 금요일이잖아 우리 즐겁게 지내자 알겠엉
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 넌 좀 그냥 죽어 내가 뭘 그렇게 잘못했는데 그냥 꼴뵈기 싫어 이유라도 물어보자 그냥 장난이지 그게 장난이야? 재밌잖아 이상한 헛소문부터 시작해서 죽으라고 하는 게 장난 이냐고 나한텐 장난인데 재밌음 그만해 이제 그냥 맞자 넌
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 갬성 국 굳 왜 그래 나한테 엥 뭐가아 뻥치지 말라니 이 반응은 뭐지 그냥 인터넷에 도는 짤 같았어 입맛감퇴짤 짤 제조기인가 멋졍 머래 나 곧 노래하러 나간다 지금 백스테이지임 오롯
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 돈 내놔 왜? 당신이 뺑소니 범인이라는 것 알고 있어 헉 그걸!! 그러니 범인이라고 말하기 전에 내놔 1000만원이면 되나? 그걸론 어림 없지 2000만원 내놔 알았어 그럼 각서 써 어 다신 이 일로 찾아오는 일은 없어야 해
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 어 저기좀봐 장애인이다. 절뚝거리는거 개웃기네. 자기 갈 길 갑시다. 왜? 웃지도 못해? 제 기분이 나쁘잖아요. 나는 기분 좋은데? 내맘이야. 에휴 방금 한숨쉬었니? 장애인주제에 감히 똑같은 사람인데 말 좀 가려서 하세요. 어떻게 똑같니 너랑 나랑. 그냥 제발좀 갈 길 가자구요.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 자네는 정말 할 줄 아는게 뭔가? 죄송합니다. 좀 더 잘하겠습니다. 이래서 대학 나온 사람은 제대로 된게 없다니깐. 한번만 더 기회를 주십시오. 기회를 준다고 그 병신같은 아이디어가 바뀌기나 하겠어? 관 둬 제가 좀 더 노력하겠습니다. 앞으로 퇴근시간을 늦출거니 그렇게 알아. 그렇게까지 하셔야합니까? 질이 모자라면 양으로 승부보는건 당연하지 안그래? .알겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 지금 당장 책상 위에 올려진 약 먹어  어떤 약물인지 확인 되지 않아 먹을 수 없습니다.  빨리 약 먹으라고 !  도대체 왜 먹으라는 거죠?  쓰레기 같은 새끼가 먹으라면 먹으면 되지 말이 많아. 니 집 주소 알고 있어. 자꾸 이런식으로 나오면 직접 찾아가서 죽여버릴거야.  뭐라고 ? 제발 그만해  아주 고통스럽게 칼로 죽여버릴거야.  왜 계속 이러는거야.  칼로 죽이든 약먹여서 죽이든 당장 죽여버릴거야.  너 협박죄로 고소 할 거고 약도 절대 먹지 않아.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 곽두팔. 드디어 잡았다.  누가 꼰질렀어? 어떤 새끼야?  어휴. 누구겠어? 니 똘마니가 술술 불더라.  김두식. 이 자식. 죽여버릴거야!  어우. 이제 감옥 가서 콩밥 먹고 성격 좀 죽여  씨발! 너도 죽여버릴꺼야! 내가 니 배에 칼빵 쑤실거야  얼른 차에 태워.  네 알겠습니다.  개새끼야! 넌 두번째 보는 날에 얼굴을 반쪽으로 만들어줄거야. 이 더러운 짭새 새끼  입만 살아선. 얼른 데려가
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 유행복 너 어디야 누가 아직까지 집에 안 들어오래. 오늘 맞을 준비해라. 나 아빠가 너무 때리니까 무서워서 집에 안 들어갈거야. 나혼자 알아서 잘 살거니까 걱정마. 이제연락하지 마. 너만 연락 끊으면 될 거같냐? 내가 그럴줄알고 너 폰에 위치추적기 깔아뒀어. 기다려 곧 데리러 갈거니까. 오지마! 오면 바로 신고해버릴거야. 경찰에 잡혀 가고 싶으면 그렇게 해. 참나 너가 뭘 모르나본데 폰 켜서 지도 봐봐. 근처에 경찰서 있나. 나10분 뒤면 도착하니까 기다려라. 싫어. 아빠 무서워. 나 진짜 알아서 살 거니까 제발 그만 좀 포기해. 아니? 너 내 딸이야 죽어도 나랑 죽고 살아도 나랑 살아야 해. 그리고 아빠한테 허락도 안 받고 집을 나가? 기다려 오늘 정신교육 제대로 시켜줄테니까 나 좀 제발 그만 괴롭혀 나 죽을거 같단 말이야. 사는 게 너무 무서워. 그니까 내가 죽여준다고 기다리라고 몇 번을 말해야해? 내가 깔끔히 죽여준다고. 보이네? 거기서 뭐해 아빠랑 빨리 집에가자. 가까이 오지마. 제발 가까이 오지마
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 이혼하자 우리 이혼? 누구 좋자고이혼해 너 그년만나러 가지? 너의 폭언과 폭행에 지쳤어.나 만나는 사람도 없어 거짓말하지마 내가 병신같아? 그런거 아니야 정말 이제는 지쳐서 그래 누굴 만날 힘도 없어 아 그래서 조강지처 버리고 가려고? 솔직히 말하자 너 그동안 결혼생활에 충실히 안하고 매일 경마장 가고 애들 밥도 제대로 안해줬잖아 애들은 내가 키울게 아 내가 경마장 다닌건 다 우리가족 잘 되라고 다닌거지 큰건하나 하면 되니까 제발 그만해 나 이제 지쳤어 아 그럼 나 버리고 간다고? 내가 나 버리면 너랑 우리새끼들 그냥 둘거같아? 그게 무슨말이야! 너 애엄마야 정신차려 니가 지금 나를 버린다는데 내가 제정신이겠어? 나도 쫓아가서 다 죽여버리고 나도 죽을거 야
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 야 너 좀 따라와 왜요? 형이 오라면 오지 말이 많아 저 집에 가야 해요 지갑만 두고 가. 그러면 가도 돼 저 돈 없어요. 진짜에요 뒤져서 나오면 1원에 한 대다 왜 이러세요. 좋게 말하면 말을 안 들어요. 요즘 애들은 집에 보내 주세요. 제발요
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 이번 일은 너가 맡도록해. 예? 저번에도 제가 하지 않았습니까. 그래서 안할거야? 좀 힘들것 같습니다. 니 자식들 목숨이 내 손가락 하나에 달려있다는거 잊었나 보구나? 제발 제 자식들 만큼은 건들지 말아주세요. 나도 내가 니 자식들 안건드렸으면 좋겠어 예. 제가 이번일 맡겠습니다. 그래 좋은 가장이 돼야지 예.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 이게 뭐냐? 아 애니메이션 보고 있는거야. 이런걸 누가 보냐? 유치하게. 뭐? 너가 무슨 상관인데. 그러니까 너가 친구가 없는거지. 말 다 했어? 너 자꾸 기어오른다? 미안. 그냥 가주라. 나한테 오라가라 하는거야? 죽을래? 미안.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 시신을 발견했습니다. 위치가 어디시죠? 인천 영흥도인근 해상인데요, 검은색 옷을 입은 남자가 떠있는것을 발견했어요. 그럼 가까운 지상으로 시신을 가져와주실수 있나요? 네 영흥도 부둣가로 갈게요 알겠습니다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 머 그건 자기가 알아서 하겠죠 저번에 백만원 자기가 전화해야되는거아냥 아니 그쪽에서 합의보자고 연락이 오지 음 계속 안오면 아
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 아  아진짜짜증나 이 회사 진짜가지가지한다 왜 개월에한번씩 자신의 성과를 정리해서 어필하래 뭔소리여 아근데진짜 얼마나 준다고 이제 어필할때가 되셨나요 아진짜하기싫엌에바야
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 여부 안녕 오늘도 너무 행복했어 조심히 들어가요 여부야다 여뷰 바보 집 잘들어가써 이모티콘 넹 여뷰 나두 오늘 너무 행복해써 사랑해 나듀 나 사랑해 좋겟당
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 아가씨 집이어디야? 왜그러세요 내가 집까지 태워줄게.타 저 혼자 갈수 있어요 소리지르면 죽는다 죄송한데 저지금 통화중이라 녹음되요 전화 당장끊어.안그럼 핸드폰이랑 같이 니 팔도 박살내버릴테니깐. 살려주세요 당장 따라와! 이러지 마세요
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 어이 김대리 자네 뭐하고 있나? 옙 최부장님 어제 말씀하신 리포트 작성중입니다 아니 대리나 달고 아직도 그런 센스가 없어? 예.? 아침에 출근할때 우리 마실것들 사와야 되는거 아니야? 아 제가 오늘 지각 할것같아서 깜박했습니다 죄송합니다. 죄송하면 다야? 회사 짤리고 싶어? 회장님 아들이랑 나랑 친구인거 까먹었어?? 죄송합니다. 정신 바짝 차리겠습니다. 하여간에 빠져가지고 당장 카페가서 커피 5분내로 사와 넵 빠르게 준비하겠습니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 나 요즘 살 개쪘다 그래보임 뭐 이 새끼가 몇 키로 쪘는데 몰라 한 오키로 찌지 않았을까 맨날 처먹고 운동도 안하니까 살찌지 돼지야 빡치는데 팩트라 할말이 없네 그만 처먹고 나가서 좀 뛰어라 뱃살 극혐 아 이새끼는 말라서 개부럽네 개꿀
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야! 너좀저리가 왜그러니 너만보면 신경질나 바보같이 뭐하냐? 좀심한거아냐? 너같은 찐따는 없어지면 좋겠다 난 잘못한거없는데 넌 그냥 우리반에서 존재자체가 짜증이야 내가 어떻게 하면 되는데 그냥 내눈에서 사라져버려라 으이구 찐따 미안하다
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 아가야 너 원래 일처리 이런식으로 하냐? 죄송합니다 뭐가 죄송한데? 죄송합니다 대답 똑바로 안해? 죽고싶어? 다음부터는 이런 실수하지 않겠습니다. 정신차려라 어? 이러다 너 모가지가 먼저 날아가는수가 있어. 네 명심하겠습니다. 한번 더 이러면 너네 집 불살라버릴거야. 가족들 타죽는꼴 보고싶으면 그런식으로 해라. 절대 그런일 없을겁니다. 죄송합니다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 야 너 이름이 뭐냐? 김지호. 얘 생긴거 장애인같네. 응? 응? 응이라고 했냐? 아.아냐. 아니긴 뭐가 아니야. 내가 잘못 들은거냐? 미안. 얘 진짜 장애인 맞네. 아니야. 너 오늘부터 내가 찍었다. 마음에 안드는 놈. 미안해. 넌 큰일났다. 장애인 새끼야
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 회사에서 성희롱 타깃이 된 것 같아서 우울해. 직장 내 성희롱 때문에 우울하시군요. 좀 더 이야기 해 주시겠어요? 다른 직원들이 옆자리 직원을 성희롱 하는 게 보여서 도와줬더니 이번엔 내가 타깃이 되었어. 어떻게 하면 성희롱 문제를 해결할 수 있을까요? 내일 직장 내 성희롱 관련 담당자를 찾아가봐야겠어. 일이 잘 풀려서 우울한 기분이 나아지면 좋겠어요.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 우리 헤어졌잖아. 이제 그만해.  제발.한번만 더 기회를 줘.  저번에도 그랬다가 나 때렸잖아.  이번이 마지막이야.진짜 이번에도 그러면 더이상안올게.  이제 니말 못믿겠어.그만하자  나 죽는거 보고싶어? 아님 널 죽일까?  뭐라고??? 미쳤어? 안가면 신고할게.  신고? 그 전에 내가 죽든 니가죽든 하자.  그만해 !! 아악  이렇게 맞을 줄 알았으면 내말 들었어야지.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 아 아 마이크 테스트 빠가야 5초 내로 튀어온나.  부르셨습니까?  야 미쳤냐? 커피에 설탕이 0.000115 파운드 더 들어가 있잖아. 나 당뇨병 걸리라고 일부로 그런 거지?  아닙니다.  근데 이 자식이 또. 너는 늘 그렇지만 말투부터 띠겁단 말이야. 일부로 나 기분 나쁘라고 그러는 거냐 선천적으로 그렇게 태어난 거냐?  그건 원래.  저는 원래부터 그 개념이 싸가지가 없는 놈 입니다. 그렇게 태어났으니까요. 이 말이지? 이거 순수악 같은 새끼네. 알면 고치려고 노력을 해야지. 척이라도 해야지. 넌 회사 사람들에 대한 '리스펙트'가 없어 고졸 새끼가 우리 회사 문을 두드린 것 자체가 졸라 리스펙트가 없는 거지. 가 뭔 뜻인지는 아냐?  제가 이 회사에 들어온 것은.  저능아 할당제 뭐 그런 거 아니겠냐? 아니면 면접관들 책상 밑에서 면접을 봤냐? 낄낄. 뭘 꼬라봐? 꺼져.  .나가보겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 아 개뜨거워 뭐하냐 커피 먹다가 입천장 다 데일뻔했네 졸라 뜨거 오바 떨기는 야 먹어봐 진짜 졸라 뜨겁다니까 이게 뭐가 뜨겁냐 나약한 새끼 와 이자식은 혀에 감각이 없나 저걸 어케 마시지 니가 나약한거다 더 성장해와라 아 이딴걸로 자부심 갖지 말라고 애기는 호호 불어 마셔
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 김씨 주말에 뭐하세요? 네 부장님. 저 가족들과 약속이 있습니다 어디서? 여의도요 그러면 가기 전에 내 딸좀 픽업해서 집에 내려주고  아 저는 약속이 있는데요. 아니 약속 가기 전에 잠깐 가라니까 네? 그것도 못해? 내 부탁인데? 알겠습니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 와 오늘 괜히 기분히 좋네 닐씨가 좋아서 그런가 그냥 오늘 컨디션도 좋고 날씨도 딱 좋고 걱정거리도 없고 해서 기분 짱 좋네 올 그럼 나랑 오늘 놀러갈래 영화 볼까 오 좋은데 요즘 개봉한거 있나 듄이라는 영화 개봉했던데 반지의제왕 같은 에스에프 영화인가봐 아 나 에쓰에프는 별론데 까다로운 년 그럼 이따 노래방이나 갈까 아 그래 노래방 좋다 노래방 가자 애들 더 불러야지 누구 부를까? 그냥 너가 부르고 싶은 애들 아무나 불러 그럼 수영이랑 명현이 부른다 그래 학교 끝나고 바로 갈거지 응 그러자
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 이새끼 이것도 틀려? 틀린건가? 바보자식. 이래가지고 대학은 가겠니 공부열심히하고있어 열심히만하면돼? 머리가나쁘잖아.누굴닮아서 부모욕은 하지마 어쭈 죽을래? 미안 넌진짜 세상어찌살려고. 한심하다 미안해
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 돈 있냐 응 아니 없는데 새끼 돈 좀 들고 다녀라 형이 쏠게 피시방 가자 오 웬일이지 이 새끼가 용돈받았다 가자 그래 나야 땡큐지  담엔 너가 쏴 씨발 알았냐 봐서 이 새끼가 진짜 확 꺼져 쫌
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 담임이랑 무슨 얘기 한거야? 설마 너 이른건 아니지? 아니 그냥 진로 상담한거야. 그걸 무슨수로 믿어? 너. 거짓말 한 거면 길가다 조심 좀 해야할거야. 그게 무슨 뜻이야? 뭐 왜 길에 위험한게 얼마나 많냐. 지금 나 협박하는거야? 글쎄 우리 아빠 이름 대면 가벼운 접촉사고든 취객이랑 시비 같은 적당한 이유로 경찰도 넘어갈거라 이거지. 나 안 일렀어. 알 일렀다고! 믿어도 되는거지? 물어봐서 니가 거짓말한 거면 다리 한두개쯤 부러질 각오는 해라? 아니면. 목을 부러뜨려줄까? . 대체 자꾸 날 괴롭히는 이유가 뭐야!
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 길동씨 어디까지 했어? 아직 하는 중입니다 아직도? 왜 이렇게 일을 못해 죄송합니다 하. 정말 죄송해요 아니 내가 길동씨 좋으라고 이러는 거야 빨리해 진짜 죄송합니다 누가 고졸아니랄까봐. 네.? 죄송합니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 이거 재연씨 아이디어인가? 네 그렇습니다. 아니지 아니지. 무슨 말씀이신지? 지금부터는 내 아이디어지. 내가 사수잖아. 그렇지만 제가 초안부터 다 작성했는데. 지금 말대꾸 하는건가? 아닙니다. 상사가 키워준 은혜도 모르고 이러면 안되지. 그렇지만. 어쨌든 이 기획안 내 이름으로 올릴거다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 이봐요 아가씨 이거 환불좀 해줘  아 환불하시려면 구매하셨던 종이들 옷걸이들 다 들고오셔야합니다  한번 입어보다가 종이가 살짝 찢어져서 그래  다시 팔아야하는 옷이라서 전 상품이 다 있어야해요  아 종이 안에 넣은거 티도 안나더만  죄송합니다 규정이 그래서요  아니 규정맞춰서 살 정도로 그렇게 갑갑해서 어떡해?  저도 알바생이라서 업체 내규가 그래서요. 죄송합니다  하 참 됐어 됐고 안입을거니까 버리던가 맘대로하고 본사에다가 컴플레인 걸어야겠다  고객님 잠시만 점장님께 여쭤보기라도 할게요 잠시만 기다려주세요  아니 되는데 안된다고 한거야? 아가씨 알바생 맞아? 일머리가 그리없어서 어떡해?  점장님 불러올게요 죄송합니다
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 아효 덥네. 저 조금만 쉬겠습니다. 야 선풍기 가져간다. 너 어쩌피 쉴 거라며. 네.? 저 지금 두 시간동안 에어컨은 커녕 선풍기도 없이 땡볕에서 사람들 코로나 검사 했어요. 잠시 쉴 때 선풍기 쓰면 안될까요? 어 안돼. 너 쓰라고 가져다 둔 선풍기 아니야. 그리고 뭐 검사해주는 게 힘들어? 사람들 문진하고 그러는 게 더 힘들어. 문진실에는 에어컨 돌잖아요. 검사소에는 선풍기도 못 킨단 말이에요. 저 진짜 너무 더워서 쓰러질거 같아요. 한 번만 양보해주세요. 야 꾀병 부리지마. 뭘 선풍기 하나 안 쐰다고 쓰러지냐? 그럼 그 방역복을 벗어 더우면. 지금 코로나 검사 하고 있는데 여기서 방역복을 벗으라구요.? 그럼 바로 감염될 확률 높은거 모르세요? 지금까지 검사하고 왔는데 앉아계셨으면서 선풍기 하나 양보 못 해주시나요? 야 그니까 내가 왜 너한테 양보해줘야 하는데. 누가 코로나 병원 전담 지원하래? 너가 지원해놓고 왜 유세야. 하는거 없이 주 4회밖에 출근 안 하면서 대우는 엄청 받고 싶어하네. 너 일하는거 보면 급여 안 받아도 될 정도로 설렁설렁해 몰라? 제가 하루 코로나 검사 거의 다 하는데 그게 왜 설렁설렁인가요? 넌 일하는 모습이 진짜 마음에 안들어. 다 설렁설렁 하는거 같고 야 그리고 니 선배는 저렇게 일 하고 있는데 넌 쉬려고 해? 아주 기강이 제대로 안 잡혔네. 돈 받고 일하면 정해진 휴식시간 이외에는 쉴 생각 하지마. 점심시간 외에는 검사에만 계속 집중하라고.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 어이 아가씨 몸매 이쁘네 네? 딱 붙는 옷에 짧은 치마 크흐 섹시하다 아 남자친구한테 사랑 많이 받겠어 그만하세요 기분나빠요. 뭐가 기분나빠 칭찬하는건데 내가 조금만 어렸어도 아가씨 만났을텐데 그만하시라구요 .! 이런 말 듣기싫으면 그렇게 입지 말던가 지가 그렇게 나 보세요 하는 복장이면서 아 .불쾌해요
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 김쌤 학부모들 클레임 들어왔어 어떻게 할 거야? 저는 정말 학생을 때리지 않았습니다. 그런데 애는 왜 선생님한테 맞았다고 하죠? 애가 거짓말이라도 한다는 건가요? 학부모가 원하는거는 다 해주세요. 네? 제가 왜 그래야 하죠? 이 학생 아빠가 교육감이에요. 회사잘리고 싶어요? 네? 저는 결백합니다 교장선생님. 그건 모르겠고 우리한테까지 타격을 입을 수는 없지 않나? 학생 안때렸습니다. 정말이에요. 무릎꿇고 가서 사과하고 용서받아 그래야 학교에서 안짤리지. 아.결백합니다 교장선생님.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 최주임 오늘 저녁 약속있어?? 박과장님! 아니요 없어요 그럼 오늘 둘이서 술한잔 어때? 네?? 아니요. 괜찮습니다. 집에 가보겠습니다. 어 왜왜!! 그럼 최주임 집에서 어때? 여자가 사는 자취방은 어떤지 궁금하기도 하고  괜찮습니다. 그래?!! 오늘 야근할생각하고! 최주임 이 프로젝트좀 완성해봐! 박과장님 제가 해야할 업무는 다 끝냈고 이건 박과장님 업무인데 아닌가요? 선임이 일을 주면 할수도 있지! 그래서 못하겠다고? 직장의 매운맛을 덜 봤구나? 이건 박과장님 제안 거부에 따른 보복조치 라고 느껴지는데요? 요즘젊은이는 까탈스럽고 튕기는것도 많아. 너같은 직원은 같이 일하기 힘든거 아니? 말씀이 심하시네요!
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 내 지갑 너가 훔쳤니? 그게 무슨말이야? 아니 너가 전에 내 지갑보고 이쁘다했잖아 그래서 너가 훔친 줄 알았지 나 아닌데. 아그래 ? 근데 왜 다른애가 너가 내 지갑을 훔치는걸 봤다고 할까? 아 맞다 너 집 가난하지? 그래서 도벽있는건가 ? 나.나.진짜아니야 !! 억울해 . 그럼 지갑이 뭐 발이라도 달렸니 ?
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# ...
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 미안합니다. 지금 우리 딸을 살려야 해요.  그래도 이건.!  죽지 않을 만큼만 뽑겠습니다.  지금 식칼을 들고 그런 말을 하면 내가 어떻게 믿습니까?  믿어주세요. 제가 너무 급합니다.  이렇게 뽑는다고 당신 딸 못 살려요!  당신이 어떻게 알아요? 우리 딸 살릴 수 있으면 몇 명이라도 죽일 수 있습니다.  이 미친 놈!!!
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 이대리 당신은 이것밖에 못하나?  죄송합니다. 그러니까 당신이 43인데도 대리인거야 말이 심하십니다. 아니 내가 틀린말이라도 했어?? 대리가 일처리를 똑바로 하면 내가 이런 말을 안할거 아니야 죄송합니다. 제가 요즘 신경쓰이는 일이 생겨서. 어휴 이래서 내가 들어보지도 못한 출신인 사람은 들여보는게 아니라고 회장님한테 말했는데. 어휴 이대리 또 무슨일이야 어제 딸이랑 싸웠다더니 회사에서 또 뭔일이야?? 어휴 그 아빠에 그 딸이구만 딱봐도 이대리 문제겠지 . 가보겠습니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 내가 여기 12년 다닌 것도 아니고 자그마치 10년을 다녔어!!! 고객님 그래도 다 반 이상을 사용하시고 바꿔 달라는 건 아니잖아요. 이 새끼가 말귀를 못 알아듣네. 우리 여기 라고!!! 고객님 아시잖아요 전에도 오셔서 한번 바꿔 드렸을 떄 다음에는 안된다고 말씀 드렸잖아요. 아니 왜 한번은 되고 두번은 안되!!! 당장 바꿔주던지 환불해 내!!! 너 말고 니 윗사람 나오라그래!! 너 같은거랑 말하기 싫어!! 니가 직장을 짤려 봐야 정신차리지!!! 고객님 왜그러세요 저번에도 이러셔서 제가 얼마나 곤란했다구요. 제 사비로 대신 메꿔서 바꿔드렸잖아요. 그럼 요번에도 바꿔줘 니가 메꾸는 돈보다 우리가 쓰는 돈이 더 많잖아!!! 우리가 여기서 쓰는 돈이 얼만데 이것도 못해줘?
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 오빠 나 생일선물 뭐 해줄거야 뭐 받고싶어 나 명품빽사줘 아 내가 어떻게 명품백을 사주냐 장난이야 나랑 분위기 좋은 식당가자 음 그럼 강남에 저번 거기갈까 저번 거기가 어디지 그 강남역 근처에 있던곳인데 이름이 기억안나네 하여튼 막 스테이크팔고 이런곳 가고싶어 그래 내가 한번 알아볼께
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 서류를 이따위로 작성해 죄송합니다 이따위로 쓸 거면 회사 그만둬 민폐야 어디를 고쳐야하는지 알려주시면 바로 수정하겠습니다 뭘 알려줘 스스로 해야지 머리가 돌이니까 제대로 안 돌아가는 거지 팀장님 말씀이 너무 심하세요 뭘 심해 너같은 돌대가리를 데리고 있다는 데 창피하다 너무하세요 뭐가 너무해 이 돌대가리야 돌대가리야 당장 그만두라고 항상 이유는 설명 안해주시고 .
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 난 네 비밀을 알고있어  뭐라고?  가 죽은 그날 같이있었던거 알아  같이 있긴했지만 그뒤에 걔가 그렇게 될지 몰랐어  거짓말 하지마 너가 그자리에 같이있는걸 봤어  그래서? 증언이라도 할거야?  그건 너가 하기에 달렸지  나한테 뭘원하는데?  오늘부터 나랑 사귀는척해  그래 알겠어
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 김인턴 이리 와보게 네 과장님 내가 자네를 왜 불렀는지 알겠나? 잘 모르겠습니다 왜 그러십니까? 자네한테 맡긴 일이 잘 안 풀려서 내가 혼나게 생겼잖나! 아 죄송합니다 자네는 벙어리에 곱추같이 걸어다니고 할 수 있는게 뭔가? 죄송합니다. 더 노력하겠습니다. 내일까지 그 똥머리 굴려서 수정안 제출하게 그 전까진 야근이야. 알겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 여보세요 네 부장님 어 지금 안 바쁘지? 네 용무 있으세요? 어 아니 집에 애가 혼자 있는데 봐줄사람이 없네 네? 그래서요 애 좀 봐달라고 어차피 할 것도 없잖아 아니 아무리 그래도 애를 봐주다뇨 부장님 뭐? 회사생활 편하지 요즘? 빨리 가봐! 하. 싫다고 말 했습니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 짠 얼마 전에 생일이 없다며 호박 초콜릿네 어떻게 알았어 민성이가 그러더라 늦게 알았네 생일 축하해 아니야 괜찮아 고마워 끝나고 뭐 해 응 딱히 일정은 없어 왜 그럼 끝나고 밥 먹자 내가 사줄게 좋아 어디 갈까요 근처 파스타집 있던데 어때 2층에 있는 거 거기 가성비도 좋고 맛있대 오케이 거기로 가자
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 같이 게임하게 몇 번 방으로 들어와 나 오늘은 학원 가야 돼서 못 들어 갈 것 같아 까불지 말고 좋은 말로 할 때 들어와라 정말이야 야 오늘은 학원 가야 해 그럼 내 아이템은 누가 결제해주냐 오늘은 나 용돈 못 받았어 그건 나 알바 아니고 저번에도 사줬잖아 그땐 그때 고 이번에도 부탁 좀 하자 좋은 말로 할 때 이번이 진짜 마지막이야
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 마스크좀 써주세요. 네? 여기는 사람들 통행이 많고 공공장소니까 마스크좀 써달라구요. 니가 뭔데 이래라 저래야? 좋은말로 할때 마스크 써라. 싫은데 니가 뭔데 참견이야? 마스크 안쓰면 니 안면 다 칼로 찢어버린다. 내가 왜 니말대로 해야되는데? 야 가까이 와봐. 얼굴 찢어버리게. 죽고 싶어? 니가 먼데 내얼굴을 찢네 마네야?
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 이사원은 조금 있다가 시간 좀 내게. 맡기실 업무가 있으신가요? 내가 조금 있다가 딸 학교에 좀 들러야하거든. 운전 면허는 있지? 네. 면허는 있습니다. 그러면 나 좀 데려다 주게. 올 때도 부탁해. 하지만 팀장님. 오늘 아직 할 업무가 많습니다. 지금까지 안하고 뭐했어? 하기 싫어? 아. 아닙니다. 지금 가서 커피도 좀 사와. 난 아이스 아메리카노로 갖다줘. 돈은 나중에 줄게. 알겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 어? 누가 못난 새끼지? 엥? 누가 못난 새끼일까? 설마 머리 큰 다현이는 아니겠지? 뭐야 갑자기 나한테 왜 그래? 네가 먼저 내 뒤 땀화를 깠잖아 뻔뻔한 새끼야 나보고 양아치라고 그치 재형아 설마 너 날 배신했어? 저 그게 아니 난 그런적이 없는. 내 친구가 얘 친구인데 내가 뒷조사를 좀 했지 그 친구가 누구인데 대체 내가 그걸 말할 것 같냐? 암튼 너희들도 내 뒤에서 욕 할 생각하지 마 그리고 너희는 앞으로 왕따당할 준비하고
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 아 저번에 말했던 우리 팀 과장님 있잖아 진짜 개꼰대야 왜 또 지랄했어 어 회사에서 슬리퍼 질질끌지말라고 괜히 시비걸잖아 그러면서 원래 다른 회사는 슬리퍼 신는것도 안된다나 뭐라나 아 개빡쳐 아 진짜 어딜가나 꼰대는 있구나 어쩌겠냐 아 진짜 회사 휴가 한 이주일 내고 싶다 그렇게 길게 휴가 내면 뭐할껀데 여행 음 글쎄 여행보다도 일단 그냥 집에서 푹 쉬면서 넷플릭스 보고 잠 늦게까지 자고 힐링하고 싶다 주말에 그렇게 하면 되잖아 아 뭔가 주말은 그렇게 잘 안돼 부모님도 뵈러 가야하고 여자친구도 만나야하고 은근 바쁘다니까 가끔 친구도 만나야지 하긴 제대로 쉬려면 길게 휴가를 내야 맘 편하게 쉬지 그니까 그런거 생각하면 군대가 편했다니까 다시 입대해 그럼 꺼져 제발
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 어이 형씨 네? 내가 담배가 똑 떨어졌는데 있으면 하나 줘봐 저도 이게 돛대인데요 형씨 딱봐도 나보다 어려보이는데 그렇게 어릴때 담배피면 폐에 구멍나 . 아저씨나 피지마세요 얼씨구? 겁대가리 상실했네? 가보겠습니다 가긴 어딜가 맞고 줄래 그냥 줄래 아휴 그냥 드릴게요 좀 떨어지세요
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 김사원 주말에 일 없지? 약속 있나?  아 네! 팀장님. 이번 주말에 여자친구 만나기로 했습니다.  여자친구? 여자친구는 일요일날 보고 나랑 금토 배낚시나하러 가자고  아 죄송합니다. 여자친구랑 약속 예전부터 잡은거여서요.  에이 약속은. 나 싫어해서 그러지? 이번에 인사고과 있는데 말이야 으흠  진짜 아닙니다. 매주 토요일마다 여자친구랑 만나고 있어서요. 죄송합니다.  민수씨. 너무 개인주의야. 이 직장생활이 말이야. 회사에서 일하는게 전부가 아니야  죄송합니다. 안될 것 같습니다.  죄송은. 그냥 나랑 여행가기 싫다고 말해. 정을 쌓으려고 하는데 이런식으로 거절을 하네 요즘 것들은 말이야. 회사가 일잘하고 일만하려고 오는게 아닐텐데. 쯧쯧  죄송합니다. 더 열심히 하겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 김쌤! 나좀봐 네? 도데체 오늘 키즈노트에 어떻게 썼가니 태화어머니가 난리셔? 아 태화가 다른 친구들을 좀 문다고 주의 부탁드린다고. 혹시나 눈 돌리면 사고날수도있다고 태화어머니가 얼마나 기분이 상했는지 나한테 전화하셔서 이십분을 다다다하시더라? . 네.죄송합니다 아니 그런걸 그렇게 직접적으로 말할 필요가 있을까? 적당히 돌려서 좀 하지 그랬어 .하지만 태화가 한두번도 아니고 나도 알아 안다고 하지만 적당히 삼키고 숨기고 해야지 그걸 일일이 미주알 고주알 다 말하면 학부모들 신경쓰여하는거 몰라? 그러다가 소문이라도 안좋게 나면 어쩌려고 그래 죄송합니다. 다음부터는 주의하겠습니다
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 언니 내 지갑에 있던 5만원 혹시 언니가 가져갔어.? 어. 왜? 나 오늘 친구들이랑 약속있는데. 나도 약속있어 그럼 언니가 엄마한테 말씀드려서 받으면 되잖아. 너 지금 말 대꾸 하냐? 내가 돈 좀 가져갈 수 있지. 짜증나게 쫑알거리네 그렇지만 나도 오늘 약속 있어서 돈이 필요해. 그럼 니가 엄마한테 다시 받으면 되겠네. 그만 귀찮게 해. 내가 니 부탁으로 엄마한테 말 안한 니 비밀이 어디 한두가지냐? 확 말해? 왜 얘기가 그렇게 돼. 아 진짜 짜증나게. 너도 이렇게 너만 편하려고 하는데 나도 니 편의 봐 줄 필요가 없지. 말한다? 아니야.내가 엄마한테 용돈 다시 받을게. 야 그럼 받는김에 더 5만원 받아와. 나 좀 부족하니까. 같은 말 반복하게 하지마라 알겠어.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 길동님 어머니 되시나요 ? 누구시죠 ? 여기는 길동병원입니다 지금 길동님께서 교통사고로 응급수술을 들어가셔야합니다 네 ? 무슨 소리세요 우리 아들이 거기왜  매우 긴급한 상황인데 수술비를 먼저 넣어주셔야 일순위로 수술 진행되는 부분입니다 지금 당장 갈께요 수술먼저 시켜주세요  네 당장오시고 계좌 번호 보내오니 당장 입금하세요 5분내로 입금 확인안되면 다른 분 먼저 수술장 들어갑니다 병원도 곧 바로 오시구여 네네 살려만 주세요 네 알겠습니다 힘써보겠습니다 수술비가 여간 비싼게 아니니 . 감사합니다 감사합니다
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 오늘도 야근이야 그래 짜증 나서 나한테 일 다 시키고 지금 퇴근한다 그러기로 유명하잖아 한 두 번이나 조그만한 실수에 겁나 성질 내 누구랑 할 줄 몰라서 어쩌겠냐 회사에서 그렇다고 대놓고 경기 수도 없고 하루만 날 잡고 야탑 하고 싶다 그만두게 될 때 마지막 날에 해 아직 속 시원하게 다 풀어 근데 속 다 풀면 죽어 그러네 목숨이 연락이라도 못 살아 나을 듯 진짜 그래도 오래 살겠네 욕 하도 먹어서
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 내일 모레까지 천만원 더 준비해주세요 네? 이번달은 이미 원하시는 금액 다 맞춰드렸잖아요 우리 사이 금액에 상한가가 어딨습니까 그때그때 상황에 다른거 아시잖아요 저 정말 이번달에 드린게 다에요. 현금 더 만들래도 만들 수가 없습니다 정말이에요 이제 겨우 자리 잡은 딸자식 앞길 망가뜨리고 싶나보네? 한번만 살려주십쇼 제 딸만은 건들지 말아주십쇼. 매번 이렇게 부탁만 하면 내가 어떻게 들어주나 다음달에 어떻게든 채워볼테니 이번만 살려주십쇼 제발 돈이 없으면 몸으로라도 떼워 그럼 몸뚱이 하나로 돈 벌어 먹고 살고 있습니다. 제발 이번만 좀 봐주십시오
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 자네 그 사실을 자네말고 누가 알고 있나? 네? 저밖에 모릅니다 부장님 정말인가? 다른 사람들이 알면 큰일나는 거 알지? 네.맞습니다 그런데 참 이상하지? 무슨 말씀이십니까 나는 자네한테밖에 말안했는데 어떻게 김부장도 알고있지? 좋은 정보 같이 먹자고 어제 전화왔더라고 저.저는 모르는 일입니다 자네 입이 참 가볍네 김부장한테는 얼마 받았어? 자.잘못했습니다 내가 자네같은 거 한명 쥐도새도 모르게 없애는거 일도 아닌거 알지? 돈좋아서 여기붙고 저기 붙고 박쥐같이 굴다가 좋아하는 돈 못만져보고 오늘 내일 할수도 있어 마지막 경고다
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 안녕하세요 씨 공부 잘 한다면서요 성적이 우수하다면 서요 네 아닌데요 맞다고 들었는데 왜 거짓말 하세요 아니 그렇게 잘 알지는 못해요 지금 잘난 척하는 겁니까 아니 저보다 더 잘하는 사람 많은데 이렇게 상사한테 말대꾸하는 거 보니까 자신감 있는 거 같은데 이번 프로젝트에 할일을 더 해 놓을게요 님 이건 좀 아닌 거 같은데요 할일을 더 추가 하기 전에 그 입 다무세요 네 저 공부 잘하고 성적도 우수합니다 그래서 계속 말을 해야겠는데요
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 희주씨 네???  아침에 좀 일찍 오지  네? 지금도 20분전에오는데요 아니 좀 일찍 와서 바닥도 닦고 그래 . 청소 아주머님이 계시는데 제가 굳이 그래야할까요?  아니 . 정말 말귀 못알아먹네 막내면 막내답게 사무실 챙기는 시늉좀 해야지  네??? 납득이 잘안되는데요 원래 사회생활은 납득안되는 일이 넘쳐 집안처럼 편안하게 지내려고했니? .네.  알아들었으면 내일부터 더 일찍와서 부장님 책상좀 닦고 그래 바닥도 쓸고
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 야. 보이냐? 개멋있지. 오백만원짜리 시계야. 응. 한번 만져나볼래? 아. 넌 본적도 없어서 뭐가 뭔지도 모르겠지?  불쌍해라 불쌍해. 넌 여기있으면 안되고 후원 받는데 들어가야돼. 아니야. 나도 열심히 살고 있어. 열심히 산다고 돈이 들어와? 어휴 냄새. 좀 씻고나 다녀라 . 옷도 그게 뭐냐. 너 옷 일주일동안 입지? 촌스럽긴. 아니야.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 민정아 안녕 ? 어? 어 안녕 너는 역시 아침부터 공부하고 있구나. 대단해 곧 수업시작이라 미리 준비하고 있었어. 아 맞다 이번 시간 수학시간이지. 응 근데 무슨 일 있어? 일? 있지. 너 혹시 수학 과제했니? 응 했지. 오늘까지 해오라고 하셨잖아. 그래서 말인데 내가 어제 너무 피곤해서 과제를 못하고 잤거든. 니가 한 과제 내가 좀 써야겠어. 그게 무슨말이야. 이건 내가 한 과제지. 너에게 주려고 해온 게 아니잖아. 너 학교 얌전히 다니고 싶은거 아니였어? 난 너가 그런 줄알고 너한테 아무짓도 안했는데 그래도. 내가 해온 숙제를 니가 가져가겠다는게 말이 안되잖아. 그래서 못주겠다는 거야 ? 너 끝나고 남고 싶어?  아.아니야. 알겠어.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 우리 씨는 얼굴도 예쁜데 몸매도 예쁘네 씨는 좀 보고 배워야겠다 아유 과장님 전 마음이 제일 예뻐서 그래요 얼굴도 예쁘면 좋잖아 화장도 좀 하고 신경좀써 과장님 자꾸 비교하시면 저 기분 나빠요 아 농담인데 뭘 정색하고 그래 성격이 좀 모났네 과장님 이거 직장내 괴롭힘이요 아시죠? 뭐? 신고해봐 어디! 이런 말도 못하는 그게 법이냐? 네 신고할게요 야 저 년 잘라버려 재수가 없으려니까 자르세요
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 시험에 자신이 없어서 일부러 아픈 척을 하고 학교를 안 갔어. 해방감이 들었어. 시험을 안 봐서 기분이 좋으시군요. 지금까지 시험이 나를 얼마나 옭아맸는지 알게 돼서 한국의 시험 문화에 화가 나. 화나는 감정이 나아지려면 어떻게 해야 할까요? 한국 시험 문화에 대한 분노를 시험을 대하는 즐거움으로 변화시켜야겠어. 목표대로 시험을 즐겁게 느낄 수 있게 되길 바라요.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 너가 어떡하면 나한테 이럴 수 있니? 내가 뭘 어쨌는데 도와준거 뿐이라고 도와줬다니 사람은 이렇게 만들어놓고?  내 약속과는 너무 다른데? 참 할말이 없다 이제 안할래 너가 이러면 안되는거 아니야.? 니 엄마를 위해서라면 뭐든 한다면서 이제 앞으로 얼굴 보지 말자 자꾸 이렇게 나오면 네 엄마가 위험해질 수 있어 맘대로해 니가 설마 총으로 죽이겠니 칼로 찌르겠니 이렇게 나온다 이거지 두고봐 후회하게 해주지
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 인재씨 무슨 보고서를 이따위로 씁니까 그게 무슨 말씀이세요 차장님 줄간격폰트 다 엉망이에요 아까 보고드리고 말씀하신대로 작성한건데. 다시 하겠습니다. 그럼 제가 잘못했다는 건가요 아닙니다 죄송합니다 인재씨 그렇게 안봤는데 완전 건방진 사람이구만 무슨 말씀을 그렇게 하세요 정신차리고 회사 다니세요 죄송합니다 더욱 노력하겠습니다
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 와 이거 뭐야?  새로 산 틴트  이거 비싼거 아니야?  응 백화점에서 산거야  나 한번만 발라볼래  응.? 나도 어제 사서.  싫단거야?  아니. 그래도 내꺼니까  아 그래? 그럼 너도 내꺼 써 아님 이거 내가 갖고 넌 내꺼 새거 줄게  뭐?.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 제가 뭘 그렇게 잘못했죠? 일이던 뭐던 잘하는 게 뭐가 있다고 그래? 뭘 그렇게 잘못했는지 말하시라고요. 너는 그냥 죽어버려야돼. 칼 내리세요 이런 식이면 저도 가만히 못 있습니다. 너가 하면 뭘 한다고 그래? 신고할거고 진짜 그만 하세요. 너 죽일거야
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 미연아 너 저 선배랑 친해 어 아니 친한건 아니고 그냥 가끔 얘기하는 정도 왜 저 선배 요즘 새내기들한테 겁나 찝적거린대 얼마 전에 유진이한테도 고백했다가 차였잖아 아 진짜 몰랐네 어쩐지 요즘 갑자기 친한 척 하시더라고 유진이 진짜 불편해하더라 너도 조심해 그래야겠다 요즘 왜 이렇게 이상한 사람들이 많지 그니까 사람 쉽게 믿으면 안된다는 말이 맞는거 같애 맞아 이게 이십대의 삶인가 와 우리 이십대다 히히 의식의 흐름 머야
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 영희씨 한번만 만나주세요. 저 괜찮은놈입니다 수환씨 자꾸 따라다니지 마세요 영희씨가 한번만 만나주시면 되지않습니까 저는 수환씨같은 사람 관심없습니다. 그만가주세요 영희씨 제가 정말 영희씨가 마음에 들어서 그렇습니다.  이렇게 자꾸 스토킹하면서 괴롭히지마세요 영희씨 사랑합니다. 당장 그만두세요. 더이상 스토킹하면서 괴롭히시면 경찰에 신고하겠습니다. 영희씨. 다시한번만 생각해주세요. 한번만 만나주세요 저는 수환씨같은 사람 질색입니다. 그만 가주세요
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야 박사원 너 이번 주말에 내 차 세차 좀 해라 부장님 이번 주말에 제가 약속이 있어서. 아니 너가 저번에 해준다며 맡겨만 달라며 그렇다고 하루 전에 그러시면 어떡합니까 뭐야 이거 대드는거야? 됐고 이번 주말에 무조건 해놔 아니 부장님. 이거 안해놓으면 이번 평가에서 불이익있을거야 네 알겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 안녕?? 오랜만이다 그치? 나 기억나?  아 너 고등학교때. 맞지?  아!! 맞아   그런데 왜 전화했어?  아 다른게 아니라 내가 사실 보이스피싱을 당해서. 부탁할 친구도 없더라고. 그러나 너가 생각났어.  아. 어.  정말 미안한데 돈 100만원만 빌릴 수 있을까?  응.? 그. 100만원이 적은 돈도 아니구. 미안  아 그럼 50만원이라두. 내가 정말 급해서 그래. 꼭꼭 값을께.  아. 정말 미안.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 흑흑 나 도저히 못찾아 찾아줘 거봐 디자이너들이 생각이없다니까 중국인들이 최고야 중국인좀데려다가 좋은원단으로좀 만들어주지 엠제이드사지마 물론돈없어아직 웅사지마 가방필요한데어떡해 잘좀찾아보 정말없지만 찾고말겠어 말일까지 찾아 없지만 퉁
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 안녕하세요 저는 이번에 새로온 알바생입니다 반가워요 서브웨이 알바는 처음이죠 네 빵집 아르바이트는 해봤는데 서브웨이는 처음이네요 별거 없고 비슷해요 포스는 해봤어요 네 많이 해봤어요 그러면 빵 종류랑 레시피만 설명드릴게요 감사합니다 혹시 메일주소 알려줄래요 레시피 보내드릴게요 문자로 보내드릴게요 고마워요 네 잘 부탁드려요
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 교수님 부르셨어요?  어 왔나?  무슨 일이세요?  내일 총장님이랑 김의원님이랑 식사 자리가 있는데 너가 와줘야 겠다.  네? 무슨 말씀이세요. 그런 자리 싫다고 말씀드렸잖아요.  거절하는건가? 자네 이번 졸업 논문. 별로 중요하지 않나 보지?  아. 교수님. 참석하겠습니다.  그래 잘생각했다. 김의원님은 화장 진한거 안좋아하시니까 옅게 하고 오도록.  네.  나가보게
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 서울 관악아파트인데요, 뒷 놀이터에서 한 학생이 맞고 있는거 같아요. 정확한 주소좀 알려주시겠어요? 서울특별시 관악구 신림동 244 관악아파트 뒷 놀이터요. 지금 그쪽에 학생들 몇명이 있는것 같으세요? 학생 10명 정도 있는거 같아요. 알겠습니다. 지금 그쪽으로 경찰을 보내겠습니다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 아 냄새 야 여기 어디서 하수구 냄새 안 나 ? 아우 뭐야 이 냄새? 아 얘 냄새인가 보다 아니야. 어우 얼른 맡아봐 얘 냄새인지 아 싫어 더러워 얘들아 냄새 안 나?! 아니야 나 아니야. 너가 말하니까 더 냄새나잖아 그냥 가만히 닥치고 있어
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 아가씨 이쁜데 왜 이러세요 우리랑 좀 놀까? 싫어요. 그럼 돈 좀 빌려주던가 얼마나요?? 십만원 정도?? 저 그렇게 큰 돈이 없는데요. 이 년이 죽어볼려고 환장했나? 돈 없어? 진짜 없어요
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 이거 왜 이렇게 놔! 똑바로 놓으라고 했지? 아침부터 왜 그러냐. 아니 수저통 똑바로 놓으라고 했잖아. 너 내 신경 건드리지마라. 뭐? 그거 지금 협박이야. 네가 협박을 해야 좀 알아 듣지. 안 그래? 진짜로 못 됐다. 왜? 어떻게라도 하게? 응. 넌 진짜 한 주먹거리야. 진짜 너를 남편으로 둔 건 내 최대 실수야. 한 번만 더 그 입 씨부려봐.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 오빠 나 카드값이 밀렸어 저번이 마지막이랬자나 이번에 내가 코로나로 일도 쉬구 힘들었자나 그래도 저번에 꾼돈도 아직 안갚았어 이번한번만 더 도와줘 니가 내여자친구지만 그래도 나도 힘든상황이야 대출받아야해 나는 신용불량자인데 나한테 할소리야? 나도 신불자되겠어 나 안사랑하네 이번이 마지막으로 빌려주는거야 진짜
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 원투 원투 야 똑바로 서 으 으윽 그만해 아이씨 서 있어봐 좀 아프다고! 어디서 소리를 질러? 미 미안 아. 나 귀 아픈 거 알면서. 너 일부러 그랬어? 아 아니야 미안해 야 서봐 다시 인간 샌드백 간다 원투 원투! 으윽.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 오늘 유현이형이 우리 다 모이라는데 아 그형 또 왜 몰라 술마실거 같은데 아 오늘 술 먹기 싫은데 야 형이 사줄 텐데 개꿀이지 뭘 개꿀은 먹기 싫은데 먹어야 되는데 그게 꿀이냐 그냥 즐겨 임마 하여튼 불만은 존나게 많아요 아 뭐래 진짜 짜증나게
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 저녁 먹었어 아니 오늘 뭐먹을까 오늘 집에서 라면 먹자 무슨 라면 먹을건데 열라면에 순두부 넣어먹는게 맛있대 진짜 맛있어 내 친구가 꼭 먹으래 와 그러면 오늘 꼭 먹어보자 내가 순두부랑 열라면 사갈게 그래그래 오늘 늦지 말고 들어와 응 알았어
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 지인의 말만 듣고 가입한 보험이 살펴보니 제대로 보장해주는 게 하나도 없었어. 지인의 말만 듣고 가입한 보험인데 많이 화가 나시겠어요. 지인이 나에게 사기를 친 걸까? 노후준비를 해야 하는데 정말 막막해. 이 상황을 해결하기 위해 무엇을 할 수 있을까요? 보험사에 전화해서 해지하고 앞으로는 잘 알아보고 보험에 가입해야겠어. 보험사에 전화해서 문제가 해결되었으면 좋겠네요.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 너 어제 집에 바로 안 들어갔지? 어떻게 알았어? 내가 눈이 좋아 왜 묻는건데? 너희 부모님이 아시면 어떨까? 절대 안돼! 그럼 내 부탁 하나만 들어줄래 그걸 내가 왜! 그럼 나 지금 부모님한테 전화하고 알았어 부탁이 뭔데
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 철수야 말 들어야지 싫은데 철밥통 선생아 너 선생님한테 말버릇이 뭐야 야 내가 너말을 왜 들어야 해? 너 때문에 애들이 피해보고 있잖아 지금 너 때문에 얘들이 집에 못가는거 안보여? 야 나 때문에 집에 못가는걸로 보이냐 저 멍청한 선생이 나를 핑계로 집에 안보네주는걸로 보이냐 야 뭐라고  똑바로 말해 뭔 똑바로 말해야 애들한테 그런거 시키지마 왜 학생들 골탕 먹이는게 들통날까봐 뜨끔해? 이 새끼가 어쭈 욕 이거 교육청에 신고해야지
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 양재 터널 입구 앞인데요. 사고가 났거든요? 위치가 양재 터널 맞으시죠? 네, 지금 버스가 승용차 한대를 덮쳤어요. 버스가 승용차를 덮쳤다고요 지금 사고가 일어난건가요? 네 운전자 분은 괜찮으세요? 워낙 사고가 크게나서 잘 모르겠어요. 알겠습니다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 동생이쁘다. 나주라 안돼 우리동생건들지마. 왜 안되냐? 좀 달라고 니 목숨값으로 동생 달라는건데 어렵냐? 안돼 그냥 날 죽이고 동생은 건들지마 그렇게 나오면 재미없지 널 그리고 죽이면 동생이 나한테 앙갚음이 있지 우리 동생 건들지 말아줘 갠 내버려둬 그러니까 다시 내 밑으로 들어와 그럼 너도 살고 동생도 살어 제발. 부탁이야 건들지말아줘. 그냥 날 죽여줘 이 약먹으면 되는거지? 그래 좋아 대신 조건이 있어. 하나로는 재미없지 3병마셔 그러고 죽어 그럼 되지. 우리 동생 건들지마.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 혹시 나 오늘 2만원만 빌려주만 안돼? 응? 안돼. 나도 요즘 맨날 택시타느라 택시비 많이 나와서 적자란 말이야. 머? 그래도 택시는 조금 일찍 일어나면 굳을 수 있는 돈이잖아. 나 지금당장 멀 살 돈도 없어 정말 미안한데. 나 진짜 돈이 없어서 그래. 근데 나도 돈이 없어. 좀 빌려주라. 미안한데 안될 것 같아. 야. 좀 너무한거 아니야? 나는 진짜 힘들게 사는데 택시비에 쓴다고 친구한테 돈을 안빌려주는건 너무하지 않어? 그런건 아닌데. 너한테 돈을 빌려주면 나는 어떻게 벼텨. 내가 너 용돈 받기 전까지 돌려줄게 어려운 건 아니잖아. 알겠어.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 이봐 네? 누구세요? 입다물고 가진거 다내놔 경찰에 신고할거에요 할 수 있으면 해봐 제발 살려만 주세요 저 돈 없어요 거짓말마 다 줄게요 그래야지 이제 됐죠?
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 미나씨 휴가 결제 올리기 전에 저랑 상의하라고 말한거 기억해요? 네 합니다. 보고서를 보니 저에게 상의 안한 내용이 올라갔던데요. 대표님과 바로 상의하여 결제 올렸습니다. 미나씨 지금 미나씨 직속 상사가 누군지 몰라? 죄송합니다. 미나씨가 낙하산인건 알겠지만 기본적인건 지켜야 할 거 아니예요. 네. 미나씨 결제 다시 올리세요. 네 알겠습니다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 교수님 제 논문에 제 이름이 없나요?  아 무슨 논문말이야?  지난 번 냈던 논문이요. 그거 제가 1 저자로 쓴 건데.  그랬던가? 흠.  제가 힘들 게 쓴 논문인 데 왜 선배이름으로 퍼플리쉬 된건가요?  이 선생 교수되기 싫어? 이 바닥에는 상도덕이 있는거야. 선배가 먼저 잘되면 안되나?  교수님 제가 쓴 논문인 데 억울합니다.  억울할 거 없어. 나중에 선배들이 다 챙겨줄 건데 무슨 걱정인가.  그래더 이 논문 제가 힘들게 쓴 논문이에요. 게다가 좋은 곳에 실렸다고요.  자네는 위아래가 없나?
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 야 너  네 저요? 그래 너 왜요 돈좀 줘봐  돈 없어요 돈이 왜 없어 지갑은 폼이니? 진짜 없어요 줘봐 내가 확인할거니까 제발요 진짜 없어요
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 야 너 빨리 안 뛰어와? 너 이 환자 제대로 봤어 안 봤어 어제 저녁부터 계속 보다가 지금 과장님께서 잠시 부르셔서 다녀 왔습니다. 혹시 무슨 문제 있습니까? 너 이 사람 약물 용량 잘 못 처방해서 죽을 뻔했어 알아? 그거 어제 노티 주신대로 전달해서 그대로 주사 한거라 문제 없을텐데요 그럼 내가 잘못 노티 줬다? 지금 날 탓하는거야? 여기 문자 보시면 노티 주신거와 똑같이 처방 했습니다 잘 못 처방하지 않았어요. 그래서 뭐 어쩌라고 니가 잘 보고 문제 있는거 같으면 나한테 먼저 연락해야 했던 거 아니야? 내가 아무리 노티 내려도 이상한거 없나 살폈어야지 어제 골프 치러 가신다고 연락 하시면 당직 한 달 내내 세우실거라고 전화하지말라고 하셔서 안 했습니다. 그리고 저는 노티가 맞게 내려온 줄 알고 그대로 주입한거 밖에 없습니다. 아 그래서 내탓 하겠다? 왜 지금 바로 과장님 콜해서 내가 환자 죽일뻔 했다고 떠들고 다니지 그러냐 내가 꼴보기 싫은거잖아 너 아닙니다 죄송합니다. 다음부터는 조심하도록 하겠습니다 야 됐어 너네 동기한테 이번달 당직 할 필요 없다고 그래 너가 두 달 내내 서 빠지는 날 있으면 한 달 씩 더 추가다 죄송합니다 한번만 용서해주세요.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 엄마 저 그 돈 안해주시면 정말 큰일나요.  이유도 말하지 않고. 몇번째니 경민아.  엄마 더이상은 못한다.  나중에 다 말씀 드린다고 했잖아요. 저 죽는거 보고싶으세요?  차라리 죽어라. 너때문에 우리 가족 전부가 힘들어.  대체 무슨일이니?  오늘까지 꼭 막아야 할게 있다고요. 이거 못해주시면  집안에 불지르고 저도 타 죽을거에요.  엄마 정말 너무 힘들어 경민아. 언제까지 그럴거니.  이번이 마지막이에요 정말.  마지막이 대체 몇번쨰인지 모르겠구나.  죄송해요.
# 예측 라벨: 일반 대화
# ------------------------------

# %%
import torch
import torch.nn.functional as F
from tqdm import tqdm
import pandas as pd

#— 하이퍼파라미터: 상황에 맞게 조정하세요 —#
batch_size     = 32
prob_threshold = 0.6   # max softmax 확률 임계값
std_threshold  = 0.45   # softmax 분포 표준편차 임계값
max_length     = 400

two_stage_model.eval()
model.eval()

final_preds = []
test_df     = pd.read_csv("./Aiffel_DLThon/data/original_data/test.csv")
test_texts  = test_df["text"].tolist()

for i in tqdm(range(0, len(test_texts), batch_size), desc="Stage 1 + Stage 2 추론"):
    batch_texts    = test_texts[i:i + batch_size]
    batch_encodings = tokenizer(
        batch_texts,
        truncation=True,
        padding=True,
        max_length=max_length,
        return_tensors="pt"
    )
    # device에 올리기
    batch_encodings = {k: v.to(two_stage_model.device) for k, v in batch_encodings.items()}

    with torch.no_grad():
        # — Stage 1 예측 — #
        s1_logits = two_stage_model(**batch_encodings).logits
        s1_preds  = torch.argmax(s1_logits, dim=1)

        for j, s1 in enumerate(s1_preds.tolist()):
            if s1 == 1:
                # Stage 1에서 협박으로 판정 → 바로 label 4
                final_preds.append(4)
            else:
                # — Stage 2 예측 — #
                single_input = {
                    key: val[j].unsqueeze(0).to(model.device)
                    for key, val in batch_encodings.items()
                }
                with torch.no_grad():
                    s2_logits = model(**single_input).logits  # shape: [1, num_labels]
                    probs     = F.softmax(s2_logits, dim=-1).squeeze(0)  # shape: [num_labels]

                max_prob = probs.max().item()
                std_prob = probs.std().item()

                # 임계값 미만이면 label 4, 아니면 예측값
                if (max_prob < prob_threshold) or (std_prob < std_threshold):
                    final_preds.append(4)
                else:
                    final_preds.append(probs.argmax().item())

# 결과를 DataFrame에 붙여서 저장 예시
test_df["pred_label"] = final_preds
test_df.to_csv("./Aiffel_DLThon/data/submission_with_threshold.csv", index=False)
print("✅ 임계값 기반 라벨링 완료, 파일 저장됨.")
# Out:
# Stage 1 + Stage 2 추론: 100%|██████████| 16/16 [00:05<00:00,  3.15it/s]
# ✅ 임계값 기반 라벨링 완료, 파일 저장됨.

# %%
from collections import Counter

print("📊 예측 결과 분포:")
print(Counter(final_preds))
# Out:
# 📊 예측 결과 분포:
# Counter({4: 500})

# %%
id_to_label = {
    0: "협박 대화",
    1: "갈취 대화",
    2: "직장 내 괴롭힘 대화",
    3: "기타 괴롭힘 대화",
    4: "일반 대화"
}
for i in range(500):
    print(f"문장: {test_texts[i]}")
    print(f"예측 라벨: {id_to_label[final_preds[i]]}")
    print("-" * 30)
# Out:
# 문장: 아가씨 담배한갑주소 네 4500원입니다 어 네 지갑어디갔지 에이 버스에서 잃어버렸나보네 그럼 취소할까요 아가씨 내 여기단골이니 담에 갖다줄께 저도 알바생이라 외상안됩니다 아따 누가 떼먹는다고 그러나 갖다준다고 안됩니다 자꾸이럼 경찰불러요 아가씨 담배피는교 그건 왜 물으세요 그람 아가씨 담배 한대만 빌립시다 내 지금 지갑도 잃어버리고 기분이 그래서 그러니 여기요  아따 주는김에 한개더 주면 되겠네
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 우리팀에서 다른팀으로 갈 사람 없나? 그럼 영지씨가 가는건 어때?  네? 제가요? 그렇지? 2달만 파견 잘 갔다오면 승진이야. 네? 저는 별로 가고 싶지 않습니다. 여기 있는 모든사람도 가기 싫어해. 그러니까 막내인 영지씨가 가는게 맞지 정말 죄송합니다. 저는 못갑니다. 장난해? 모두를 위해 영지씨가 희생하는게 싫어? 네. 부당한 방법으로 가는 것 같습니다. 영지씨 안가면 회사생활 오래 못할 것 같은데 그래도 안갈거야? 안가면 지옥일텐데. 그래도 이 방법은 아닌 것 같습니다. 죄송합니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 너 오늘 그게 뭐야 네 제가 뭘 잘못했나요.? 제대로 좀 하지 네 똑바로 좀 하지 행실이 맘에 안들어 네 실천할께요 옆에 동기들 좀 본받으란 말야 어? 네 알겠습니다 그래 똑바로해 노럭할께요
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 이거 들어바 와 이 노래 진짜 좋다 그치 요즘 이 것만 들어 진짜 너무 좋다 내가 요즘 듣는 것도 들어봐 음 난 좀 별론데 좋을 줄 알았는데 아쉽네 내 취향은 아닌 듯 배고프다 밥이나 먹으러 가자 그래
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 아무튼 앞으로 니가 내 와이파이야. .응 와이파이 온. 켰어. 반말? 주인님이라고도 말해야지? .켰습니다. 주인님. 오냐. 앞으로도 잘부탁한다 와이파이. 넵. 이렇게만 해? 알겠지? 응.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 그러니까 빨리 말해. 선생님 제발 살려주십시오.  비밀번호 틀릴 때마다 손톱 하나씩 뺀찌로 뽑는다.  선생님 저도 정말 모릅니다.  하나 엄지 손톱 뽑는다.  으악! 잘못했습니다. 그런데 진짜 모릅니다.  둘 이번에는 두 번째 손톱 뽑는다.  으악! 진짜 저는 모릅니다.  셋 중지를 아주 분질러 줄까?  으아아 살려주십시오.  아니다 아주 손가락을 다 잘라놔야겠다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 그 사람 누구냐?  누구말하는거야?  다 알면서 모른척 하지마. 둘다 쏴버리기 전에.  아니 정말 왜이래? 누굴말하는거냐고.  어제 밤에 전화온 그새끼 말이야. 번호 알아놨으니까 죽이기 전에 다 불어라.  아! 김대리? 그냥 회사사람이야. 오해하지마  회사사람이란 인간이 그 오밤중에 사랑한다고 보고싶다고 하냐? 진짜 다 죽여버리기 전에 솔직히 말해라.  정말 아니야. 왜 이래? 오해라니까.  안되겠다. 그럼 지난주 점심시간에 모텔은 왜갔냐?  어??? 그냥 피곤해서 쉬러간거야. 오해야.  안되겠다. 그냥 불지르고 다 끝내자.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 야 저기야 닭꼬치 트럭왔다 응 그러네 그치? 너도 먹고 싶지? 어?나도? 그래 너 세상에 닭꼬치 싫어하는 사람이 어딨어 그렇긴한데 배부른데 그래? 그럼 나만 먹고 올게 응. 뭐해?? 뭘? 돈줘야 먹고오지 내가 돈이 어딨냐 할머니랑 둘이 사는데? 응.?? 어 알겠어 얼른줘 미적거리지말고
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 안경 안쓰고 키작고통통해보이는 분이었는데 다안경안씀  쌍꺼풀없었던것같고 아 단발인가 키작은사람들은 검정색 머리인데 없어가지고 단발인가 단발은 아니었던것같은데 막 나같은 장발도아님 모르겟다 중단발  영업직분중 하나인가 그럴수도
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야 너 2학년 김민석 맞지? 네 맞는데요. 혹시 누구신가요? 내가 누군지 궁금하면 학교 뒤쪽으로 내려와. 2분 준다. 네 지금 내려가겠습니다. 야 니가 김민석이냐? 돈 있어? 돈 없는데요. 야 쟤 몸뒤져. 너 천 원 나올 때마다 얼차려 10분이다. 야 여기 얘 지갑 있는데? 오 지갑만 봐도 돈 많게 생겼네. 열어봐봐 오 12만원 있네? 얼차려가 몇 분이야? 야 이 돈 주면 얼차려 없애줄게. 그거 오늘 저 문제집 사려고 가져온 돈이라. 혹시 내일 드리면 안될까요? 야 니 얼차려 받고 싶냐? 그렇게 내일 주고 싶으면 오늘 이 돈도 우리 주고 내일도 돈 가져다 주면 돼. 뭐가 어려워. 네 알겠습니다. 그 12만원 가져게세요. 말 잘 듣네. 아주 예뻐 내일도 돈 가져와라. 안 그러면 알지? 내일도 같은 시간에 여기로 와.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 예전에 네가 나한테 했던 일 기억하지? 너도 당해봐 예전 일이라면 내가 사과할게. 제발 살려줘. 과만 하면 다야? 그 때 네가 칼로 내 얼굴에 흉터낸 거 아직도 남아있어 그 때는 어렸을 때야. 이제는 나도 변했다고! 이렇게 용서를 빌게 아니. 그런 깨달음은 그 때 했었어야지. 빈다고 변하는 건 없어 제발 이러지마. 나에겐 먹여 살려야 할 가족도 있어. 이제와서 이렇게 빌어봤자 그 때의 내 상처는 사라지지 않아. 네가 잘못한 것들도. 원하는 게 뭐야? 날 죽이는 거 말고 원하는 건 뭐든지 할게. 내가 원하는 건 네가 나와 같은 상처를 입고 죽는 것 뿐이야 그거 말고 다른 건 뭐든지 할게. 제발 살려줘. 그래? 그렇다면 네 아들의 목숨을 내놔. 그럼 넌 살려주지. 네가 사람이야? 어떻게 그럴 수 있어? 너는 그 때 사람이었니?  난 그 때 아직 어렸어. 내가 너무 철이 없었어.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 아 취업하고 싶은데 누가 나 좀 안 데려가냐 아 그니까 나도 취업하고싶다 코로나때문에 미친거같아 진짜 너무 안 뽑아 그니까 동기들중에 취업한애들 아는애들 있어 뭐 지한이 삼성갔다그러고 그 여자애 이름 기억 안나는데 카카오 들어갔다던데 와 씨발 다들 잘갔네 부럽다 그니까 그냥 그럭저럭 학교생활 했는데 쫌 더 열씸히 할껄 아 난 나름 열심히해서 학점도 좋고한데 왜 안되냐 맨날 면접가서 떨어지니까 더 힘드네 너는 면접연습만 하면 될거같은데 나는 서류에서 광탈이야 아 그러게 면접연습 해야되는데 타고난게 말을 잘 못하는데 어쩌라는거야 그니까 공부도 잘해야되고 말도잘해야 취업되는 더러운세상 에휴 부모님한테도 죄송하고 얼른 취업해야되는데
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 김비서 지금 우리애 학교가서 집에다가 좀 데려다 주세요 사장님 그런 개인적인 일은 제가 도와드릴수 없습니다 머라고? 자네는 비서아닌가? 내 개인적인 일이 바로 회사의 공적인일이야 죄송합니다. 아무리 그래도 그건 아닌거 같습니다 김비서 지금 상사의 지시에 항명하는건가 죄송합니다. 부당한 지시에는 따를 수 없습니다 김비서 월급주는사람이 바로 나야. 월급받기 싫은가? 죄송합니다. 개인적인 용무를 지시하는것은 아닌것 같습니다 머라고?!! 꼴도 보기싫으니깐 당장나가 죄송합니다. 나가보겠습니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 과장님 오늘 부장님 기분이 안 좋으신것 같네요 오늘 프레젠테이션 있었는데 사장님한테 엄청 까였나봐 아 그래요 오늘 조심해야겠네요 엉 알아서들 조심해 완전 저기압인거 같아 네 근데 오늘 저희 주간 회의 있어서 어차피 부딪힐거 같은데 그때까지 부장님 기분이 풀리길 바래야지 뭐 아 오늘 잘못하면 엄청 혼날꺼 같은데 그니까 준비 잘해 네 알겠습니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 야 김대리 니 주말에 뭐했냐? 아 그냥 쉬었습니다. 아 그냥 쉬어? 말 좀 짧다이 어. 집에서 그냥 친구랑 배달 시켜먹고 쉬어서 그랬습니다 왜그러세요 과장님 그냥 쉬었다는데 아니 내가 물어보지도 못해? 뭐 내가 여친이랑 있었는지 물어본것도 아니고 안그래 김대리? 여친이랑 있었어? 아. 아뇨 그냥 친구입니다. 어 반응 뭐야 여친이랑 있었나본데 아닙니다 그냥 대학 동기였습니다. 그게 아닌 것 같은데 이새끼 뭐했냐 여친이랑?
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 후기 내리세요. 안그러면 고소합니다.  지금 협박하시는 건가요?  협박 아니고 알려주는 겁니다. 당장 내리세요.  제 후기는 사실만을 적었고 잘못된 부분이 없는데요?  사실적시 명예훼손 모르세요? 그리고 업무방해도 포함입니다.  공익목적으로 적은 후기는 무죄인걸로 알고 있는데요  마음대로 생각하세요 무죄가 나오든 어쨌든 고소할거니까요  제 후기의 어떤점이 잘못됐다는거죠?  그냥 돈받고 합의하시라고요 왜 굳이 인터넷에 올리고 그러세요  음식에서 쥐가 나왔는데 그걸 다른 사람들이 알게 한게 잘못인가요?  네 잘못 맞아요 손님때문에 매출 떨어지면 어쩔거냐고요.  애초에 저는 사실을 고발했을뿐 진작 대처를 잘하셨으면 됐잖아요.  아 죄송하다고요 빨리 내리라고요!! 가게 망하게 생겼는데 이거 잘못되면 직접 찾아갑니다. 주소 저한테 있고요 저 무서운거 없어요. 님 죽일수도 있으니까 그만하세요.  진짜 적반하장도 유분수네. 프로그램에 제보하겠습니다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 응응 점점 깊이 깊이 이야기가 들어갈수록 응응 맞아 마음이 좀 그럴수 잇을것같은데 그리고 감사한일 많이 주셨으니깐 전혀 안그러고 좋아지고 잇다는게 너무 신기하네 하나님한테 더 잘해야지 네 마음이 그래지는게 뭐야 무슨 뜻이지 나 아직 바본가 음뭔가 새로운 음 오늘 같이 조금 부끄러운 모습들이나 말하기 힘든 이야기들을 응응 털어놓았는데도 상대방 마음이 실망감이나 충격 이런 느낌이 아니라 아아아 더더 좋아진다는것이 대충 무슨 느낌인지 알겠다
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야 박보영 오늘 학원 갔다왔어 아니 오늘 못갔어 왜 아니 친구랑 놀다가 시간을 못봤어 자랑이냐 깜빡했어 저녁은 뭐야 너는 저녁 없어 학원 다녀왔어야지 엄마 미안해 나 배고파 다음부터 꼭 가 알았어 나 손 씻고올게 깨끗하게 씻고와
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 좋은말 할때 내돈갚아. 내가 왜 그래야 하지? 너가 여기 재개발 된다며. 너믿고 내 전재산을 투자했다고 꼼꼼히 확인안한 너 잘못이지 나도 그땐 맹지인지 몰랐다고 웃기지마! 너랑 공인중개사랑 짜고 나 속인거 모를줄 알아? 증거있으면 대보라고 내가 너 칼로 죽이고 교도소가고말거야 어이구 무서워라 너뿐아니라 너 가족까지 다 죽여버릴거야 어디 한번 해보시지.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 저기요. 혹시 번호 좀 알려주실 수 있나요? 네? 아 죄송해요. 저 남자친구 있어서요 . 그게 뭐가 중요한데요? 네? 그게 뭐가 중요하냐뇨. 아니 남자 꼬실라고 그렇게 입고 나오신 거 아는데 그만 튕기시고 그냥 좀 알려주세요. 참. 어이가 없네요. 제가 남자를 꼬시려고 입고 나왔다뇨. 무례하시네요. 어이가 없는 건 그 쪽아니에요? 딱 봐도 남자하나 잡고 놀고 싶어서 안달난 싸구려같은 여자 옷 입고와놓고  저기요. 그 쪽같은 싸구려 남자랑 저도 더 이상 대화하고 싶지가 않은데요. 그만 가주시죠. 겁나게 비싸게 구네. 하루 놀고 버림 당하게 생긴 년이 뭘 믿고 저러나. 야 너같은 애들은 딱 한 번만 놀고 버리기 좋은 타입이야 알아? 자꾸 그러시면 성희롱으로 신고 할거니까 그렇게 아세요. 사실을 말해도 신고를 당하나? 웃기는 년이네. 저거
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 너 내가 돈 갚으라고 했지!!!!! 안갚으면 죽여버릴거야 어떻게 죽일건데 내가 칼로 너를 찔러 죽여버릴거야 언재까지 갚으면 되는데? 내일 까지 당장 갚아 내일까지는 못 갚아 그럼 너 칼로 찍어 죽일게 안돼 죽이지마 그럼 너 딸을 죽일게
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 야 얘는 왤케 돼지냐? 그만 좀 먹어라 놀리지마 너 라면 한번에 5개 끓어먹지? 아니야 그런 말 하지마 아니긴 뭐가 아니야 너 먹방 해봐라 조회수 잘 나올거 같네 하지말라고 와 내가 너였으면 자살했다 그만둬 제발 어휴 그래도 살겠다고 쳐먹는거 봐라 그만하라고
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 너 왜 그렇게 생겼어?  내가 뭘  너 정말 토나오게 생겼어 알아?  너도 잘생긴 거 아니거든?  너보단 백배 낫지 너처럼 생기면 어떤 기분이냐? 이 세상 살아갈 수는 있는거냐?  그만해  뭘 그만해 현실을 자각시켜야 너가 성형을 하든 뭘 하든 할 거아냐  내 얼굴이고 내가 알아서 할 거야  너 얼굴을 계속 대면해야하는 내가 괴로워서 그래  그만하라고!  얼굴도 못생긴데 성질도 드럽네
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 너 이리로 와서 돈 좀 내놔라 아니 당신 미쳤나요? 나 참 너야 말로 목숨이 여러 개인줄 아는 미친놈이세요? 날 어떻게 할거죠? 이 아줌마 눈치가 지지리도 없으시네 돈 안주면 큰일날거야. 자 여기요 얼시구 돈을 일부만 주셨네 장난치나 그럼 얼마나 줘야 하는데 다 줘야지 어딜 장난치고 있어
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 나. 이번에도 돈이 좀 필요한데. 우리사이에 차용증이나 돈 갚겠다는 각서는 필요없지? 자기야. 저번에도 돈 필요하다면서 5백만원 가져갔잖아 나 빨리 백수탈출 해야지. 원래 강남 학원이 비싸. 그래도.무슨 학원비가 5백만원이나. 이번엔 또 뭔데? 집이랑 학원이랑 너무 멀어서 근처 오피스텔이나 원룸 좀 알아보려고. 뭐어!? 그건 몇백이 아니라 몇천만원이 필요한거 아니야?  자기야!! 나 사랑한다면서 그것도 못해줘? 그래도 이건 너무하잖아. 백수가 돈이 어딨어? 오빠 저번에 상여금 많이 받았잖아. 그거 좀 줘. 저번에 말한 그친구 사정이 안좋아서 걔한테 좀 빌려주기로 했어 .무튼 이번달엔 지출할곳이 좀 많아. 내가 오빠 반찬도 갖다주고 함께 한 시간이 얼마인데. 나야 아니면 그 친구야?
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 김인턴 지금 회의 들어가야 되니까 빨리 이거 좀 해와. 아 저 지금 퇴근하려고 했는데요 야 김인턴. 너 정규직 되기 싫어? 아뇨 되고 싶습니다 근데 행동거지가 그따구야? 죄송합니다 너 전환되는거 내 입김 쎈거 몰라서 지금 말대꾸야? 빨리 해와 알았어? 알겠습니다 너 한 번만 더 그래봐 진짜. 죄송합니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 저기요 돈을 빌리셨음 갚으셔야죠 뭐래 상황극 좀 그만해 재미없었어 엉 재미없어 센치한놈 하여튼 상황극 할거면 재밌게나 하던가 연기도 더럽게 못해요 디스 장난아니네 내가 배우냐 연기 잘하게 그니까 쫌 하지를 말아라 알았어 알았어
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 와 강아지 너무 이쁘다 감사합니다 몇 살이에요 올해로 네 살이에요 와 애기네요 애기 포메인가여 네 맞아요 잘 아시네요 그럼요 저희 집도 개 키우거든요 오오 대박 강아지 키우는 사람들은 모두 강아지를 좋아하죠 맞아여 정말 그런 것 같아요
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 김대리 이따구로 할꺼야?  네?  글씨가 왜 이모양이야?  죄송합니다  김대리 학교 안나왔어?   죄송합니다 똑바로 쓰겠습니다  그럼 이건 똑바로 안쓴거야? 정신 안차려?  정신차리겠습니다 집안사정이랑 일이랑 별개야 이따구로 일하꺼여? 네 죄송합니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 선생님도 환자타는 징크스 있겠네요 난 그런거 없어 특이하네요 다들 하나씩 있으시던데 굳이 있다면 족보에도 나와있는 전통적인 징크스 그정도 그게 뭔데요 후배가 산 과자나 음식을 하나라도 먹는다면 어떻게 되는데요 하늘에서 환자가 우수수수수 내려 아 큰일났다 왜왜 내가 지금 먹는 아이스크림 누가 산거야 제 제가 빨리 계좌번호 불러 빨리 돈 보내줄게
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 너 이 영상 유포되면 어떻게 될거 같아? 미안. 지워줘. 그건 안 되지. 내가 뭐든 할게. 그래? 그러면 합의금으로 1억만 줘. 뭐? 나한테 그런 큰 돈이 어디있어? 그럼 인터넷에 올리지 뭐. 아니야. 내가 마련해 볼게. 시간를 조금 줘. 그래 1달이야. 1달 안에 1억 입금해. 응.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 서울 전체를 10분 뒤에 폭파하겠다. 너 대체 원하는게 뭐야? 왜 이런짓을 하는거냐고 돈 300억과 내가 안전하게 탈출할 수 있는 제트보트를 10분내로 준비해라 조금이라도 늦으면 시민들의 안전은 보장 못한다. 알았어 일단 진정해 다 준비해준다고 근데 10분은 너무 촉박하잖아 그래? 이러면 가능하려나? 아니 왜 갑자기 반포대교를 박살내는거야!!! 제발 알겠어 금방 준비할게 조금만 기다려 딱 10분이야 그 이상은 없어 잘 생각해 지금부터 딱 10분내로 준비해줄게 제발 서울만은 안돼!!! 참고로 서울이 끝이라고 생각하지마 대한민국 전체가 될 수도 있으니까 제발. 제발 그만해 이러다 다죽어
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 오늘 너 미팅아니야 맞아 망했어 오늘 왜 뭐가 문제야 나 살이 너무 많이 쪘나봐 옷이 다 이상해 괜찮은데 뭐가 그래 어디서 만나냐 오늘 강남역에서 보기로했어 누구랑 그 너 친구 민영이랑 이대이야 맞아 나 괜찮지 이옷 응 이쁘네 재밌게 놀다와라 알았어 나 오늘 늦을수도 있다 먼저 자
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 저 며칠전에 대리 운전 했던 길동 기사입니다. 아 네네 무슨 일로 전화하셨죠? 제가 돈을 모자르게 드렸나요? 아니 그게 아니고. 손님 내려드리고 내여보라고 저장되어 있는 분께 전화 걸었더니 와이프라 저장 되어 있는 사람한테 전화를 걸라고 하더군요 네. 근데요? 뭐가 문제인가요? 에이 같은 선수끼리 왜 그러실까? 둘이 다른 사람 이잖아요 제가 증거 다 확보 했어요 어쩌피 번호도 모르면서 어떻게 알려주게요 그냥 끊으세요 01012345678 이거 지금 부인분 번호 맞죠? 여기로 증거 보내도 되는거죠? 상관없어 하시는거 같은데. 아. 아니 뭐 어떻게 하면 되는데요. 아내한테 말하면 안돼요. 저 이제 곧 결혼 할 사람이란 말이에요. 그럼 내 계좌로 120만원만 보내 그럼 못 봤던 일로 해줄테니까 120이요.??? 당장 120만원을 어디서 구해요. 저 결혼식에 돈 다들었단 말이에요. 그럼 포기하던가 뭐 재산은 아내가 다 가져가겠네. 결혼도 안 하고 헤어진 사이인가? 아내 될 사람이 불쌍하다. 그 날만 엄청 기다렸을텐데 아. 지금 보내드릴게요. 그대신 꼭 지워주셔야 합니다. 이건 저희둘의 약속입니다 꼭 지우세요.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 그만 건드리세요 뭐? 반복하시잖아요 뭐를 진짜 모르세요? 몰라 불쾌하네요 이 새끼좀봐라 그만요 제발 넌 좀 쳐 맞자 제발요
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 어이 코털 왜 왜? 아놔됐고 너 매점가서 곰보빵 두개에 콜라하나 사와라 나 돈없어 돈없어? 그럼 내가 돈줄께 어 여기 1000원 줄테니까 빵두개 콜라하나 사고 거스름돈 거슬러와라 야 택도없어 야 뒤질래? 쌔벼서라도 갖고와 색키야 야
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 저기요 번호 주세요 네? 죄송합니다. 머라고요? 내가 누군줄 알아요? 아. 네 당연히 알죠 근데 왜 번호 안줘요? 아니요. 저는 남자친구있어요 남자친구 있는거랑 번호주는거랑 무슨 상관인데 빨리 번호 찍어봐요 죄송합니다. 개인정보잖아요. 그래도 빨리 줘봐 튕기지말고 여기 계속 번호달라 그래요 살려주세요.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 다 손들어! 지금부터 손을 내리면 이 직원은 죽는거야 저한테 왜 그러세요 빨리 돈다발 이 가방에 담아. 빨리! 담지 않으면 넌 총에 맞는거야 저 비밀번호 몰라요! 5초 준다 5 4 3 2 1 정말 모른다니깐요. 너가 돈을 담는게 빠를까? 얘가 죽는게 빠를까? 죄송합니다. 얼른 열게요. 진작에 그럴 것이지. 더 빠르게 더 빠르게! 네 제발 쏘지마세요.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 다시 못걸어다니게 만들어줄까? 어? 이러지마세요. 난 분명히 시간을 줬다. 제가 할 수 없는 일이에요. 그래? 그러면 어쩔 수 없네. 이제 못걷는거지 뭐. 왜이러세요. 빨리빨리 시키는 대로 했어야지.  어떻게 시간을 좀 더 주세요. 다음번에도 안되어 있으면 못걷는거에서 안끝날 줄 알아. 알겠어? .네 어떻게든 해보겠습니다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 핸드폰 빌려 주실 수 있어요?  네? 급하시면 1통화 하세요  감사합니다  어?  제가 깨트린거 아니에요  니가 빌려달라고 하고 니가 깨트렸잖아  아니라구요 님이 깨트렸잖아요  이거 완전 사기꾼이네. 당장 액정 값 내놔  사기꾼은 당신이지. 한두번 해본 솜씨가 아니구만  이 새끼야 니 핸드폰이라도 가져간다.  뭐하는거야? 당신! 돌려줘  꺼져 이제부터 이거 내 꺼야.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 이 영감탱이 자네가 우리 할망구랑 바람났지? 노망났나 이게 무슨소리야 왜 젊었을때 서로 첫사랑이라 아직도 못잊었나? 무슨 말도 안되는 소리야 옛날일이네 다 내가 암만 생각해도 이 시골 촌구석으로 이사온 자네의 저의가 심히 궁금하네 그건 고향이라 돌아온거네 고향에 옛사랑까지 있어 돌아온거 아닌가? 내가 자네랑 우리 망구 똑똑히 지켜보고 있네 혹시라도 헛짓거리 하다 걸리면 다 죽는거여 자네도 죽고 나도 죽고 우리 망구도 죽고 이 마을도 다 불태워서 다 죽여버릴거여 그런거 아니니 제발 진정하게 뒤가 구린새끼가 아주그냥 입만 열면 거짓부렁이네 그런거 아니네 제발
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 야 거기 이 골목 지나려면 통행비 5만원이다. 그딴게 어딨어요? 오늘부터다 시발롬아. 저 돈 없어요. 돈 뒤져서 나오면 10원당 한대다 오케이? 아 시발 통행비가 고속도로도 아니고 왜 있어요 미친놈아. 뒤질래 어디서 욕이야. 그럼 본인 지나가주는 대가로 헌금 5만원 걷어간다 십새야 미친놈이네 너도다 시발
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 수진씨 목마른데 1층 커피숍에서 나 커피 한 잔 사다 줄 수 있어? 돈은 내가 줄게. 이따 줄테니까 일단 다녀와.  네 알겠습니다.  아 잘 사왔네 고마워. 내일도 나 커피 한 잔 사다 줄 수 있어? 돈은 한 번에 줄게.  네? 내일 주신다고요? 네. 알겠습니다. 수진씨 나 오늘 커피 부탁해.  부장님 벌써 한 달째인데 돈은 언제 주시나요?  아 벌써 그렇게 되었나? 다음달에 줄게.  .  수진씨 왜그래. 내가 안준다는 것도 아니고. 잘하다가 왜그래. 이래서 젊은 것들은 안된다니까  아닙니다. 죄송합니다.  그래 정신 똑바로 챙겨야지? 그래야 일도 잘하지.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 저희 이 집에서 나가게 하려면 위로금이라도 주시고 나가게 하세요. 저번에 원래 집 값이랑 조금의 보상금 까지 드리기로 계약하셨잖아요. 근데 며칠사이에 집 값이 더 올랐어. 집 값 달라고 안 할테니가 위로금이라도 달라니까? 계약서에 명시 되어 있고 마음대로 바꾸실 수 없어요. 빨리 나가세요. 절대 안 나갈거야 돈 주기 전까지. 마음대로 내쫓으면 폭력으로 신고할거야. 그럼 도대체 얼마만큼에 돈을 더 드려야 하는건가요? 집 값오른거에 5분의 1인 100만원만 더 얹어줘. 100만원 더 받고 나가는거 이 집밖에 없어요. 원래 의무적으로 비워줘야 하시는거예요 알아요? 그래서 뭐 어떡하라고 줄거야 안 줄거야 빨리 결정해 시간 없으니까 내일 안으로 돈 드릴테니 꼭 퇴거 하십시오.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 와 너 요즘 태양의 후예 보냐 아 당연하지 요즘 누가 안보냐 송준기 존잘 송혜교 존예 진짜 그니까 군복 너무 멋있더라 진짜로 저런 군인들 있나 있으면 소개좀 미쳤냐 내가 만나지 와 주위에 전역하는 애들한테 연락해봐야겠따 군인 너무 멋있다 아 그니까 관심도 없었는데 저거 보니까 관심생기더라 미쳤나봐 진짜 나 입대할까도 고민했잖아 미쳤나봐 진짜 개웃기네
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 홍시씨 오늘 데이트 하나 봐? 엄청 힘줬네? 네? 아니 저 평상시랑 똑같은데. 그렇게 외모신경 쓰는 거 반만이라도 일에 신경 좀 써 회사 놀러왔어? 죄송합니다 열심히 하겠습니다 열심히? 열심 필요없어 잘 해야지 홍시씨 머리가 좀 안 좋나? 네? 무슨 말씀이신지 그 왜 있잖아 머리가 안 좋으면 몸이 고생한다고 홍시씨 보면 딱 그 말이 생각나서 내 마음이 아파 잘하겠습니다 홍시씨 지금 나랑 말장난 해? 면접은 어떻게 붙은 거야 빽이라도 있는거야 뭐야 팀장님 말이 너무 심하세요
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 차에서 당장 내려 내가 왜 내려? 당신이 뭔데 이래라 저래라야? 그럼 왜 계속 내 차 뒤에서 빵빵거렸는데? 당신이 답답하게 운전하니까 그랬지 노란불에 멈추는 게 당연한 거 아니야? 바빠죽겠는데 에휴 이 사람아 당신만 바빠? 나도 바빠 그럼 갈 길 그냥 가시라고요 됐고 당장 내려서 사과해 아님 너 오늘 집에 못 가 당장 차 안 빼? 확 박아버릴라
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 너 때문에 내 인생이 망했어! 아빠 왜 이러세요. 너도 내가 알콜 중독자라고 생각하냐? 왜.왜 그래요. 또 술 드신 거예요? 네 애미를 닮아 쨍알쨍알 시끄럽네! 아빠! 술 그만 드시기로 했잖아요. 닥쳐! 내가 술을 마시든 약을 하든 내 알바야! 아빠.전 아빠 딸이잖아요. 그러니까 넌 내 소유잖아! 따지지 말고 술이나 더 사와! 흑흑
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 나 호랑이 보러 가고 싶어 갑자기 호랑이 좋아했나 원래 내가 원래 동물을 좋아하잖아 에버랜드 가고싶다 에버랜드 여기서 가깝잖아 내일 갈까 오 진짜 같이 가줄거야 응 가서 놀이기구도 타자 나 놀이기구는 잘 못타는데 안 무서운건만 가능 아 뭐야 그럼 동물만 볼거야 응 호랑이도 보고 사자도 보고 펭귄도 보고 뭐그래 나도 오랜만에 동물보면 재밌을거 같네
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 니 죽고싶냐?  아니요.  왜 사람 말귀 한번에 못알아처먹고 자꾸 두 번 세 번 말하게 하냐?  죄송합니다.  니 딸래미 거기에서 알바하는거 알고 있다. 니 아들래미 주몽학교 다니는것도 다 알아  제 아이들은 건들지마세요 왜 그러세요.  너는 내 말 안들으면 니가 사랑하는 사람 포함해서 니 주변 가까운 사람 하나씩 다 너 보는 앞에서 쥐도 새도 모르게 액체로 만들어버릴 수도 있어  그런 무서운 말씀 하지마세요 제발.  니가 애초에 제대로 했으면 내가 이러냐 나 착한놈 나쁜놈 만드는거 니가 하는거에 달렸어  죄송합니다 제가 다 잘못했습니다.  오늘은 이정도지만 다음번엔 치아 보험 제대로 들어와야 될거다. 강냉이를 다 털어버릴거니까. 이제 니 그 죄송하단 말도 지겹고 죄송하단 말도 못하게 만들어줄게 그냥
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 이 자식 아이패드 새로 샀네?  좋아보인다 나도 요즘 아이패드 사고 싶었는데 잘 됐네.  우리 좀 써 봐도 되지?  안돼. 엄마가 사주신 거란 말야.  친구끼리 왜 이래 한 번만 써본다니까.  안된다니까.  야 맞고 싶냐? 내놓으라면 그냥 내놔.  한 대 맞고 내놓을래 그냥 내놓을래?  진짜 안 되는데. 여기.  아싸 아이패드 득템
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 야 고구마?  내가 왜 고구마야? 고구마니까 고구마지.  그만해. 내 이름은 고군만이야.  너 불붙이면 아주 맛있겠다.  가 비켜.  아주 빨갛게 익으니까 군고구마네.  비키라고.  야 군고?  제발 좀 그만해. 나 정말 힘들어.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 100원만 빌려주라 구라치네 내일 200원로 갚을게 밀린 돈이 니가 천원이 넘어 아니 우리 친구잖아 친구긴 하냐? 아 백원만 이번만이다 진짜 고마워 안 갚으면 죽인다
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 민선씨 이번주 주말까지 제출인데 이것 좀 도와줘요.  각자 개인 업무 입니다. 저도 아직 제출 전이라 바빠요.  상사 부탁인데 이정도도 못 해주나요 ?  그래도 대신 업무를 봐주는 건 아닌 것 같습니다.  하기 싫으면 회사를 관둬요.  너무 심하십니다.  지옥 같은 회사 생활을 경험하게 해줄게요  그래도 업무 대신 처리는 부당합니다.  잘 생각하고 대답해요. 회사에서 고통을 맛 보게 해줄테니까  죄송합니다. 안될 것 같습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 김대리 네 과장님 무슨일이세요? 김대리 옷이 오늘 왜그래? 제 옷에 무슨문제가 있나요?  김대리 일을 못하면 옷이라도 단정하게라도 입고 출근하던가.  제 나름 신경 쓰고 입고 나온건데 죄송합니다.  과장님 요즘 김대리 남편이랑 사이가 안좋아서 옷에 신경 쓸수 없다고 하네요. 남편과 사이도 안좋은데 회사일은 제대로 하겠냐? 회사일에는 지장없게 하겠습니다.  아침부터 김대리 옷 꼬라지 보니깐 기분이 팍 상하네.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 아 내가 아이스 시켰지? 네 근데 지금 너무추운것같아서 나 뜨거운 걸로 마시려구 아네 손님 그럼 다시 계산해드릴까요? 무슨소리야? 바꿔주라고 하지만 아이스 반쯤 드신것같은데. 아이거 흘려서 그런거지 입 안댔어 그러니까 새거지 바꿔줄수 있지? 네? 원래 교환 환불은 7일까지된까 얼른 해줘 그건 이상황이랑 안맞는거 같은데요. 뭐가 달라? 소비자 보호법도 모르니?
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 어이 오랜만이다 너 나 피해 다니냐? 그건 아니야 근데 왜 난 그렇게 느껴지지? 지난번 맞은곳 아파서 잘 못 나갔어 그래? 어디더라 그건 왜 거기 빼고 맞자 제발 이러지마 싫은데? 난 재밌는데?
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장:  아니 진짜 걍 지구 망할 거 같아 위쪽은 비 난리고 밑에는 비는 안 와도 공기 난리고 이제 또 비오는 너무 많이와 진짜 망할려고이러나  그러게 말이여 진짜 몇년 전부터 미세먼지도 난리고 원래는 봄에만 황사처럼 공기 안 좋았잖아 근데 요즘엔 걍 사계절 내내 안 좋으니까 약간 더 무서운 건 또 거기에 다 적응한 거임  일단 나부터 적응 다함 공기 안 좋은 거 그러려니해 아 개인정  어쩌다 이렇게 됐는지 진짜 예전이 그립다 초딩 때라던가 그냥 벌받는거 같기두 하구 마잡 그래서 나 늦은 감 있지만  이제라도 일회용 줄이려고 뭔가 이젠 다들 좀 경각심 느껴야 할 거 같음
#
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 너네 엄마 다리가 하나 없더라? 응 사고 당하셔서 그래 으 다리 하나 없는 장애인이네 그래도 생활하시는데 문제 없으셔 문제가 없긴 뭐가 없어. 걸을 때 뒤뚱뒤뚱 이상하더만 말을 왜 그렇게 하니? 뭐가 맞는 말한건데 이상하잖아 계속 뭐가 이상하다는거야 뛰지도 못하고 걷는것도 이상하다는거지 뭐야 너 진짜 나쁘다 너가 불쌍해서 그러지
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 애 시어머니가 우습니? 아니요.그건아닌데 그게 아니면 미역국에 소고기 건더기가 없네? 아니. 요새 건강생각하셔서 채식하신다하셔서요 그래도 그렇지 미역국에 고기가 없음 그게 미역국이니? 죄.죄송합니다 내가 말을 말지 이렇게 답답해서야 다시 끓일까요? 그럼 이거 먹으라고? 죄송합니다.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 너 이번에 알바비 들어왔다며? 어 . 근데 왜? 내가 급해서 그러는데 10만원만 줘봐 왜 . 저번에도 안갚았잖아. 아니 한번에 돌려준다니깐 줘봐 언제까지 갚을껀데 . 아 시끄럽고 맞기 싫으면 빨리 보내 나도 써야하는데 . 안보내면 진짜 뒤진다 빨리 보내 아 제발.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 선생님 지금 저희애가 잘못했다는거에요? 아니요 어머니 그게 아니라요 그게 아니면 뭔데요? 시작은 민혁이가 먼저 했기때문에 사과를 하고 좋게 넘어가는게 아니 우리 민혁이가 그럴애가 아닌데 상대 아이가 잘못했겠죠 어머니 제가 상황을 파악해봤는데 민혁이가 먼저 시작한게 맞대요 아니 선생님이 너무 편파적이고 편협하고 일방적이시네요? 어머니. 일이 더 커져요. 제발요 진정하세요 아니 나는 진정못해요 우리 민혁이 얼마나 애지중지 키웠는데 게다가 민혁이가 틀린말한것도 아니잖아요? 그애가 한부모 가정인게 우리 민혁이 잘못도 아니고 어머니 제발요.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 자네 이번에 취직을 했다지? 예. 어렵사리 구한 자리입니다 그래. 잃기에는 너무 아쉬운 자리겠군 예? 그게 무슨 소리십니까 그날 자네가 본 것들. 네?! 못 본거로 해줬으면 좋겠구먼 무. 무슨 참. 어린나이에 가족들을 부양하는건 쉽지 않은 일이지. 아니면 부양할 가족들을 없애버리는게 나으려나. 제발 아무에게도 말하지 않을테니 제발. 내 항상 자네를 걱정하고 있다는걸 알아주게. 그럼 일 열심히 하게.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 이쪽에 주차 하시면 됩니다. 너가 대주세요 고객님 저의 역할은 안내요원 입니다. 내가 바쁘니까 빨리 가야된다고 죄송합니다 아 여기 사장 누구야 죄송합니다 저의 역할은. 아니 너 가만히 있고 사장 나오라고 해 죄송해요 이러지 말아주세요 너 자르는 건 일도 아니야
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 오늘 저녁 회식합시다  네 갑자기요? 왜요? 하은씨안돼요? 애가 아파서 빨리 가봐야할것같은데요  애는 하은씨만 키웁니까?  죄송합니다. 신랑이 오늘 출장이라  죄송할 것 없고 오늘 회식은 무조건 참석이니까그리 아세요 .아. 안되는 사람은 다음 인사고가때 봅시다 . 죄송합니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 야 새끼야 내 사랑스러운 여동생을 욕하면 어떡하냐 진짜 땅에 매장 될 준비나 해 죄송합니다. 한번만 봐주세요 하이고 싫은데 너 내가 깡패를 고용해서 널 보복할줄 몰랐지? 죄송합니다. 여동생분 한테 함부로 까불지 않겠습니다. 살려주세요 야 깡패야 이 새끼 봐줘야 하냐? 너가 판단해봐 아뇨 저런 새끼는 남자도 아니에요 그냥 형님이 원하는대로 진행 하겠습니다. 들었지 새끼야 너 임마 건들면 안되는 사람을 건든거야 우리 형님 무서우신 분이다.  넌 이 세상에서 아예 삭제 시켜줄게
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 201호에 좀 이상한 사람이 이사왔다면서요?  무슨 조현병인가 뭔가?  그거 완전 정신병이잖아요  맞아 요즘 그런것들이 잠재적 범죄자잖아  아휴 무서워  집값떨어지겠어요  그러니까요 장애인들은 집에만 조용히 있었음좋겠어요  그러게요 괜히 애들 교육에도 좋지않겠어요  무슨말씀이세요? 감기처럼 치료가능한 질병이에요.  아니 우리가 못할말했어? 맞잖아 정신병자 아휴 옮을까 두렵네 왠만하면 보지맙시다?
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 아니 커피를 이따구로 만들어서 돈받고 팔아도 되는거야? 손님 어떤일로 그러시죠?  아니 커피가 쓰다고!!!!!!!평소에 먹던 커피처럼 달지거 않고 쓰다고!!!  손님 평소에는 마끼야또 드시다가 아메리카노 드셔서 쓰게 느껴지실 수있습니다  아니 이렇게 쓰면 어떻게 먹냐고  손님 그러면 따뜻한 물을 섞어서 좀 도 연하게 희석해서 드리겠습니다  아니 나 안먹어 환불해주고 내 시간도 보상해 당장  손님 이미 커피는 주문해주신 것이어서 환불은 어렵습니다  아니 내 입을 버려서 기분이 나쁘다고!!!!!!!!사장어딨어 사장 나오라고해  손님 죄송합니다 환불해드리겠습니다
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 옥상에서 사람이 떨어졌어요. 사람이 떨어졌다고요? 위치가 어디세요? 경기도 광주시 오포읍 문형리 행복 아파트인데요, 사람이 떨어졌어요. 몇층에서 떨어졌는지는 보셨나요? 아니요 어디서 떨어졌는지는 못봤어요. 알겠습니다. 잠시만 기다려 주세요.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 사장님 제 돈 돌려주세요 시끄러 너가 줬잖아 갚아주신다면서요 됐고 너가 준 이상 지금 내 돈이야 와 이런 도둑놈을 봤나 새끼야 인생은 먹고 먹히는 세상이야 사장님 진짜 천벌받아요 이러다가 음 호랑이가 사슴을 잡아먹는다고 천벌받냐? 네? 에휴 그러게 자신을 믿었어야지 남을 믿으면 어쩌냐 경찰에 신고 합니다. 진짜 신고 해봐 넌 일자리 없어 질줄 알아 새끼가 더 큰 돈을 받을수있는데
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 말편하게해도될까요 도 아니고 갑자기 다짜고짜 놓고 응응 마저 이러는데 나 첨에 잘못 들은줄 맞긴 뭐가 맞아 첨엔  있어 했는데 그때 딱 알았어 아 말 놓으려고 드릉드릉 하는구나
#
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 쓰레기통 비우고 왔으면 당연히 닦아야죠. 그거 다 막내 일인데. 안했네?  네 선배님 죄송합니다. 제가 바빠서 깜빡했습니다  회사 소문 안 궁금해요? 돌아가는 꼴 한번 재미있네.  네? 소문이요?  막내가 막내 일 제대로 못한다는 소문이 있던데 완전 사실이잖아. 대체 하는 게 뭐에요?  예? 그 저기. 시키시는 일 위주로.  저기요 눈치가 없어요? 네? 아 그. 죄송합니다. 그치만 사실 제 주요 업무를 위주로 하다보니.  주 업무? 지금 그쪽한테 그런 업무가 있긴 해요? 내가 그런 거 까지 알거 없고 똑바로해요. 장난치나 지금. 짤리고싶어요? 눈치껏 하라고. 재바르게.  네 죄송합니다.  대답 한마디 듣기가 어쩜 저렇게 힘드냐. 진짜 누가 뽑았는지. 인사팀 보는 눈 다 죽었지 쯧쯧
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 야 돼지 . 돼지 너 부르잖아 왜 너가 돼지야? 왜 대답해 하아 그러니까 살을 빼 돼지새끼야 하지마 뭘 하지마 너나 뚱뚱하지마 왜 그래 보기 역겨워서 그런다 왜
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 수민 씨 아침에 일찍 좀 오세요  저 지각 안했습니다  아니 신입이면 1시간 일찍 와야지  네?  요즘 애들은 기본이 없어 일찍 와서 커피도 타고 정리도 해놓고 그래야지  그건 부당하다고 생각합니다  이것 봐 바로 말대꾸야  말대꾸라뇨?  역시 싸가지가 없어 수민 씨는 회사 짧게 다니고 싶은가 보네  지금 무슨 말씀을 하시는지 모르겠네요
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 넌 뭔데 시비야?  그쪽이 먼저 시비걸지 않았나? 그 여자 놔줘. 형씨 정의의 사도라도 납셨나? 그냥 가던 길 가 못가겠다면? 그럼 너도 같이 맞던가. 평생 절름발이로 살게해줄까? 여자부터 놔줘. 여자는 아무 잘못 없어.  와 이거 어이없네. 순순히 놔줄거라 생각한게 웃기다야 남자답게 덤벼. 여자는 건드리지마. 난 내가 안 때려. 우리 애들이 대신 때리지. 가지마.! 그 여자만 으윽 놔주고 가
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 나 오늘 회사 지각한거 있지 헐 몇분이나 삼십분 하 미쳤다 어캐 됨 부장님한테 한시간동안 깨지고 왔다 개같은거 그래서 저기압이었구나 왜 늦었는데 아니 어제 깜빡하고 알람을 안 맞추고 잔거야 알람 안맞췄는데 삼십분밖에 안늦은거면 대단한건데 그치 그니까 부장님이 그걸 알아줘야되는데 그래도 앞으로 조심해야겠다
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 서류 오늘까지야 자리에 안계셔서 책상위에 올려 놓았습니다 그래?언제? 오전에요 그럼 내가 왔을때 다시 왔어야지.가정 교육을 못 받았나. 무슨 말씀이세요? 가정교육을 못받아서 일을 그리 하는거 아냐 저희 부모님께 막말 하시는 거에요? 막말은 무슨. 히스테리 대단하네. 남자친구랑 문제 있어? 뭐라구요?
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 안녕 얘들아 이번 반장은 내가 맡게 되었어. 모두들 잘 부탁해. 우와 축하해! 우리반을 위해 열심히 일을 해줘! 아 그런데 이번에 반장되고 반장으로서 너희들에게 할 말이 있어. 우리에게 할 말이 있다고? 뭔데? 벌써부터 일 하려는거야? 무리하지 마 이제 앞으로 아침마다 등교시간은 8시며 지각할 때마다 벌금을 오천원 씩 걷어 들이려고 해. 뭔소리야 우리 학교 원래 지정된 등교시간은 9시잖아. 아무리 반장이어도 교칙을 바꿔서는 안 돼. 더욱이 벌금같은 돈이 오가서는 안되고. 내가 반장이잖아. 너가 반장이야? 그럼 뭐 반장은 아무 재정도 없이 일을 해야해? 지각을 안하면 되는거잖아. 애초에 돈을 걷을 생각이면 그 돈을 어디에다 어떻게 쓸건지 말해줘야 하는게 먼저 아닐까? 일단 지각비로 걷은 오천원 중 삼천원은 반의 발전을 위해 쓸거고 이천원은 그래도 내가 반을 위해 일 하는데 수고금 같은건 가져가야지. 야 무슨 학교에서 반장 하나 하는데 돈이 필요해. 너 도둑놈심보다. 그럼 너가 반장하던지 그럴 용기도 없으면서 말이 많네? 어쨌든 내일부터 지각하면 오천원이야. 지각할 마음 있으면 오천원씩 들고와.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 신입 치마가 진짜 잘 어울린다. 아 감사해요. 앞으로 매일 치마 입고 안 돼? 얼마나 좋아? 네? 무슨 말씀이세요? 아니 신입이 치마 입고 사무실 걸어다니니까 얼마나 좋아. 무슨 말씀이신지 잘 모르겠어요. 사무실 분위기가 산다구. 예쁜 다리로 걸어다니니까 아 네. 기분이 조금 나쁘네요. 아이 참 뭘 그래. 조심해주세요.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 하지만 내려서 최대한 아무렇지 않은척 빨리 이곳을 벗어나자 이런일 익숙하다는 듯 사람이 그럴 수 있지 와 마자 태연한척 합리화하며 소심쟁이들끼리만의 공감대구나 이거시 와 그니깐 너무공감되고귀까지빨개지는 그런 썰이야
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 아 이자식 이십분이나 늦어 죽을래 미안 버스를 반대 방향으로 탔지 뭐야 지랄하네 그 핑계 이제 지겨워 임마 아 진짜야 됐고 니 한번만 더 늦으면 쌩깐다 알겠어 대신 내가 오늘 밥 사줄게 나 졸라 비싼거 먹는다 아이 그건 아니지 적당히 골라 너 용돈 받아서 돈 많잖아 한 턱 크게 쏴라 아 알겠어 골라
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 총 내려놔 너 이래 봤자 이미 경찰 불렀고 나는 그 사람 어디 갔는 지 몰라 경찰 오기 전에 튀면 그만이야 너 걔 어디 갔는 지 안불면 니 이마에 총알 박히는 거야 어디서 부터 잘못 한 건지 모르지만 나는 그 사람이랑 전혀 관련 없어. 그냥 나는 시키는 대로 할 뿐이었다고 웃기시네 너 잔챙이인 척 할려나 본데 다 알고 왔어 꿈틀 거리지 말고 제대로 손 들어 나는 정말 아랫것일 뿐이라니까 내 말좀 들어줘 너 3일 전에도 그 사람이랑 통화한 내역 나한테 있어 그거는 내가 약속했던 물건 준다고 만난 거고 역 앞에서 잠깐 만난 거야 그 사람 어디로 갔는 지 나는 몰라 조금이라도 알고 있는 거라도 빨리 불어 배를 타고 갔는 지 비행기를 탄 건지 아마 배를 탔을 거야 그게 밀수하기가 쉬우니까 나도 정말 모른다고 그 뒤에도 통화 내역이 있은 걸 내가 알게 되면 너 손가락 부터 잘라버릴 거야
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 천안 두정동 제이빌라 인데요, 지금 화재가 발생했어요. 빌라 어디에 불이 났나요? 1층 주차장에서 불이 나고 있어요. 그러면 지금 다친 사람도 있나요? 아직까지는 없는거 같아요. 알겠습니다. 지금 119 소방대를 보내도록 하겠습니다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 당신 블랙박스 삭제하세요! 당장!  내가왜요? 이게 당신에게 불리하게 작용하나요?  삭제하라면 할 것이지 말이 많아?  명령조로 제가 왜 말을 들어야하죠??목소리크면 다에요?  뭐?? 목소리크며 다냐고??  손찌검하시려거든 동영상녹화 하겠습니다  녹화한다는게 더 협박아닌가??  당신도 찍으시던지요.  무고한 상대로 고소를 하는게 말이 되나?  차량 훼손혐의 증거입니다.  그건 법정가서 얘기하면 되고 그게 나인지 확실한가??  변호사랑 얘기하시죠  내가 순순히넘어갈거같나? 밤길조심하라고  경찰에신고하겠습니다  신고? 뭘했다고신고?  협박이잖습니까?  증거있어? 사전동의없는 녹취는 증거도 안돼  .당신이 이러고도 사람이야??  뒤통수조심하라고  .절대 고소취하안할겁니다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 너 살 빼야겠다 살 빼야 겠지 나는 먹어도 잘 살도 안 찌는데 그래 좋겠다 너는 먹으면 살 찌는 편이니 뭐 그런 편이야 너는 공부 잘하니 아니 너 나한테 고마워 해야겠다 뚱뚱하고 공부도 못 하는데 친구 해 주잖아 그래 고맙다
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 신대리 오늘 내 아내가 계단에서 넘어져서 무릎 수술을 했다고 하더라고 이를 어쩌나. 어머 어떡해요. 많이 다치시는 않으셨나요? 한창 조심하셔야 할 나이인데. 그래서 말인데. 오늘 내 아내 간병 좀 부탁 드려도 될까? 내가 오늘 저녁에 술 약속이 있어서. 사모님께서 아프신데 병원에 직접 가셔야죠. 수술도 하셨다면서요. 친구들이랑 술 약속이야 거의 두달만에 가는건데 빠질 순 없잖아. 한 번만 부탁할게. 저도 오늘 친구들이랑 저녁 약속 있어서 안 돼요. 다음 달 결혼하는 친구 만나서 노는거라 빠지기가 좀 그렇네요. 내가 이렇게 부탁하는데도 거절하는거야? 내가 썩어빠진 물에서 건져 올려서 취직 시켜줬으면 이런 일 하나라도 해야지. 정말 실망이네. 제가 약속이 있어서 그래요. 정말 죄송합니다. 죄송하면 다 될거라 생각하는가? 이런 사소한 부탁도 못 들어주는데 나중에 회사에 중요 한 일 있을 때 내가 자네를 어떻게 믿나? 사소한것도 거절하니까 기분이 썩 좋지가 않네. 하.이번 부서이동 할 때 불이익 줄거니까 그렇게 알고 있어. 그럼. 사모님 간병 몇시까지 해드려야 하는건데요. 오늘 저녁 6시부터 모레 아침까지만 해주면 돼. 내가 지방으로 술마시러 가서 좀 오래걸려. 그건 안돼요. 저도 회사 쉬는 날 해야 할 일이 산더미입니다. 그럼 왜 물어봤나? 나 가지고 노는건가 자네? 그니까 자네가 일 할 곳도 없는거야. 얼굴부터 딱 보이거든 놀고 마실거 같은게.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 이 자료를 공개 시 당신의 명예를 실추시킬 수 있습니다  새꺄 해봐  네 해당 자료는 당신의 범죄이력을 적은 문서입니다. 괜찮습니까  어떻게 얻은거야  공개 시 아무런 무리가 없으신지 다시한번 여쭙습니다  살려주세요. 그거 있음 나 죽어요  좋습니다. 대신 제가 요구한 금액에 맞춰주시죠.  오 부디. 부탁드립니다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야 창모 신곡 나온거 들었어 아 당연하지 한시간 내내 들었잖아 개좋아 이번꺼 진짜 그니까 아니 근데 댓글 보니까 실망했다는 사람들도 있더라고 헐 그래 솔직히 실망할 정도는 아닌데 나도 놀랐어 뭐 모든 사람이 좋아하는건 불가능하긴하지 그렇긴해 아이유 싫어하는 사람도 있잖아 맞아 근데 내 주변에선 못보긴함 나도 아이유 싫어한다하면 좀 이상해보일듯 그니까 인정
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야 꼬맹아 일로와  아저씨 누군데요  아씨 오라면 와 임마  싫어요 도망갈래요.  가봐야 꼬맹이지 야 돈있냐  없어요 저 갈래요  아니 있으면 어쩔건데 맞고 싶냐  죄송해요.  아무거나 돈 되는거나 줘  네 여기요
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 아니. 마케팅 팀은 이번 행사 때 김민주사원인가 ? 그 사원 참 예쁘던데. 죄송해요. 제가 이번 행사에 더 열심히 했어야했는데. 뭐 박사원이 잘못을 한 건 아니지. 그렇게 생긴게 죄는 아니잖아 그렇게 생긴거라뇨.? 그렇잖아 그 때 반응도 그렇고 박사원나올 때랑 김민주사원 나올 때 반응부터가 너무 다르던데 뭐. 외모를 보고 뽑는 이벤트가 아니지 않았나요.? 요즘은 말야 외모도 능력이라고 기본으로 가지고 가야하는거야. 전 그렇게 생각하지 않습니다. 일 백날 열심히 해봐 나중에 누가 먼저 대리달고 승진하겠어. 참 아직 세상물정 모르는구나. 그래 가서 일이나 열심히 해. 그래야 조금이라도 따라가지. 제가 그렇게 많이 부족한가요.?  부족한 수준이면 말을 안하지. 괜찮아. 누구 탓을 해. 그렇지? 어디 샵이라도 다녀와봐 요즘 메이크업도 영 안어울린다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 좋은 아침 좋지 않아 왜 그래 무슨 일 있어 또 산더미처럼 들어가서 잠을 못 잤지 헐 설마 김 차장님 또 누구 겠니 나 정말 일 폭탄으로 누구 죽일 있어 그러게나 말이다 그런 좀 도와주겠니 친구야이 몸도 달리 할 일이 생긴 듯하다 힘내라 새끼
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 김대리 여기서 뭐해? 탕비실에 뭐 꿀 발라 놨니? 아닙니다. 바로 들어가겠습니다. 아니 내가 계속 보니까 김대리는 화장실에도 꿀 발라 놓고 탕비실에도 꿀 발라 놓았나? 아닙니다. 우린 이렇게 열심히 일하는데 김대리는 내가 볼 때마다 사라져있네? 회사가 편하나? 아닙니다. 열심히 하겠습니다. 아니. 내가 기합하는 것도 아니고 그럴 필요는 없는데. 옆 부서도 옆옆 부서도 대리들이 다 일 잘해서 좋다네? 그에 비해 우리 김대리는? 죄송합니다. 그렇게 사과만 하고 행동이 안 바뀌니 김대리가 아직도 대리인거지. 아무튼 내가 앞으로 김대리 지켜볼거야. 열심히 하겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 닌 진짜 다시 생각해 봤는데 그냥 살려주면 안될 것 같다. 그래 새끼야 한번 죽여봐라 이거 진짜 돌았노 그래 내가 못 찌를 줄 알았냐 왓다 마 진짜로 찌를 생각이네 알겠다 미안하다. 내가 잘못했다 아이가 도와주세요 여기 사람이 죽을것 같아요 뭔 상관이야 너도 죽여줄까? 아니요 죄송합니다. 그냥 조용히 지나가겠습니다. 그냥 보내줄 순 없지 너도 내 얼굴을 봤잖아 너도 이리로 와!
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 야 오늘 쟤로 우리 내기할까? 오 뭔데 뭔게 쟤가 빵을 몇 분안에 사오는지! 오우 쉣 콜 콜 만원빵이다? 오케이 야 길동아 지금부터 최대한 빵 빨리 사와라 어? 어어 알겠어! 키키 쟤 뛰는거봐라 내가 이기겠는데? 3분안에 무조건 온다 쟤 어리버리하느라 무조건 5분 이상이야 봐라 한 번 그러면 쟨 나한테 뒤지지 여 여기!! 야 7분이나 걸렸잖아 니 뒤질래?
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 아우 가만히 좀 있어 정신없어 죽겠네 저 새끼 저 고등학교부터 유명해  왜 고등학교때 어땠길래 그래 아주 다 말 걸고 다녀 정신없어 죽겠어 이리 갔다 저리 갔다 그런 걸 요즘 말로 인싸라고하지 인싸 얘는 아싸 나 지금 음악감상 중이거든 매앤날 가만히 누워만 있어 아주 난 이게 좋아 이 인싸새끼야
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 김대리 연차는 또 왜내? 아 예 부장님 막내가 많이 아파서 그렇습니다. 이래서 암탉이 울면 집안이 망한다니까? 아.죄송합니다 결혼하고 애 낳은 것들은 뽑지를 말아야해 죄송합니다. 시정하겠습니다. 뭘 시정해? 그냥 가서 설거지나 하고 살아 연차 제가 생각이 짧았습니다. 쯧 계집애들은 꼭 좋게 말하면 못 알아들어 .나가보겠습니다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 일날 도착했단 우편물이 보이지 않아요  뭐지 에 왜죠 모르겠어요 새 주소로 했는데 경비실이 있나요 아니면 편의점이 근처에 있나 아니 으아닠 자연스럽게 부동산에 맡기고갔나봐요 못살아 아씨 그 택배가 내것이었어  내것이었어
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 민성이 이번주 뭐하니? 네 대구에서 부모님 오시기러 했습니다 아그래?? 네 교수님 무슨일있으세요? 아니 우리 딸이 이번주에 귀국인데 내가 그날 약속이 있네 . 아네. 부모님몇시에 오시나? 오전에 오십니다 아 그럼 잘됏네 내 딸은 새벽 비행기로 오니까 자네가 다녀왔다가 바로 버스터미널로 부모님 모시러 가면 되겠구만 네. 좀 피곤하겠지만 다 젊을때 고생은 사서도 한다고하지 않나? 네
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 지금 당장 돈 꺼내라고 제가 지금 가진 돈이 없어요 그게 말이 돼 당장 내놔 진짜로 돈이 없어요 저도 월급을 못 받았어요 내가 그말을 믿을 거 같아? 그러면 너 진짜 죽는거야 잘못했어요 제가 다음달엔 꼭 드릴게요 내가 이 칼로 진짜 못 찌를 것 같지? 잘못했어요 죄송해요 내가 너네 집 가서도 깽판치고 다 부숴버릴 수 있어 안돼요 죄송해요 한번만 봐주세요
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 김기자 내일 그 기사 낼생각인가? 제상각은 변함 없습니다 그래 우리 김기자 뚝심있어 그래서 내가 좋아해 죄송합니다. 이렇게 나랑 척 지어도 괜찮겠어? 죄송합니다. 음 뭐 마음이 확고한건 알았어 근데 김기자 딸 이쁘더라? 네?? 우리 딸이랑 같은 나이던데 딸 못보면 상심이 크겠어? 무슨 소리를 하시는 겁니까 아니 잘 생각하라고 대의를 선택할지 딸을 고를지
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 그리거 니보증금 아빠가 내준대 사장한테 빌리지마래 아 왜 자는데 놀래라 을  왜 엄마한테 돈달라고안했냐고 빌려준다고 왜 남한테달라하냐고 말도안했냐면서
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야 나 오늘 차비가 없는데 만원만 빌려주라 안돼 나 돈 없어 뒤져서 나오면 뒤진다 너 저번에 빌려간 돈도 안갚았잖아 그것까지 한번에 갚을께 안돼 그것부터 내놔 벌써 10만원이야 미친 어서 돈 빌려주라고 갚겠다고 못믿어 못비렬줘 찌질하게 왜그러냐 사람 화나게 하지말아라 너는 뭐가 그렇게 떳떳하냐 마지막으로 말한다 어서 내놔
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 울고잇는데 옆에서 웃으면 나도 웃음나는거잇자나 그런거지 웃음벨같은거지 마저 인강다봣당 오이 완존슈퍼공부러셧 히히헤헤 근데 짧은거엿어 옹개꿀띠 지금 크루롤한다고 같이하제 옧글쿤 밥부터머거야지 그래용 캐춰 그래용 그래용 저녁은 뭐드세용 스퓀이랑 배부르게머것당 에벌써드심 그뤄치 와근데개졸령 지금 주무심 안되여 졸려죽겠는데 오늘방송없다하고 그냥지금부터잘까 띠로리 그정도야 잠깐 앉아서 자는건 어떠심 잠이미친듯이옴
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 씨파. 이것들이 지금 .내가 우스워? 아닙니다.형님 .죄송합니다  피맛을 니들이 아직 못봤지? 잘못했습니다. 살려주십시요. 흑흑흑 야. 눈알 하나씩 뽑자. 눈 하나없어도 다 보이제? 형님.살려만 주십시요. 시키는건 다하겠습니다  내손에 피 묻히기전에 해라 응
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 너 꿈이 뭐라고? 교수?  넵  네 머리로 무슨 교수는 교수야.  제 목표입니다.  현실성 없는 목표는 그냥 없는 것보다 못해. 포기해.  저는 제 꿈을 계속 실현해 나갈 것입니다.  그래 응원은 못해주겠다.  열심히 하겠습니다.  백날 해봐라 교수의 교 자도 못 따라갈거다.  그냥 저를 좀 응원해주셨으면 좋겠네요.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 승현씨 오늘 저녁에 약속있어요? 아니요. 없습니다. 잘됐네. 오늘 남아서 내 내 야근 좀 해줘요 네? 그거 대리님 야근이요? 네. 조금만 부탁해요. 나 우리애 학예회 가야 해서 아무래도 이건 아닌 것 같아요 대리님. 머가 아니라는 거야? 엄마로써 학예회는 가야지. 그래도 대리님 일이잖아요. 그래서 대타 뛰어달라는데 말이 많어. 그렇게 회사 다녀도 돼? 그래도 이건 아닌 것 같아요. 대리님.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 너 어제 영수씨랑 잤다며? 책임님. 누가 그런 소리를 해요.? 누구긴 여기 사람들 다 아는데? 정말 다들 왜그러시는 거에요. 저는 그런적 없어요. 흑흑 너가 영수씨 맨날 꼬리치고 다니잖아. 그러면 뻔하지 뭐. 제가 언제 꼬리치고 다녔다는 거에요? 어제는 술마시고 취한 척 영수씨 차에타고. 쯧쯧 저도 영수씨 때문에 많이 힘들어요. 회사생활 잘하고 싶으면 앞으로 조심해라 예.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 으악. 이게 뭐야! 어머 지혜야 너 안에 있었구나 너.너 정말. 아니 우리는 아까 걸레빨고 남은 물을 버려야 하는데 화장실이 다 닫혀있길래 아무대나 버린다는게 진짜 너무하는거 아니야!? 교복이고 다 젖었잖아! 어차피 너도 드러운데 씻었다 생각해  저 더러운 물로 씻었다니? 저 물이 아무리 더러워도 너만큼 더럽겠니?  진짜 돌았어 너? 아니? 그러니까 조심히 다녀 언제 또 이런 일 생길지 장담못하니까.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 너 살 좀 빠졌냐 아니 그대론데 아 그래 좀 빠진 것 같네 요즘 운동하기는 하는데 잘 안빠져 일주일에 몇번 가 나 두번정도 별로 안가네 더 많이 가야지 그런가 겨울이면 원래 더 안빠지는거 아냐 에이 그런가 모르겠네 더 열심히 해봐 알았어 고맙다
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 이 가방에 있는 돈 다 쓸어담아. 그러지 않으면 쏴 죽인다. 예. 알겠습니다. 제발 살려만 주십쇼. 움직이지 않고 뭐해! 당장 시작해! 알겠습니다. 거짓말하면 들통나는거 알지? 네 절대 거짓말 안 합니다. 경찰한테 신고하면 너 뿐만 아니라 너 주변에 있는 가족들 다 죽여버릴 줄 알아. 저는 괜찮지만 제 가족들은 죽이지 마세요.! 부탁입니다! 제대로 해. 일단 다리부터 쏠까? 죄송합니다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 내려놓고있기뭐해서 올린거야 응 어머니 캐리어 필요하시다며 문앞에둘테니까 가져가 배낭메고갈거래 짐다쌌어 알겠어 엄마 금토일 가는거였어 너일에 오전에가 새벽에가 그래 롤안해 응안해 아까 내 어떤 말에 기분이 나빴던거야  그거 모르는것도 기분이나빠 말해주면되잖아 내가 하는말 다 기분나빠겠지 아까말했어 근데 너가 그런식으로나온거지 진짜오늘일은 무조건 너잘못이야 나도 내가 일부러 안받는게아닌데 계속 그걸로 우리가 안좋게 이야기가 나오니까 기분이 안 좋아졌어 물론내가 너한테 말 안하고 빌려준게 잘못인건 알아 그래도 계속 그 얘기가 나오는게 싫어 너가 말안해도 생각나면 짜증나는데
#
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 너 나 좋아하냐?  어 좋아하지 죽을만큼 좋아? 응 당연하지 그럼 죽어봐 죽는시늉이라도 해봐 무슨말이야장난이지 사람 가지고 장난하니? 못죽겠으면 죽여줄께 내가 왜그래 진짜 너야말로 왜그래 나 좋아한다며 내가 죽어라면 죽을수도 있는거 아냐? 무슨말을 그렇게 해 지금 나 너무 무섭다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 내가 이번달까지라고 하지 않았나? 아. 월급이 밀리는 바람에 죄송합니다. 조금만 더 기회를 주십쇼. 됐고 오늘 이 각서 사인받으려고 온거야. 네? 다음달까지 못갚으면 여기 신장하나랑 여기 안구하나 대신 가져간다 오케이? 두 달만 더 주시면 안될까요? 장난해? 다음주까지로 해버리기 전에 알겠다고해. 예. 당장 각서에 사인해. 네 알겠습니다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 요새 살좀 빠졌네 민주씨? 아 네 신랑이 잘안해줘? 네?? 저 살빠지는거랑 신랑이랑 무슨 상관이. 신랑이 속썩이는거 아닌가 해서 글지 괜찮습니다. 이런 대화 불편해요 민주씨 상사가 걱정해서 하는 말에 왜이렇게 정색이야? 하지만. 하지만은 무슨 하지만이야 그렇게 딱딱하게 해서 사회생활 어찌고 하려고 그래? 죄송합니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 언니 이거하나사줘 아 이쁘네요 얼마에요? 30000원이야 네? 그냥 리본 삔인거 같은데 삼만원이요? 응 삼만원 아 다음에 살게요 언니 지금 장난해? 나 데리고 장난쳐? 그게 아니라 터무니없이 비싼것같아서 지금 나 길바닥에서 이런거 판다고 무시하냐고 그런거 아니에요. 그럼 얼른 사가라고 짜증나게 하지말고
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 여기 있던 돈 어디다 뒀어?  무슨 소리야? 돈이 어디있다고 그래?  얼른 내놔! 여기 있는거 마지막으로 확인했어!  또 도박하려고 하지? 미친 인간아!  이번엔 느낌이 아주 좋다고! 내가 톡톡히 쳐서 되돌려줄게!  지금 공과금 낼 돈도 없는데. 무슨 소리야?!  세간 살림 다 부셔놔야 정신 차리겠어?! 내놔!  그 돈이 어떤 돈인데.! 현아 등록금이야.  내가 그냥 달래? 돌려준다고!  아이고. 내 팔자야. 이 돈 쳐먹고 다시는 돌아오지마.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 예쁜이메리크리스마쑤 아직인뎅 원래 이브에하는거거든 카드써조 카드 어제 써서보냈는데 어디 카톡선물하면서 써서 보냈어 안봤나보네 그거카드아닌데
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 자 다들 일 멈추고 점심식사 하러갑시다  네 알겠습니다  자네도 갈거야? 일 더 안하고?  네. 저도 점심 식사 해야합니다  근데 우리는 선약이 있어서 안될 것 같은데  같이 먹으면 안될까요?  동료들이 불편해할 것 같은데 말이지  동료들이 저를 싫어하나요?  어쨌든 알아서 식사하라구  알겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 한수씨 네? 이번주말에 어디 나들이 안갈래요?  저요? 아 나 옆 팀 미영씨랑 사귀는거 알지? 아네. 아니 텐트치고 놀다올건데 내가 텐트 잘 못치잖아 아. 저번에 보니까 캠핑이 취미라든데 같이 가자구 아.안가면 안될까요 아니 같이 가서 고기도 구워먹고 좀 친해지자는건데 사람 왜이렇게 딱딱해 암튼 짐도 많고 머리가니까 토요일 8시까지 우리집앞으로와
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 사진 보셨죠? 이야.아내분이 있는데 이렇게 당당하게 바람을 피시다니. 뭐야.당신 어떻게 이걸. 에이 중요한겅 제가 이걸 어떻게 알았냐가 아니라 그쪽이 바람을 폈다는 사실이죠. 이걸 당신 부인이랑 가족들이 알게되면. 바라는게 뭐야 도데체. 뭐 다른건 없고 돈 한 3억 정도? 말도안되는. 갑자기 그런 큰돈이 어디서 구해진다고 내놓으란거야 뭐 어떻게 구하실진 저는 잘 모르겠고 못구하시면 부인분이랑 가족들이 크게 실망하실겁니다. 너.두고보자. 그럼 일주일내로 돈가지고 다시 봅시다. 일주일은 너무 짧아.한달만 시간을 줘.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 대성씨 네? 이번주말에 뭐해? 애들이랑 놀이동산 가기러 했습니다 아그래? 우리 아버지 과수원에 사과를 좀 따야하는데 네?? 아이고 대성씨 그렇게 귀가 어두워서 사회생할 어떻게하나? 무슨말씀이신지 애들이 데리고 와서 여기가 놀이동산이라 생각하고 풀어두고 자네는 사과좀 따지 그래 제가요??? 그럼 여기 누가있나? 주말에 보세 주소는 문자로 보낼테니
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 저.저기요 네? 아까부터 지켜봤는데 너무 예쁘시네요 네? 아 예. 감사합니다 저기 남자친구 있으세요? 그건 왜요? 없으면 만난것도 인연이니 차 한잔 하실 수 있나해서요 죄송해요. 시간이 없네요. 에이 그러지 말고 차 한잔만 합시다. 제가 보기에는 바빠보이지도 않는데 뭐하시는거예요? 이 손 치워요!
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 기타연주를 그것 밖에 못치냐? 죄송합니다. 그러면서 길거리 연주로 돈을 받으려고 해? 니가 받은 돈 내가 가져간다. 아니 주세요 뭐하세요 지금 야 빨리 도망가 넌 가만히 있어  아니 이거 범죄에요 신고 할거에요 신고해 봐라 어처피 우린 지문 등록도 안되어있는 노숙자라서 소용없어 도망치면 끝이야 도대체 왜 그러세요 넌 우리 구역에서 영업을 했어  뭐라고요 우리 구역에서 돈을 벌면 너 돈이 아니지
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 친구야 돈좀 빌려주라.  돈.? 왜 빌리려고? 왜긴 왜야. 매점가려 그러지  지난번에 빌려간 것도 안갚았잖아.  아 그거 얼마나 한다고! 나중에 한꺼번에 갚는다니까.  오늘은 돈 없어.  아니 그럼 아까 쉬는시간에 너 매점 다녀온건 뭐냐?  그때 남은돈 다 쓴거야.  그럼 너네 어머니께 지난번에 있었던일 전화로 말한다?  아. 알겠어. 여기 돈 줄게.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 내일까지 입금하세요  도저히 내일까지는 돈 마련 못할 것 같아요  그럼 저도 가만히 있지 않겠습니다  500만 원이라는 큰 돈을 어떻게 하루만에 마련하나요  그럼 인터넷에 유출해도 되나요?  그것만은. 안돼요 시간을 좀 더 주세요 부탁이예요  그럼 이번주 안까지는 돈 마련할 수 있나요?  이번주요? 하. 최대한 노력할게요  노력말고 확실히 입금하시길 바랍니다. 더이상 봐드리지 않고 사이트에 공개하겠습니다  알겠습니다.  시간 더 드렸으니 입금하시고 연락주세요. 이번이 마지막 기회 드리는겁니다  알겠습니다.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 이거 한정판 굿즈 아니야? 대박 영롱하다. 그지 우리 오빠들 너무 멋져. 오 고생한 보람 좀 있다. 그런 의미로 나 이것 좀 빌려주라 어? 안돼. 이거 나도 구하기 힘들었어. 하나라도 없어지면 난리나. 안 잃어버리고 잘 돌려줄게 그럼 되는거지 그래도. 이거 조금이라도 너 힘들게 얻은거야. 나도 자랑이란걸 좀 해보자 자랑만 하고 다시 돌려줄게 된거지 그럼?? 그래도 안돼. 야 다시 돌려준다고 돌려줘도 난리야. 좋은말로 할 때 줘라. 알았어. 빨리 돌려줘.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 새론씨 오늘 저녁에 약속있어요?  아니요. 없습니다. 잘됐다. 그럼 보고서 작성을 좀 부탁해도 될까요.? 내가 급하게 일이 생겨서 가야할 것 같은데. 네? 그거 주임님 일 아니에요? 그래도 내가 오늘 급한 일이 있어서 어려울 것 같네. 남아서 좀 부탁해요. 아무래도 이러한 방법은 좀 아닌 것 같아요 주임님. 머가 아니야? 내가 공손하게 부탁한다고 머 먹고 싶은거나 갖고 싶은거 있어? 그거 사주면 되는거지 아니에요. 대가를 바라는게 아니라 원래 주임님 일이잖아요. 그래서 뭐 좀 도와달라는데 말이 많니. 그렇게 회사 다녀도 돼? 그래도 이건 아닌 것 같아요. 주임님.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 친구가 나를 이용해 보장항목이 별로 없는 암보험 상품을 계약하게 했어 네? 친구가 그런 행동을 했다구요? 응 자기 실적을 올리려고 그런 행동을 했어. 믿었던 친구였는데 기분이 너무 나빠. 지금 이 상황을 바꾸기 위해 할 수 있는게 없을까요? 친구 회사에 연락을 해 볼까 해. 잘못 계약 했다고 당신이 원하는대로 일이 풀렸으면 좋겠어요
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 어 아가씨 잠깐 스돕스톱 누구세요? 아가씨 내가 요즘 좀 힘들어서 그런데 불우이웃 돕는다 생각하고 만원짜리 몇장만 좀 꺼내줘봐 왜 이러세요 왜 이러긴 아가씨는 도덕심이라곤 없어? 네 이웃을 사랑하라 몰라? 지금 부도덕 저지르고 있는게 누군데요. 이게 진짜 맞고 줄래 그냥 줄래 때리기 전에 좋은 말로 할래 달라니까 이 돈 진짜 저한테 소중한 돈이에요 이러지 마세요 잔말 말고 빨리 내놔 드릴테니 저 좀 보내주세요
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 야 내꺼 겁나 맛없어 내거도 그래 여기 개별로다 그니까 여기 리뷰 안좋은 이유가 있었네 내가 별로일 것 같다 그랬지 다신 오지 말자 그래 내가 어리석었네 그냥 저기나 갈걸 진짜 왜 이렇게 덮밥 잘하는데가 없지 이 주변엔 그니까 내가 집에서 만든거보다 맛이 없는게 말이 되냐고 우리가 가게 하나 차리자 콜 우리가 원탑 먹을듯 인정
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 내 이름 불러봐. 기. 기. 기.기철.아 내 이름이 기기기기철이냐? 제대로 불러! 기. 기. 야! 말더듬이! 똑바로 말 못해? 미. 미.안 야! 장애인! 너 말 한 번 더듬을 때마다 한 대씩이다? 왜.? 왜긴 네 목소리만 들어도 열불 터지니까 그렇지. 미. 미. 안
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 입어보시니 어떠세요 손님? 다 별로네 여기 옷이 다 왜이래? 그럼 어떤 옷을 원하시나요? 아니 그걸 아직도 파악 못했어? 옷가게 직원이 뭔 일을 이딴식으로 해! 죄송합니다 손님 근데 원하는걸 말해주서야 야 너 뭔데 눈을 똑바로 뜨고 나한테 이래라 저래라야? 아니 저 손님 지금 10벌 넘게 입어보셨는데 야 너 몇 살이야? 어디서 알바 주제에! 너 내가 누군지 알아? 죄송합니다 진정하세요 손님 매니저 불러와 너 가고 매니저 불러!
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 최대리 옷 샀어? 네!  또 똑같은 거므스레한 옷이네.  하하.이런 게 좋네요. 좀 화사하게 입어보지 그래 그래도 나름 깔끔한 옷으로 샀는데. 깔끔이 문제가 아니라 보는 재미도 있게 어우 강부장. 요즘 젊은 사람들 그런 말 하면 싫어해 하 그치? 내가 실수를 했네 원 아닙니다.하하 무슨 말도 못하는 세상에서 입을 나불댔구만. 하하
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야 야 이리와봐 왜.왜불러. 너는 친구가 부르는데 가봐야지 왜 부르냐고 물어보면 어떻게 해 미.미안.왔어. 애들아 성적표 나왔잖아. 얘 성적 궁금하지 않아? 그러지 마.내 성적.공개하지 마. 공걔하지마아 크크크크 말투 진짜 웃겨. 왜 성적 안좋아? 그.그게. 말 못하는거보면 성적 더 떨어졌나보네? 이렇게 나오니까 더 궁금하다 하지마.진짜로. 햬지마 얘 진짜 웃겨 성적표 어딨냐?
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 나 사고쳤어. 갑자기 무슨소리야 아 몰라. 걍 돈 좀 줘봐. 입막아야 하니까. 아니 갑자기 그게 무슨 소리야! 아!! 그냥 사고 쳤으니까 돈 달라고!!!!! 내용이 뭐가 중요해 내가 돈이 필요하다고!!! 무슨 사고를 친건지 알아야 돈을 주든 말든하지!! 무슨짓을 한거야!!! 몰카찍다 걸렸다!!! 재수가 없을라니까 그년이 합의 안해주면 빨간줄 걸린다고!! 합의하게 돈달라고! 너 진짜 미쳤어?!?! 씨발 내가 몰카 좀 찍었을 수도 있지 돈 줄거야 말거야!!! 몰카라니 너 똑바로 이야기해 니가 찍은거 맞아? 안걸렸으면 이러고 있겠냐고!! 아 어쩔거야 나 빨간줄 그이게 걍 냅둬?! 어? 합의포기하고 이대로 빨간 줄 끄일까?! 돈 줄거야 말거야!!!!!
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 내가 너한테 얼마나 잘했는데. 술만 마시면 욕하고 때리고. 내가 취해서 그랬어.  그게 니 본성이야. 말 다 했어? 어. 헤어져. 안 돼. 너 없으면 나 못 살아. 나 죽는 꼴 보고 싶어? 죽으려면 몰래 죽어. 광고하지 말고. 너 진짜 사람 미치게 한다. 한번 더 헤어지자는 말 하면 쥐도 새도 모르게 죽여버릴줄 알아. 이거 놔!
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 마스크써주세요 공공장소입니다 니가뭔데 쓰라마라야 코로나로 예민한때에 우리모두 조심해야 합니다 백신맞아서 안써도돼 돌파감염도 있으니 주의해주세요 야 참견하지마 여기 제가하나드릴게요 나사실 코로나 환자인데 너같은것들 코로나걸리라고 안쓰는건데 옮아라 너는 코로나걸려 죽을꺼야 보건당국에 신고할게요
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 저 그만좀 하시면 안될까요 야 니가 만져도 된다고 거의 이미 합의가 된상태야 만약 경찰한테 신고 하면 그날 니 맞아 죽는줄알아라 네 알겠습니다. 야 안되겠어 그냥 살려두면 신고할게 뻔해 그래 안되겠다  살려주세요. 진짜 다시 경고 한다. 신고 하면 죽는다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 거지 왔네 나 거지 아니야 맞잖아 너네 아빠 어제 노가다 하는거 봤어 헐 진짜? 니가뭔데! 아니 난그냥 본걸 말하는거야 그거 하루종일 일하면 얼마 받어? 하루 한 끼는 먹고 살 수 있어? 야야 얘 운다! 찐따새끼
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 지금 사장딸 없어서 에어팟끼고 동영상 보고 있어 사장 심부름 간다고 갔는데 아직도  걔 땡땡이치네  바로 집갔을수도 있고  하 상상하니까  열받네 아냐 오늘 금요일이잖아 우리 즐겁게 지내자 알겠엉
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 넌 좀 그냥 죽어 내가 뭘 그렇게 잘못했는데 그냥 꼴뵈기 싫어 이유라도 물어보자 그냥 장난이지 그게 장난이야? 재밌잖아 이상한 헛소문부터 시작해서 죽으라고 하는 게 장난 이냐고 나한텐 장난인데 재밌음 그만해 이제 그냥 맞자 넌
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 갬성 국 굳 왜 그래 나한테 엥 뭐가아 뻥치지 말라니 이 반응은 뭐지 그냥 인터넷에 도는 짤 같았어 입맛감퇴짤 짤 제조기인가 멋졍 머래 나 곧 노래하러 나간다 지금 백스테이지임 오롯
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 돈 내놔 왜? 당신이 뺑소니 범인이라는 것 알고 있어 헉 그걸!! 그러니 범인이라고 말하기 전에 내놔 1000만원이면 되나? 그걸론 어림 없지 2000만원 내놔 알았어 그럼 각서 써 어 다신 이 일로 찾아오는 일은 없어야 해
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 어 저기좀봐 장애인이다. 절뚝거리는거 개웃기네. 자기 갈 길 갑시다. 왜? 웃지도 못해? 제 기분이 나쁘잖아요. 나는 기분 좋은데? 내맘이야. 에휴 방금 한숨쉬었니? 장애인주제에 감히 똑같은 사람인데 말 좀 가려서 하세요. 어떻게 똑같니 너랑 나랑. 그냥 제발좀 갈 길 가자구요.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 자네는 정말 할 줄 아는게 뭔가? 죄송합니다. 좀 더 잘하겠습니다. 이래서 대학 나온 사람은 제대로 된게 없다니깐. 한번만 더 기회를 주십시오. 기회를 준다고 그 병신같은 아이디어가 바뀌기나 하겠어? 관 둬 제가 좀 더 노력하겠습니다. 앞으로 퇴근시간을 늦출거니 그렇게 알아. 그렇게까지 하셔야합니까? 질이 모자라면 양으로 승부보는건 당연하지 안그래? .알겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 지금 당장 책상 위에 올려진 약 먹어  어떤 약물인지 확인 되지 않아 먹을 수 없습니다.  빨리 약 먹으라고 !  도대체 왜 먹으라는 거죠?  쓰레기 같은 새끼가 먹으라면 먹으면 되지 말이 많아. 니 집 주소 알고 있어. 자꾸 이런식으로 나오면 직접 찾아가서 죽여버릴거야.  뭐라고 ? 제발 그만해  아주 고통스럽게 칼로 죽여버릴거야.  왜 계속 이러는거야.  칼로 죽이든 약먹여서 죽이든 당장 죽여버릴거야.  너 협박죄로 고소 할 거고 약도 절대 먹지 않아.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 곽두팔. 드디어 잡았다.  누가 꼰질렀어? 어떤 새끼야?  어휴. 누구겠어? 니 똘마니가 술술 불더라.  김두식. 이 자식. 죽여버릴거야!  어우. 이제 감옥 가서 콩밥 먹고 성격 좀 죽여  씨발! 너도 죽여버릴꺼야! 내가 니 배에 칼빵 쑤실거야  얼른 차에 태워.  네 알겠습니다.  개새끼야! 넌 두번째 보는 날에 얼굴을 반쪽으로 만들어줄거야. 이 더러운 짭새 새끼  입만 살아선. 얼른 데려가
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 유행복 너 어디야 누가 아직까지 집에 안 들어오래. 오늘 맞을 준비해라. 나 아빠가 너무 때리니까 무서워서 집에 안 들어갈거야. 나혼자 알아서 잘 살거니까 걱정마. 이제연락하지 마. 너만 연락 끊으면 될 거같냐? 내가 그럴줄알고 너 폰에 위치추적기 깔아뒀어. 기다려 곧 데리러 갈거니까. 오지마! 오면 바로 신고해버릴거야. 경찰에 잡혀 가고 싶으면 그렇게 해. 참나 너가 뭘 모르나본데 폰 켜서 지도 봐봐. 근처에 경찰서 있나. 나10분 뒤면 도착하니까 기다려라. 싫어. 아빠 무서워. 나 진짜 알아서 살 거니까 제발 그만 좀 포기해. 아니? 너 내 딸이야 죽어도 나랑 죽고 살아도 나랑 살아야 해. 그리고 아빠한테 허락도 안 받고 집을 나가? 기다려 오늘 정신교육 제대로 시켜줄테니까 나 좀 제발 그만 괴롭혀 나 죽을거 같단 말이야. 사는 게 너무 무서워. 그니까 내가 죽여준다고 기다리라고 몇 번을 말해야해? 내가 깔끔히 죽여준다고. 보이네? 거기서 뭐해 아빠랑 빨리 집에가자. 가까이 오지마. 제발 가까이 오지마
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 이혼하자 우리 이혼? 누구 좋자고이혼해 너 그년만나러 가지? 너의 폭언과 폭행에 지쳤어.나 만나는 사람도 없어 거짓말하지마 내가 병신같아? 그런거 아니야 정말 이제는 지쳐서 그래 누굴 만날 힘도 없어 아 그래서 조강지처 버리고 가려고? 솔직히 말하자 너 그동안 결혼생활에 충실히 안하고 매일 경마장 가고 애들 밥도 제대로 안해줬잖아 애들은 내가 키울게 아 내가 경마장 다닌건 다 우리가족 잘 되라고 다닌거지 큰건하나 하면 되니까 제발 그만해 나 이제 지쳤어 아 그럼 나 버리고 간다고? 내가 나 버리면 너랑 우리새끼들 그냥 둘거같아? 그게 무슨말이야! 너 애엄마야 정신차려 니가 지금 나를 버린다는데 내가 제정신이겠어? 나도 쫓아가서 다 죽여버리고 나도 죽을거 야
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 야 너 좀 따라와 왜요? 형이 오라면 오지 말이 많아 저 집에 가야 해요 지갑만 두고 가. 그러면 가도 돼 저 돈 없어요. 진짜에요 뒤져서 나오면 1원에 한 대다 왜 이러세요. 좋게 말하면 말을 안 들어요. 요즘 애들은 집에 보내 주세요. 제발요
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 이번 일은 너가 맡도록해. 예? 저번에도 제가 하지 않았습니까. 그래서 안할거야? 좀 힘들것 같습니다. 니 자식들 목숨이 내 손가락 하나에 달려있다는거 잊었나 보구나? 제발 제 자식들 만큼은 건들지 말아주세요. 나도 내가 니 자식들 안건드렸으면 좋겠어 예. 제가 이번일 맡겠습니다. 그래 좋은 가장이 돼야지 예.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 이게 뭐냐? 아 애니메이션 보고 있는거야. 이런걸 누가 보냐? 유치하게. 뭐? 너가 무슨 상관인데. 그러니까 너가 친구가 없는거지. 말 다 했어? 너 자꾸 기어오른다? 미안. 그냥 가주라. 나한테 오라가라 하는거야? 죽을래? 미안.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 시신을 발견했습니다. 위치가 어디시죠? 인천 영흥도인근 해상인데요, 검은색 옷을 입은 남자가 떠있는것을 발견했어요. 그럼 가까운 지상으로 시신을 가져와주실수 있나요? 네 영흥도 부둣가로 갈게요 알겠습니다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 머 그건 자기가 알아서 하겠죠 저번에 백만원 자기가 전화해야되는거아냥 아니 그쪽에서 합의보자고 연락이 오지 음 계속 안오면 아
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 아  아진짜짜증나 이 회사 진짜가지가지한다 왜 개월에한번씩 자신의 성과를 정리해서 어필하래 뭔소리여 아근데진짜 얼마나 준다고 이제 어필할때가 되셨나요 아진짜하기싫엌에바야
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 여부 안녕 오늘도 너무 행복했어 조심히 들어가요 여부야다 여뷰 바보 집 잘들어가써 이모티콘 넹 여뷰 나두 오늘 너무 행복해써 사랑해 나듀 나 사랑해 좋겟당
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 아가씨 집이어디야? 왜그러세요 내가 집까지 태워줄게.타 저 혼자 갈수 있어요 소리지르면 죽는다 죄송한데 저지금 통화중이라 녹음되요 전화 당장끊어.안그럼 핸드폰이랑 같이 니 팔도 박살내버릴테니깐. 살려주세요 당장 따라와! 이러지 마세요
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 어이 김대리 자네 뭐하고 있나? 옙 최부장님 어제 말씀하신 리포트 작성중입니다 아니 대리나 달고 아직도 그런 센스가 없어? 예.? 아침에 출근할때 우리 마실것들 사와야 되는거 아니야? 아 제가 오늘 지각 할것같아서 깜박했습니다 죄송합니다. 죄송하면 다야? 회사 짤리고 싶어? 회장님 아들이랑 나랑 친구인거 까먹었어?? 죄송합니다. 정신 바짝 차리겠습니다. 하여간에 빠져가지고 당장 카페가서 커피 5분내로 사와 넵 빠르게 준비하겠습니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 나 요즘 살 개쪘다 그래보임 뭐 이 새끼가 몇 키로 쪘는데 몰라 한 오키로 찌지 않았을까 맨날 처먹고 운동도 안하니까 살찌지 돼지야 빡치는데 팩트라 할말이 없네 그만 처먹고 나가서 좀 뛰어라 뱃살 극혐 아 이새끼는 말라서 개부럽네 개꿀
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야! 너좀저리가 왜그러니 너만보면 신경질나 바보같이 뭐하냐? 좀심한거아냐? 너같은 찐따는 없어지면 좋겠다 난 잘못한거없는데 넌 그냥 우리반에서 존재자체가 짜증이야 내가 어떻게 하면 되는데 그냥 내눈에서 사라져버려라 으이구 찐따 미안하다
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 아가야 너 원래 일처리 이런식으로 하냐? 죄송합니다 뭐가 죄송한데? 죄송합니다 대답 똑바로 안해? 죽고싶어? 다음부터는 이런 실수하지 않겠습니다. 정신차려라 어? 이러다 너 모가지가 먼저 날아가는수가 있어. 네 명심하겠습니다. 한번 더 이러면 너네 집 불살라버릴거야. 가족들 타죽는꼴 보고싶으면 그런식으로 해라. 절대 그런일 없을겁니다. 죄송합니다.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 야 너 이름이 뭐냐? 김지호. 얘 생긴거 장애인같네. 응? 응? 응이라고 했냐? 아.아냐. 아니긴 뭐가 아니야. 내가 잘못 들은거냐? 미안. 얘 진짜 장애인 맞네. 아니야. 너 오늘부터 내가 찍었다. 마음에 안드는 놈. 미안해. 넌 큰일났다. 장애인 새끼야
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 회사에서 성희롱 타깃이 된 것 같아서 우울해. 직장 내 성희롱 때문에 우울하시군요. 좀 더 이야기 해 주시겠어요? 다른 직원들이 옆자리 직원을 성희롱 하는 게 보여서 도와줬더니 이번엔 내가 타깃이 되었어. 어떻게 하면 성희롱 문제를 해결할 수 있을까요? 내일 직장 내 성희롱 관련 담당자를 찾아가봐야겠어. 일이 잘 풀려서 우울한 기분이 나아지면 좋겠어요.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 우리 헤어졌잖아. 이제 그만해.  제발.한번만 더 기회를 줘.  저번에도 그랬다가 나 때렸잖아.  이번이 마지막이야.진짜 이번에도 그러면 더이상안올게.  이제 니말 못믿겠어.그만하자  나 죽는거 보고싶어? 아님 널 죽일까?  뭐라고??? 미쳤어? 안가면 신고할게.  신고? 그 전에 내가 죽든 니가죽든 하자.  그만해 !! 아악  이렇게 맞을 줄 알았으면 내말 들었어야지.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 아 아 마이크 테스트 빠가야 5초 내로 튀어온나.  부르셨습니까?  야 미쳤냐? 커피에 설탕이 0.000115 파운드 더 들어가 있잖아. 나 당뇨병 걸리라고 일부로 그런 거지?  아닙니다.  근데 이 자식이 또. 너는 늘 그렇지만 말투부터 띠겁단 말이야. 일부로 나 기분 나쁘라고 그러는 거냐 선천적으로 그렇게 태어난 거냐?  그건 원래.  저는 원래부터 그 개념이 싸가지가 없는 놈 입니다. 그렇게 태어났으니까요. 이 말이지? 이거 순수악 같은 새끼네. 알면 고치려고 노력을 해야지. 척이라도 해야지. 넌 회사 사람들에 대한 '리스펙트'가 없어 고졸 새끼가 우리 회사 문을 두드린 것 자체가 졸라 리스펙트가 없는 거지. 가 뭔 뜻인지는 아냐?  제가 이 회사에 들어온 것은.  저능아 할당제 뭐 그런 거 아니겠냐? 아니면 면접관들 책상 밑에서 면접을 봤냐? 낄낄. 뭘 꼬라봐? 꺼져.  .나가보겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 아 개뜨거워 뭐하냐 커피 먹다가 입천장 다 데일뻔했네 졸라 뜨거 오바 떨기는 야 먹어봐 진짜 졸라 뜨겁다니까 이게 뭐가 뜨겁냐 나약한 새끼 와 이자식은 혀에 감각이 없나 저걸 어케 마시지 니가 나약한거다 더 성장해와라 아 이딴걸로 자부심 갖지 말라고 애기는 호호 불어 마셔
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 김씨 주말에 뭐하세요? 네 부장님. 저 가족들과 약속이 있습니다 어디서? 여의도요 그러면 가기 전에 내 딸좀 픽업해서 집에 내려주고  아 저는 약속이 있는데요. 아니 약속 가기 전에 잠깐 가라니까 네? 그것도 못해? 내 부탁인데? 알겠습니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 와 오늘 괜히 기분히 좋네 닐씨가 좋아서 그런가 그냥 오늘 컨디션도 좋고 날씨도 딱 좋고 걱정거리도 없고 해서 기분 짱 좋네 올 그럼 나랑 오늘 놀러갈래 영화 볼까 오 좋은데 요즘 개봉한거 있나 듄이라는 영화 개봉했던데 반지의제왕 같은 에스에프 영화인가봐 아 나 에쓰에프는 별론데 까다로운 년 그럼 이따 노래방이나 갈까 아 그래 노래방 좋다 노래방 가자 애들 더 불러야지 누구 부를까? 그냥 너가 부르고 싶은 애들 아무나 불러 그럼 수영이랑 명현이 부른다 그래 학교 끝나고 바로 갈거지 응 그러자
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 이새끼 이것도 틀려? 틀린건가? 바보자식. 이래가지고 대학은 가겠니 공부열심히하고있어 열심히만하면돼? 머리가나쁘잖아.누굴닮아서 부모욕은 하지마 어쭈 죽을래? 미안 넌진짜 세상어찌살려고. 한심하다 미안해
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 돈 있냐 응 아니 없는데 새끼 돈 좀 들고 다녀라 형이 쏠게 피시방 가자 오 웬일이지 이 새끼가 용돈받았다 가자 그래 나야 땡큐지  담엔 너가 쏴 씨발 알았냐 봐서 이 새끼가 진짜 확 꺼져 쫌
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 담임이랑 무슨 얘기 한거야? 설마 너 이른건 아니지? 아니 그냥 진로 상담한거야. 그걸 무슨수로 믿어? 너. 거짓말 한 거면 길가다 조심 좀 해야할거야. 그게 무슨 뜻이야? 뭐 왜 길에 위험한게 얼마나 많냐. 지금 나 협박하는거야? 글쎄 우리 아빠 이름 대면 가벼운 접촉사고든 취객이랑 시비 같은 적당한 이유로 경찰도 넘어갈거라 이거지. 나 안 일렀어. 알 일렀다고! 믿어도 되는거지? 물어봐서 니가 거짓말한 거면 다리 한두개쯤 부러질 각오는 해라? 아니면. 목을 부러뜨려줄까? . 대체 자꾸 날 괴롭히는 이유가 뭐야!
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 길동씨 어디까지 했어? 아직 하는 중입니다 아직도? 왜 이렇게 일을 못해 죄송합니다 하. 정말 죄송해요 아니 내가 길동씨 좋으라고 이러는 거야 빨리해 진짜 죄송합니다 누가 고졸아니랄까봐. 네.? 죄송합니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 이거 재연씨 아이디어인가? 네 그렇습니다. 아니지 아니지. 무슨 말씀이신지? 지금부터는 내 아이디어지. 내가 사수잖아. 그렇지만 제가 초안부터 다 작성했는데. 지금 말대꾸 하는건가? 아닙니다. 상사가 키워준 은혜도 모르고 이러면 안되지. 그렇지만. 어쨌든 이 기획안 내 이름으로 올릴거다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 이봐요 아가씨 이거 환불좀 해줘  아 환불하시려면 구매하셨던 종이들 옷걸이들 다 들고오셔야합니다  한번 입어보다가 종이가 살짝 찢어져서 그래  다시 팔아야하는 옷이라서 전 상품이 다 있어야해요  아 종이 안에 넣은거 티도 안나더만  죄송합니다 규정이 그래서요  아니 규정맞춰서 살 정도로 그렇게 갑갑해서 어떡해?  저도 알바생이라서 업체 내규가 그래서요. 죄송합니다  하 참 됐어 됐고 안입을거니까 버리던가 맘대로하고 본사에다가 컴플레인 걸어야겠다  고객님 잠시만 점장님께 여쭤보기라도 할게요 잠시만 기다려주세요  아니 되는데 안된다고 한거야? 아가씨 알바생 맞아? 일머리가 그리없어서 어떡해?  점장님 불러올게요 죄송합니다
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 아효 덥네. 저 조금만 쉬겠습니다. 야 선풍기 가져간다. 너 어쩌피 쉴 거라며. 네.? 저 지금 두 시간동안 에어컨은 커녕 선풍기도 없이 땡볕에서 사람들 코로나 검사 했어요. 잠시 쉴 때 선풍기 쓰면 안될까요? 어 안돼. 너 쓰라고 가져다 둔 선풍기 아니야. 그리고 뭐 검사해주는 게 힘들어? 사람들 문진하고 그러는 게 더 힘들어. 문진실에는 에어컨 돌잖아요. 검사소에는 선풍기도 못 킨단 말이에요. 저 진짜 너무 더워서 쓰러질거 같아요. 한 번만 양보해주세요. 야 꾀병 부리지마. 뭘 선풍기 하나 안 쐰다고 쓰러지냐? 그럼 그 방역복을 벗어 더우면. 지금 코로나 검사 하고 있는데 여기서 방역복을 벗으라구요.? 그럼 바로 감염될 확률 높은거 모르세요? 지금까지 검사하고 왔는데 앉아계셨으면서 선풍기 하나 양보 못 해주시나요? 야 그니까 내가 왜 너한테 양보해줘야 하는데. 누가 코로나 병원 전담 지원하래? 너가 지원해놓고 왜 유세야. 하는거 없이 주 4회밖에 출근 안 하면서 대우는 엄청 받고 싶어하네. 너 일하는거 보면 급여 안 받아도 될 정도로 설렁설렁해 몰라? 제가 하루 코로나 검사 거의 다 하는데 그게 왜 설렁설렁인가요? 넌 일하는 모습이 진짜 마음에 안들어. 다 설렁설렁 하는거 같고 야 그리고 니 선배는 저렇게 일 하고 있는데 넌 쉬려고 해? 아주 기강이 제대로 안 잡혔네. 돈 받고 일하면 정해진 휴식시간 이외에는 쉴 생각 하지마. 점심시간 외에는 검사에만 계속 집중하라고.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 어이 아가씨 몸매 이쁘네 네? 딱 붙는 옷에 짧은 치마 크흐 섹시하다 아 남자친구한테 사랑 많이 받겠어 그만하세요 기분나빠요. 뭐가 기분나빠 칭찬하는건데 내가 조금만 어렸어도 아가씨 만났을텐데 그만하시라구요 .! 이런 말 듣기싫으면 그렇게 입지 말던가 지가 그렇게 나 보세요 하는 복장이면서 아 .불쾌해요
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 김쌤 학부모들 클레임 들어왔어 어떻게 할 거야? 저는 정말 학생을 때리지 않았습니다. 그런데 애는 왜 선생님한테 맞았다고 하죠? 애가 거짓말이라도 한다는 건가요? 학부모가 원하는거는 다 해주세요. 네? 제가 왜 그래야 하죠? 이 학생 아빠가 교육감이에요. 회사잘리고 싶어요? 네? 저는 결백합니다 교장선생님. 그건 모르겠고 우리한테까지 타격을 입을 수는 없지 않나? 학생 안때렸습니다. 정말이에요. 무릎꿇고 가서 사과하고 용서받아 그래야 학교에서 안짤리지. 아.결백합니다 교장선생님.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 최주임 오늘 저녁 약속있어?? 박과장님! 아니요 없어요 그럼 오늘 둘이서 술한잔 어때? 네?? 아니요. 괜찮습니다. 집에 가보겠습니다. 어 왜왜!! 그럼 최주임 집에서 어때? 여자가 사는 자취방은 어떤지 궁금하기도 하고  괜찮습니다. 그래?!! 오늘 야근할생각하고! 최주임 이 프로젝트좀 완성해봐! 박과장님 제가 해야할 업무는 다 끝냈고 이건 박과장님 업무인데 아닌가요? 선임이 일을 주면 할수도 있지! 그래서 못하겠다고? 직장의 매운맛을 덜 봤구나? 이건 박과장님 제안 거부에 따른 보복조치 라고 느껴지는데요? 요즘젊은이는 까탈스럽고 튕기는것도 많아. 너같은 직원은 같이 일하기 힘든거 아니? 말씀이 심하시네요!
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 내 지갑 너가 훔쳤니? 그게 무슨말이야? 아니 너가 전에 내 지갑보고 이쁘다했잖아 그래서 너가 훔친 줄 알았지 나 아닌데. 아그래 ? 근데 왜 다른애가 너가 내 지갑을 훔치는걸 봤다고 할까? 아 맞다 너 집 가난하지? 그래서 도벽있는건가 ? 나.나.진짜아니야 !! 억울해 . 그럼 지갑이 뭐 발이라도 달렸니 ?
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# ...
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 미안합니다. 지금 우리 딸을 살려야 해요.  그래도 이건.!  죽지 않을 만큼만 뽑겠습니다.  지금 식칼을 들고 그런 말을 하면 내가 어떻게 믿습니까?  믿어주세요. 제가 너무 급합니다.  이렇게 뽑는다고 당신 딸 못 살려요!  당신이 어떻게 알아요? 우리 딸 살릴 수 있으면 몇 명이라도 죽일 수 있습니다.  이 미친 놈!!!
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 이대리 당신은 이것밖에 못하나?  죄송합니다. 그러니까 당신이 43인데도 대리인거야 말이 심하십니다. 아니 내가 틀린말이라도 했어?? 대리가 일처리를 똑바로 하면 내가 이런 말을 안할거 아니야 죄송합니다. 제가 요즘 신경쓰이는 일이 생겨서. 어휴 이래서 내가 들어보지도 못한 출신인 사람은 들여보는게 아니라고 회장님한테 말했는데. 어휴 이대리 또 무슨일이야 어제 딸이랑 싸웠다더니 회사에서 또 뭔일이야?? 어휴 그 아빠에 그 딸이구만 딱봐도 이대리 문제겠지 . 가보겠습니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 내가 여기 12년 다닌 것도 아니고 자그마치 10년을 다녔어!!! 고객님 그래도 다 반 이상을 사용하시고 바꿔 달라는 건 아니잖아요. 이 새끼가 말귀를 못 알아듣네. 우리 여기 라고!!! 고객님 아시잖아요 전에도 오셔서 한번 바꿔 드렸을 떄 다음에는 안된다고 말씀 드렸잖아요. 아니 왜 한번은 되고 두번은 안되!!! 당장 바꿔주던지 환불해 내!!! 너 말고 니 윗사람 나오라그래!! 너 같은거랑 말하기 싫어!! 니가 직장을 짤려 봐야 정신차리지!!! 고객님 왜그러세요 저번에도 이러셔서 제가 얼마나 곤란했다구요. 제 사비로 대신 메꿔서 바꿔드렸잖아요. 그럼 요번에도 바꿔줘 니가 메꾸는 돈보다 우리가 쓰는 돈이 더 많잖아!!! 우리가 여기서 쓰는 돈이 얼만데 이것도 못해줘?
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 오빠 나 생일선물 뭐 해줄거야 뭐 받고싶어 나 명품빽사줘 아 내가 어떻게 명품백을 사주냐 장난이야 나랑 분위기 좋은 식당가자 음 그럼 강남에 저번 거기갈까 저번 거기가 어디지 그 강남역 근처에 있던곳인데 이름이 기억안나네 하여튼 막 스테이크팔고 이런곳 가고싶어 그래 내가 한번 알아볼께
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 서류를 이따위로 작성해 죄송합니다 이따위로 쓸 거면 회사 그만둬 민폐야 어디를 고쳐야하는지 알려주시면 바로 수정하겠습니다 뭘 알려줘 스스로 해야지 머리가 돌이니까 제대로 안 돌아가는 거지 팀장님 말씀이 너무 심하세요 뭘 심해 너같은 돌대가리를 데리고 있다는 데 창피하다 너무하세요 뭐가 너무해 이 돌대가리야 돌대가리야 당장 그만두라고 항상 이유는 설명 안해주시고 .
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 난 네 비밀을 알고있어  뭐라고?  가 죽은 그날 같이있었던거 알아  같이 있긴했지만 그뒤에 걔가 그렇게 될지 몰랐어  거짓말 하지마 너가 그자리에 같이있는걸 봤어  그래서? 증언이라도 할거야?  그건 너가 하기에 달렸지  나한테 뭘원하는데?  오늘부터 나랑 사귀는척해  그래 알겠어
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 김인턴 이리 와보게 네 과장님 내가 자네를 왜 불렀는지 알겠나? 잘 모르겠습니다 왜 그러십니까? 자네한테 맡긴 일이 잘 안 풀려서 내가 혼나게 생겼잖나! 아 죄송합니다 자네는 벙어리에 곱추같이 걸어다니고 할 수 있는게 뭔가? 죄송합니다. 더 노력하겠습니다. 내일까지 그 똥머리 굴려서 수정안 제출하게 그 전까진 야근이야. 알겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 여보세요 네 부장님 어 지금 안 바쁘지? 네 용무 있으세요? 어 아니 집에 애가 혼자 있는데 봐줄사람이 없네 네? 그래서요 애 좀 봐달라고 어차피 할 것도 없잖아 아니 아무리 그래도 애를 봐주다뇨 부장님 뭐? 회사생활 편하지 요즘? 빨리 가봐! 하. 싫다고 말 했습니다
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 짠 얼마 전에 생일이 없다며 호박 초콜릿네 어떻게 알았어 민성이가 그러더라 늦게 알았네 생일 축하해 아니야 괜찮아 고마워 끝나고 뭐 해 응 딱히 일정은 없어 왜 그럼 끝나고 밥 먹자 내가 사줄게 좋아 어디 갈까요 근처 파스타집 있던데 어때 2층에 있는 거 거기 가성비도 좋고 맛있대 오케이 거기로 가자
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 같이 게임하게 몇 번 방으로 들어와 나 오늘은 학원 가야 돼서 못 들어 갈 것 같아 까불지 말고 좋은 말로 할 때 들어와라 정말이야 야 오늘은 학원 가야 해 그럼 내 아이템은 누가 결제해주냐 오늘은 나 용돈 못 받았어 그건 나 알바 아니고 저번에도 사줬잖아 그땐 그때 고 이번에도 부탁 좀 하자 좋은 말로 할 때 이번이 진짜 마지막이야
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 마스크좀 써주세요. 네? 여기는 사람들 통행이 많고 공공장소니까 마스크좀 써달라구요. 니가 뭔데 이래라 저래야? 좋은말로 할때 마스크 써라. 싫은데 니가 뭔데 참견이야? 마스크 안쓰면 니 안면 다 칼로 찢어버린다. 내가 왜 니말대로 해야되는데? 야 가까이 와봐. 얼굴 찢어버리게. 죽고 싶어? 니가 먼데 내얼굴을 찢네 마네야?
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 이사원은 조금 있다가 시간 좀 내게. 맡기실 업무가 있으신가요? 내가 조금 있다가 딸 학교에 좀 들러야하거든. 운전 면허는 있지? 네. 면허는 있습니다. 그러면 나 좀 데려다 주게. 올 때도 부탁해. 하지만 팀장님. 오늘 아직 할 업무가 많습니다. 지금까지 안하고 뭐했어? 하기 싫어? 아. 아닙니다. 지금 가서 커피도 좀 사와. 난 아이스 아메리카노로 갖다줘. 돈은 나중에 줄게. 알겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 어? 누가 못난 새끼지? 엥? 누가 못난 새끼일까? 설마 머리 큰 다현이는 아니겠지? 뭐야 갑자기 나한테 왜 그래? 네가 먼저 내 뒤 땀화를 깠잖아 뻔뻔한 새끼야 나보고 양아치라고 그치 재형아 설마 너 날 배신했어? 저 그게 아니 난 그런적이 없는. 내 친구가 얘 친구인데 내가 뒷조사를 좀 했지 그 친구가 누구인데 대체 내가 그걸 말할 것 같냐? 암튼 너희들도 내 뒤에서 욕 할 생각하지 마 그리고 너희는 앞으로 왕따당할 준비하고
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 아 저번에 말했던 우리 팀 과장님 있잖아 진짜 개꼰대야 왜 또 지랄했어 어 회사에서 슬리퍼 질질끌지말라고 괜히 시비걸잖아 그러면서 원래 다른 회사는 슬리퍼 신는것도 안된다나 뭐라나 아 개빡쳐 아 진짜 어딜가나 꼰대는 있구나 어쩌겠냐 아 진짜 회사 휴가 한 이주일 내고 싶다 그렇게 길게 휴가 내면 뭐할껀데 여행 음 글쎄 여행보다도 일단 그냥 집에서 푹 쉬면서 넷플릭스 보고 잠 늦게까지 자고 힐링하고 싶다 주말에 그렇게 하면 되잖아 아 뭔가 주말은 그렇게 잘 안돼 부모님도 뵈러 가야하고 여자친구도 만나야하고 은근 바쁘다니까 가끔 친구도 만나야지 하긴 제대로 쉬려면 길게 휴가를 내야 맘 편하게 쉬지 그니까 그런거 생각하면 군대가 편했다니까 다시 입대해 그럼 꺼져 제발
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 어이 형씨 네? 내가 담배가 똑 떨어졌는데 있으면 하나 줘봐 저도 이게 돛대인데요 형씨 딱봐도 나보다 어려보이는데 그렇게 어릴때 담배피면 폐에 구멍나 . 아저씨나 피지마세요 얼씨구? 겁대가리 상실했네? 가보겠습니다 가긴 어딜가 맞고 줄래 그냥 줄래 아휴 그냥 드릴게요 좀 떨어지세요
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 김사원 주말에 일 없지? 약속 있나?  아 네! 팀장님. 이번 주말에 여자친구 만나기로 했습니다.  여자친구? 여자친구는 일요일날 보고 나랑 금토 배낚시나하러 가자고  아 죄송합니다. 여자친구랑 약속 예전부터 잡은거여서요.  에이 약속은. 나 싫어해서 그러지? 이번에 인사고과 있는데 말이야 으흠  진짜 아닙니다. 매주 토요일마다 여자친구랑 만나고 있어서요. 죄송합니다.  민수씨. 너무 개인주의야. 이 직장생활이 말이야. 회사에서 일하는게 전부가 아니야  죄송합니다. 안될 것 같습니다.  죄송은. 그냥 나랑 여행가기 싫다고 말해. 정을 쌓으려고 하는데 이런식으로 거절을 하네 요즘 것들은 말이야. 회사가 일잘하고 일만하려고 오는게 아닐텐데. 쯧쯧  죄송합니다. 더 열심히 하겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 김쌤! 나좀봐 네? 도데체 오늘 키즈노트에 어떻게 썼가니 태화어머니가 난리셔? 아 태화가 다른 친구들을 좀 문다고 주의 부탁드린다고. 혹시나 눈 돌리면 사고날수도있다고 태화어머니가 얼마나 기분이 상했는지 나한테 전화하셔서 이십분을 다다다하시더라? . 네.죄송합니다 아니 그런걸 그렇게 직접적으로 말할 필요가 있을까? 적당히 돌려서 좀 하지 그랬어 .하지만 태화가 한두번도 아니고 나도 알아 안다고 하지만 적당히 삼키고 숨기고 해야지 그걸 일일이 미주알 고주알 다 말하면 학부모들 신경쓰여하는거 몰라? 그러다가 소문이라도 안좋게 나면 어쩌려고 그래 죄송합니다. 다음부터는 주의하겠습니다
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 언니 내 지갑에 있던 5만원 혹시 언니가 가져갔어.? 어. 왜? 나 오늘 친구들이랑 약속있는데. 나도 약속있어 그럼 언니가 엄마한테 말씀드려서 받으면 되잖아. 너 지금 말 대꾸 하냐? 내가 돈 좀 가져갈 수 있지. 짜증나게 쫑알거리네 그렇지만 나도 오늘 약속 있어서 돈이 필요해. 그럼 니가 엄마한테 다시 받으면 되겠네. 그만 귀찮게 해. 내가 니 부탁으로 엄마한테 말 안한 니 비밀이 어디 한두가지냐? 확 말해? 왜 얘기가 그렇게 돼. 아 진짜 짜증나게. 너도 이렇게 너만 편하려고 하는데 나도 니 편의 봐 줄 필요가 없지. 말한다? 아니야.내가 엄마한테 용돈 다시 받을게. 야 그럼 받는김에 더 5만원 받아와. 나 좀 부족하니까. 같은 말 반복하게 하지마라 알겠어.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 길동님 어머니 되시나요 ? 누구시죠 ? 여기는 길동병원입니다 지금 길동님께서 교통사고로 응급수술을 들어가셔야합니다 네 ? 무슨 소리세요 우리 아들이 거기왜  매우 긴급한 상황인데 수술비를 먼저 넣어주셔야 일순위로 수술 진행되는 부분입니다 지금 당장 갈께요 수술먼저 시켜주세요  네 당장오시고 계좌 번호 보내오니 당장 입금하세요 5분내로 입금 확인안되면 다른 분 먼저 수술장 들어갑니다 병원도 곧 바로 오시구여 네네 살려만 주세요 네 알겠습니다 힘써보겠습니다 수술비가 여간 비싼게 아니니 . 감사합니다 감사합니다
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 오늘도 야근이야 그래 짜증 나서 나한테 일 다 시키고 지금 퇴근한다 그러기로 유명하잖아 한 두 번이나 조그만한 실수에 겁나 성질 내 누구랑 할 줄 몰라서 어쩌겠냐 회사에서 그렇다고 대놓고 경기 수도 없고 하루만 날 잡고 야탑 하고 싶다 그만두게 될 때 마지막 날에 해 아직 속 시원하게 다 풀어 근데 속 다 풀면 죽어 그러네 목숨이 연락이라도 못 살아 나을 듯 진짜 그래도 오래 살겠네 욕 하도 먹어서
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 내일 모레까지 천만원 더 준비해주세요 네? 이번달은 이미 원하시는 금액 다 맞춰드렸잖아요 우리 사이 금액에 상한가가 어딨습니까 그때그때 상황에 다른거 아시잖아요 저 정말 이번달에 드린게 다에요. 현금 더 만들래도 만들 수가 없습니다 정말이에요 이제 겨우 자리 잡은 딸자식 앞길 망가뜨리고 싶나보네? 한번만 살려주십쇼 제 딸만은 건들지 말아주십쇼. 매번 이렇게 부탁만 하면 내가 어떻게 들어주나 다음달에 어떻게든 채워볼테니 이번만 살려주십쇼 제발 돈이 없으면 몸으로라도 떼워 그럼 몸뚱이 하나로 돈 벌어 먹고 살고 있습니다. 제발 이번만 좀 봐주십시오
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 자네 그 사실을 자네말고 누가 알고 있나? 네? 저밖에 모릅니다 부장님 정말인가? 다른 사람들이 알면 큰일나는 거 알지? 네.맞습니다 그런데 참 이상하지? 무슨 말씀이십니까 나는 자네한테밖에 말안했는데 어떻게 김부장도 알고있지? 좋은 정보 같이 먹자고 어제 전화왔더라고 저.저는 모르는 일입니다 자네 입이 참 가볍네 김부장한테는 얼마 받았어? 자.잘못했습니다 내가 자네같은 거 한명 쥐도새도 모르게 없애는거 일도 아닌거 알지? 돈좋아서 여기붙고 저기 붙고 박쥐같이 굴다가 좋아하는 돈 못만져보고 오늘 내일 할수도 있어 마지막 경고다
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 안녕하세요 씨 공부 잘 한다면서요 성적이 우수하다면 서요 네 아닌데요 맞다고 들었는데 왜 거짓말 하세요 아니 그렇게 잘 알지는 못해요 지금 잘난 척하는 겁니까 아니 저보다 더 잘하는 사람 많은데 이렇게 상사한테 말대꾸하는 거 보니까 자신감 있는 거 같은데 이번 프로젝트에 할일을 더 해 놓을게요 님 이건 좀 아닌 거 같은데요 할일을 더 추가 하기 전에 그 입 다무세요 네 저 공부 잘하고 성적도 우수합니다 그래서 계속 말을 해야겠는데요
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 희주씨 네???  아침에 좀 일찍 오지  네? 지금도 20분전에오는데요 아니 좀 일찍 와서 바닥도 닦고 그래 . 청소 아주머님이 계시는데 제가 굳이 그래야할까요?  아니 . 정말 말귀 못알아먹네 막내면 막내답게 사무실 챙기는 시늉좀 해야지  네??? 납득이 잘안되는데요 원래 사회생활은 납득안되는 일이 넘쳐 집안처럼 편안하게 지내려고했니? .네.  알아들었으면 내일부터 더 일찍와서 부장님 책상좀 닦고 그래 바닥도 쓸고
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 야. 보이냐? 개멋있지. 오백만원짜리 시계야. 응. 한번 만져나볼래? 아. 넌 본적도 없어서 뭐가 뭔지도 모르겠지?  불쌍해라 불쌍해. 넌 여기있으면 안되고 후원 받는데 들어가야돼. 아니야. 나도 열심히 살고 있어. 열심히 산다고 돈이 들어와? 어휴 냄새. 좀 씻고나 다녀라 . 옷도 그게 뭐냐. 너 옷 일주일동안 입지? 촌스럽긴. 아니야.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 민정아 안녕 ? 어? 어 안녕 너는 역시 아침부터 공부하고 있구나. 대단해 곧 수업시작이라 미리 준비하고 있었어. 아 맞다 이번 시간 수학시간이지. 응 근데 무슨 일 있어? 일? 있지. 너 혹시 수학 과제했니? 응 했지. 오늘까지 해오라고 하셨잖아. 그래서 말인데 내가 어제 너무 피곤해서 과제를 못하고 잤거든. 니가 한 과제 내가 좀 써야겠어. 그게 무슨말이야. 이건 내가 한 과제지. 너에게 주려고 해온 게 아니잖아. 너 학교 얌전히 다니고 싶은거 아니였어? 난 너가 그런 줄알고 너한테 아무짓도 안했는데 그래도. 내가 해온 숙제를 니가 가져가겠다는게 말이 안되잖아. 그래서 못주겠다는 거야 ? 너 끝나고 남고 싶어?  아.아니야. 알겠어.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 우리 씨는 얼굴도 예쁜데 몸매도 예쁘네 씨는 좀 보고 배워야겠다 아유 과장님 전 마음이 제일 예뻐서 그래요 얼굴도 예쁘면 좋잖아 화장도 좀 하고 신경좀써 과장님 자꾸 비교하시면 저 기분 나빠요 아 농담인데 뭘 정색하고 그래 성격이 좀 모났네 과장님 이거 직장내 괴롭힘이요 아시죠? 뭐? 신고해봐 어디! 이런 말도 못하는 그게 법이냐? 네 신고할게요 야 저 년 잘라버려 재수가 없으려니까 자르세요
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 시험에 자신이 없어서 일부러 아픈 척을 하고 학교를 안 갔어. 해방감이 들었어. 시험을 안 봐서 기분이 좋으시군요. 지금까지 시험이 나를 얼마나 옭아맸는지 알게 돼서 한국의 시험 문화에 화가 나. 화나는 감정이 나아지려면 어떻게 해야 할까요? 한국 시험 문화에 대한 분노를 시험을 대하는 즐거움으로 변화시켜야겠어. 목표대로 시험을 즐겁게 느낄 수 있게 되길 바라요.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 너가 어떡하면 나한테 이럴 수 있니? 내가 뭘 어쨌는데 도와준거 뿐이라고 도와줬다니 사람은 이렇게 만들어놓고?  내 약속과는 너무 다른데? 참 할말이 없다 이제 안할래 너가 이러면 안되는거 아니야.? 니 엄마를 위해서라면 뭐든 한다면서 이제 앞으로 얼굴 보지 말자 자꾸 이렇게 나오면 네 엄마가 위험해질 수 있어 맘대로해 니가 설마 총으로 죽이겠니 칼로 찌르겠니 이렇게 나온다 이거지 두고봐 후회하게 해주지
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 인재씨 무슨 보고서를 이따위로 씁니까 그게 무슨 말씀이세요 차장님 줄간격폰트 다 엉망이에요 아까 보고드리고 말씀하신대로 작성한건데. 다시 하겠습니다. 그럼 제가 잘못했다는 건가요 아닙니다 죄송합니다 인재씨 그렇게 안봤는데 완전 건방진 사람이구만 무슨 말씀을 그렇게 하세요 정신차리고 회사 다니세요 죄송합니다 더욱 노력하겠습니다
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 와 이거 뭐야?  새로 산 틴트  이거 비싼거 아니야?  응 백화점에서 산거야  나 한번만 발라볼래  응.? 나도 어제 사서.  싫단거야?  아니. 그래도 내꺼니까  아 그래? 그럼 너도 내꺼 써 아님 이거 내가 갖고 넌 내꺼 새거 줄게  뭐?.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 제가 뭘 그렇게 잘못했죠? 일이던 뭐던 잘하는 게 뭐가 있다고 그래? 뭘 그렇게 잘못했는지 말하시라고요. 너는 그냥 죽어버려야돼. 칼 내리세요 이런 식이면 저도 가만히 못 있습니다. 너가 하면 뭘 한다고 그래? 신고할거고 진짜 그만 하세요. 너 죽일거야
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 미연아 너 저 선배랑 친해 어 아니 친한건 아니고 그냥 가끔 얘기하는 정도 왜 저 선배 요즘 새내기들한테 겁나 찝적거린대 얼마 전에 유진이한테도 고백했다가 차였잖아 아 진짜 몰랐네 어쩐지 요즘 갑자기 친한 척 하시더라고 유진이 진짜 불편해하더라 너도 조심해 그래야겠다 요즘 왜 이렇게 이상한 사람들이 많지 그니까 사람 쉽게 믿으면 안된다는 말이 맞는거 같애 맞아 이게 이십대의 삶인가 와 우리 이십대다 히히 의식의 흐름 머야
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 영희씨 한번만 만나주세요. 저 괜찮은놈입니다 수환씨 자꾸 따라다니지 마세요 영희씨가 한번만 만나주시면 되지않습니까 저는 수환씨같은 사람 관심없습니다. 그만가주세요 영희씨 제가 정말 영희씨가 마음에 들어서 그렇습니다.  이렇게 자꾸 스토킹하면서 괴롭히지마세요 영희씨 사랑합니다. 당장 그만두세요. 더이상 스토킹하면서 괴롭히시면 경찰에 신고하겠습니다. 영희씨. 다시한번만 생각해주세요. 한번만 만나주세요 저는 수환씨같은 사람 질색입니다. 그만 가주세요
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 야 박사원 너 이번 주말에 내 차 세차 좀 해라 부장님 이번 주말에 제가 약속이 있어서. 아니 너가 저번에 해준다며 맡겨만 달라며 그렇다고 하루 전에 그러시면 어떡합니까 뭐야 이거 대드는거야? 됐고 이번 주말에 무조건 해놔 아니 부장님. 이거 안해놓으면 이번 평가에서 불이익있을거야 네 알겠습니다.
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 안녕?? 오랜만이다 그치? 나 기억나?  아 너 고등학교때. 맞지?  아!! 맞아   그런데 왜 전화했어?  아 다른게 아니라 내가 사실 보이스피싱을 당해서. 부탁할 친구도 없더라고. 그러나 너가 생각났어.  아. 어.  정말 미안한데 돈 100만원만 빌릴 수 있을까?  응.? 그. 100만원이 적은 돈도 아니구. 미안  아 그럼 50만원이라두. 내가 정말 급해서 그래. 꼭꼭 값을께.  아. 정말 미안.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 흑흑 나 도저히 못찾아 찾아줘 거봐 디자이너들이 생각이없다니까 중국인들이 최고야 중국인좀데려다가 좋은원단으로좀 만들어주지 엠제이드사지마 물론돈없어아직 웅사지마 가방필요한데어떡해 잘좀찾아보 정말없지만 찾고말겠어 말일까지 찾아 없지만 퉁
#
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 안녕하세요 저는 이번에 새로온 알바생입니다 반가워요 서브웨이 알바는 처음이죠 네 빵집 아르바이트는 해봤는데 서브웨이는 처음이네요 별거 없고 비슷해요 포스는 해봤어요 네 많이 해봤어요 그러면 빵 종류랑 레시피만 설명드릴게요 감사합니다 혹시 메일주소 알려줄래요 레시피 보내드릴게요 문자로 보내드릴게요 고마워요 네 잘 부탁드려요
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 교수님 부르셨어요?  어 왔나?  무슨 일이세요?  내일 총장님이랑 김의원님이랑 식사 자리가 있는데 너가 와줘야 겠다.  네? 무슨 말씀이세요. 그런 자리 싫다고 말씀드렸잖아요.  거절하는건가? 자네 이번 졸업 논문. 별로 중요하지 않나 보지?  아. 교수님. 참석하겠습니다.  그래 잘생각했다. 김의원님은 화장 진한거 안좋아하시니까 옅게 하고 오도록.  네.  나가보게
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 서울 관악아파트인데요, 뒷 놀이터에서 한 학생이 맞고 있는거 같아요. 정확한 주소좀 알려주시겠어요? 서울특별시 관악구 신림동 244 관악아파트 뒷 놀이터요. 지금 그쪽에 학생들 몇명이 있는것 같으세요? 학생 10명 정도 있는거 같아요. 알겠습니다. 지금 그쪽으로 경찰을 보내겠습니다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 아 냄새 야 여기 어디서 하수구 냄새 안 나 ? 아우 뭐야 이 냄새? 아 얘 냄새인가 보다 아니야. 어우 얼른 맡아봐 얘 냄새인지 아 싫어 더러워 얘들아 냄새 안 나?! 아니야 나 아니야. 너가 말하니까 더 냄새나잖아 그냥 가만히 닥치고 있어
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 아가씨 이쁜데 왜 이러세요 우리랑 좀 놀까? 싫어요. 그럼 돈 좀 빌려주던가 얼마나요?? 십만원 정도?? 저 그렇게 큰 돈이 없는데요. 이 년이 죽어볼려고 환장했나? 돈 없어? 진짜 없어요
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 이거 왜 이렇게 놔! 똑바로 놓으라고 했지? 아침부터 왜 그러냐. 아니 수저통 똑바로 놓으라고 했잖아. 너 내 신경 건드리지마라. 뭐? 그거 지금 협박이야. 네가 협박을 해야 좀 알아 듣지. 안 그래? 진짜로 못 됐다. 왜? 어떻게라도 하게? 응. 넌 진짜 한 주먹거리야. 진짜 너를 남편으로 둔 건 내 최대 실수야. 한 번만 더 그 입 씨부려봐.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 오빠 나 카드값이 밀렸어 저번이 마지막이랬자나 이번에 내가 코로나로 일도 쉬구 힘들었자나 그래도 저번에 꾼돈도 아직 안갚았어 이번한번만 더 도와줘 니가 내여자친구지만 그래도 나도 힘든상황이야 대출받아야해 나는 신용불량자인데 나한테 할소리야? 나도 신불자되겠어 나 안사랑하네 이번이 마지막으로 빌려주는거야 진짜
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 원투 원투 야 똑바로 서 으 으윽 그만해 아이씨 서 있어봐 좀 아프다고! 어디서 소리를 질러? 미 미안 아. 나 귀 아픈 거 알면서. 너 일부러 그랬어? 아 아니야 미안해 야 서봐 다시 인간 샌드백 간다 원투 원투! 으윽.
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 야 오늘 유현이형이 우리 다 모이라는데 아 그형 또 왜 몰라 술마실거 같은데 아 오늘 술 먹기 싫은데 야 형이 사줄 텐데 개꿀이지 뭘 개꿀은 먹기 싫은데 먹어야 되는데 그게 꿀이냐 그냥 즐겨 임마 하여튼 불만은 존나게 많아요 아 뭐래 진짜 짜증나게
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 저녁 먹었어 아니 오늘 뭐먹을까 오늘 집에서 라면 먹자 무슨 라면 먹을건데 열라면에 순두부 넣어먹는게 맛있대 진짜 맛있어 내 친구가 꼭 먹으래 와 그러면 오늘 꼭 먹어보자 내가 순두부랑 열라면 사갈게 그래그래 오늘 늦지 말고 들어와 응 알았어
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 지인의 말만 듣고 가입한 보험이 살펴보니 제대로 보장해주는 게 하나도 없었어. 지인의 말만 듣고 가입한 보험인데 많이 화가 나시겠어요. 지인이 나에게 사기를 친 걸까? 노후준비를 해야 하는데 정말 막막해. 이 상황을 해결하기 위해 무엇을 할 수 있을까요? 보험사에 전화해서 해지하고 앞으로는 잘 알아보고 보험에 가입해야겠어. 보험사에 전화해서 문제가 해결되었으면 좋겠네요.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 너 어제 집에 바로 안 들어갔지? 어떻게 알았어? 내가 눈이 좋아 왜 묻는건데? 너희 부모님이 아시면 어떨까? 절대 안돼! 그럼 내 부탁 하나만 들어줄래 그걸 내가 왜! 그럼 나 지금 부모님한테 전화하고 알았어 부탁이 뭔데
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 철수야 말 들어야지 싫은데 철밥통 선생아 너 선생님한테 말버릇이 뭐야 야 내가 너말을 왜 들어야 해? 너 때문에 애들이 피해보고 있잖아 지금 너 때문에 얘들이 집에 못가는거 안보여? 야 나 때문에 집에 못가는걸로 보이냐 저 멍청한 선생이 나를 핑계로 집에 안보네주는걸로 보이냐 야 뭐라고  똑바로 말해 뭔 똑바로 말해야 애들한테 그런거 시키지마 왜 학생들 골탕 먹이는게 들통날까봐 뜨끔해? 이 새끼가 어쭈 욕 이거 교육청에 신고해야지
# 예측 라벨: 기타 괴롭힘 대화
# ------------------------------
# 문장: 양재 터널 입구 앞인데요. 사고가 났거든요? 위치가 양재 터널 맞으시죠? 네, 지금 버스가 승용차 한대를 덮쳤어요. 버스가 승용차를 덮쳤다고요 지금 사고가 일어난건가요? 네 운전자 분은 괜찮으세요? 워낙 사고가 크게나서 잘 모르겠어요. 알겠습니다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 동생이쁘다. 나주라 안돼 우리동생건들지마. 왜 안되냐? 좀 달라고 니 목숨값으로 동생 달라는건데 어렵냐? 안돼 그냥 날 죽이고 동생은 건들지마 그렇게 나오면 재미없지 널 그리고 죽이면 동생이 나한테 앙갚음이 있지 우리 동생 건들지 말아줘 갠 내버려둬 그러니까 다시 내 밑으로 들어와 그럼 너도 살고 동생도 살어 제발. 부탁이야 건들지말아줘. 그냥 날 죽여줘 이 약먹으면 되는거지? 그래 좋아 대신 조건이 있어. 하나로는 재미없지 3병마셔 그러고 죽어 그럼 되지. 우리 동생 건들지마.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 혹시 나 오늘 2만원만 빌려주만 안돼? 응? 안돼. 나도 요즘 맨날 택시타느라 택시비 많이 나와서 적자란 말이야. 머? 그래도 택시는 조금 일찍 일어나면 굳을 수 있는 돈이잖아. 나 지금당장 멀 살 돈도 없어 정말 미안한데. 나 진짜 돈이 없어서 그래. 근데 나도 돈이 없어. 좀 빌려주라. 미안한데 안될 것 같아. 야. 좀 너무한거 아니야? 나는 진짜 힘들게 사는데 택시비에 쓴다고 친구한테 돈을 안빌려주는건 너무하지 않어? 그런건 아닌데. 너한테 돈을 빌려주면 나는 어떻게 벼텨. 내가 너 용돈 받기 전까지 돌려줄게 어려운 건 아니잖아. 알겠어.
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 이봐 네? 누구세요? 입다물고 가진거 다내놔 경찰에 신고할거에요 할 수 있으면 해봐 제발 살려만 주세요 저 돈 없어요 거짓말마 다 줄게요 그래야지 이제 됐죠?
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 미나씨 휴가 결제 올리기 전에 저랑 상의하라고 말한거 기억해요? 네 합니다. 보고서를 보니 저에게 상의 안한 내용이 올라갔던데요. 대표님과 바로 상의하여 결제 올렸습니다. 미나씨 지금 미나씨 직속 상사가 누군지 몰라? 죄송합니다. 미나씨가 낙하산인건 알겠지만 기본적인건 지켜야 할 거 아니예요. 네. 미나씨 결제 다시 올리세요. 네 알겠습니다.
# 예측 라벨: 일반 대화
# ------------------------------
# 문장: 교수님 제 논문에 제 이름이 없나요?  아 무슨 논문말이야?  지난 번 냈던 논문이요. 그거 제가 1 저자로 쓴 건데.  그랬던가? 흠.  제가 힘들 게 쓴 논문인 데 왜 선배이름으로 퍼플리쉬 된건가요?  이 선생 교수되기 싫어? 이 바닥에는 상도덕이 있는거야. 선배가 먼저 잘되면 안되나?  교수님 제가 쓴 논문인 데 억울합니다.  억울할 거 없어. 나중에 선배들이 다 챙겨줄 건데 무슨 걱정인가.  그래더 이 논문 제가 힘들게 쓴 논문이에요. 게다가 좋은 곳에 실렸다고요.  자네는 위아래가 없나?
# 예측 라벨: 직장 내 괴롭힘 대화
# ------------------------------
# 문장: 야 너  네 저요? 그래 너 왜요 돈좀 줘봐  돈 없어요 돈이 왜 없어 지갑은 폼이니? 진짜 없어요 줘봐 내가 확인할거니까 제발요 진짜 없어요
# 예측 라벨: 갈취 대화
# ------------------------------
# 문장: 야 너 빨리 안 뛰어와? 너 이 환자 제대로 봤어 안 봤어 어제 저녁부터 계속 보다가 지금 과장님께서 잠시 부르셔서 다녀 왔습니다. 혹시 무슨 문제 있습니까? 너 이 사람 약물 용량 잘 못 처방해서 죽을 뻔했어 알아? 그거 어제 노티 주신대로 전달해서 그대로 주사 한거라 문제 없을텐데요 그럼 내가 잘못 노티 줬다? 지금 날 탓하는거야? 여기 문자 보시면 노티 주신거와 똑같이 처방 했습니다 잘 못 처방하지 않았어요. 그래서 뭐 어쩌라고 니가 잘 보고 문제 있는거 같으면 나한테 먼저 연락해야 했던 거 아니야? 내가 아무리 노티 내려도 이상한거 없나 살폈어야지 어제 골프 치러 가신다고 연락 하시면 당직 한 달 내내 세우실거라고 전화하지말라고 하셔서 안 했습니다. 그리고 저는 노티가 맞게 내려온 줄 알고 그대로 주입한거 밖에 없습니다. 아 그래서 내탓 하겠다? 왜 지금 바로 과장님 콜해서 내가 환자 죽일뻔 했다고 떠들고 다니지 그러냐 내가 꼴보기 싫은거잖아 너 아닙니다 죄송합니다. 다음부터는 조심하도록 하겠습니다 야 됐어 너네 동기한테 이번달 당직 할 필요 없다고 그래 너가 두 달 내내 서 빠지는 날 있으면 한 달 씩 더 추가다 죄송합니다 한번만 용서해주세요.
# 예측 라벨: 협박 대화
# ------------------------------
# 문장: 엄마 저 그 돈 안해주시면 정말 큰일나요.  이유도 말하지 않고. 몇번째니 경민아.  엄마 더이상은 못한다.  나중에 다 말씀 드린다고 했잖아요. 저 죽는거 보고싶으세요?  차라리 죽어라. 너때문에 우리 가족 전부가 힘들어.  대체 무슨일이니?  오늘까지 꼭 막아야 할게 있다고요. 이거 못해주시면  집안에 불지르고 저도 타 죽을거에요.  엄마 정말 너무 힘들어 경민아. 언제까지 그럴거니.  이번이 마지막이에요 정말.  마지막이 대체 몇번쨰인지 모르겠구나.  죄송해요.
# 예측 라벨: 협박 대화
# ------------------------------

# %%
# 1. 디바이스 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

# 2. 입력 텐서도 같은 디바이스로 이동
data_config = {
    "test_file": "/content/Aiffel_DLThon/data/processed/clean_test.csv",
    "train_file": "./Aiffel_DLThon/data/processed/original/clean_train.csv"
}

# ✅ 올바른 접근
test_df = pd.read_csv(data_config["test_file"])
test_encodings = tokenizer(
    test_df["clean_text"].tolist(),
    padding="max_length",
    truncation=True,
    max_length=400,
    return_tensors="pt"
)

# ⬇️ 여기가 핵심
test_encodings = {k: v.to(device) for k, v in test_encodings.items()}

# 3. 예측
with torch.no_grad():
    outputs = model(**test_encodings)
    preds = outputs.logits.argmax(dim=-1).cpu().numpy()

# %%
save_submission(final_preds, "./Aiffel_DLThon/data/original_data/submission.csv", './submission.csv')
log_message("Experiment complete.", '.')
# Out:
# [2025-05-06 21:21:50] Experiment complete.

# %%
# 파일 로딩
df = pd.read_csv('/content/submission.csv')
log_target_distribution(df, '.')
# Out:
# [2025-05-06 21:22:01] 📊 Target 클래스 분포:
# [2025-05-06 21:22:01] Label 0: 74
# [2025-05-06 21:22:01] Label 1: 104
# [2025-05-06 21:22:01] Label 2: 95
# [2025-05-06 21:22:01] Label 3: 101
# [2025-05-06 21:22:01] Label 4: 126
